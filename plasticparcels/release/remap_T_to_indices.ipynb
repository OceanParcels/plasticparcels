# %%
import xarray as xr
import numpy as np
model_mask = xr.open_dataset('/storage/shared/oceanparcels/input_data/MOi/domain_ORCA0083-N006/PSY4V3R1_mask.nc')

# %%
## Map to the ocean model grid

# Load in land mask
data_mask_land = xr.open_dataset('../../data/output_data/masks/mask_land_NEMO0083.nc')

lats_ocean = data_mask_land['lat'].data[np.where(~data_mask_land['mask_land'])]
lons_ocean = data_mask_land['lon'].data[np.where(~data_mask_land['mask_land'])]

# A list of ocean points
ocean_points = np.array([lons_ocean, lats_ocean]).T

# %%
xr.where(~data_mask_land['mask_land'],)
# Out:
# <xarray.DataArray 'mask_land' (x: 3059, y: 4322)>
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])
# Coordinates:
#     lon      (x, y) float64 72.92 73.0 73.08 73.17 73.25 ... 73.0 73.0 73.0 73.0
#     lat      (x, y) float64 -77.01 -77.01 -77.01 -77.01 ... 50.0 50.0 50.0 50.0
# Dimensions without coordinates: x, y

# %%
model_mask = xr.open_dataset('/storage/shared/oceanparcels/input_data/MOi/domain_ORCA0083-N006/PSY4V3R1_mask.nc')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/py3_parcels/lib/python3.11/site-packages/xarray/backends/file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File ~/anaconda3/envs/py3_parcels/lib/python3.11/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/storage/shared/oceanparcels/input_data/MOi/domain_ORCA0083-N006/PSY4V3R1_mask.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), '30553517-53df-4619-9492-cab8e1fab90e']
#
# During handling of the above exception, another exception occurred:
#
# ...
