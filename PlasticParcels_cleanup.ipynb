# %% [markdown]
# # PlasticParcels DRAKKAR Tutorial
# In this tutorial we will introduce you to some of the basic Parcels functions, as well as utilise the PlasticParcels tool for simulating microplastic pollution in the Mediterranean sea.
#
# By the end of this tutorial you should be able to create and visual hydrodynamic (and other) fields, create particle sets that represent marine microplastic pollution release locations, and apply physics parameterisations to simulate the dispersal of microplastics in the ocean.
#
# We will start by importing a number of necessary packages.

# %%
## Library imports
import os
import numpy as np
import pandas as pd
from datetime import datetime, timedelta

# Parcels and PlasticParcels imports
from parcels import ParticleFile, JITParticle, Variable
#from PlasticParcels import create_fieldset, create_particleset, create_kernel, load_default_settings, create_particleset_from_file, load_test_settings
#from utils import select_files, create_directory, getclosest_ij
#import PlasticParcels
## Plotting imports
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

# %%
from PlasticParcels import constructors

# %%
import PlasticParcels as PP

# %% [markdown]
# # Model settings
# Using PlasticParcels, we will load the default settings for our sumulations, using the `load_default_settings` function.
#
# This returns two dictionary of parameters, one used for fieldset creation, the other for particleset creation.
#
# You can update the parameters by updating the dictionaries as necessary.
#
# The description of each parameter can be found in the PlasticParcels/helper.py file.

# %%
settings = PP.constructors.load_default_settings()

# %%
## View settings
settings
# Out:
# {'mode': '2D',
#  'allow_time_extrapolation': False,
#  'verbose_delete': False,
#  'mixing_f': False,
#  'biofouling_f': False,
#  'stokes_f': False,
#  'wind_f': False,
#  'ocean': {'directory': 'data/input_data/MOi/',
#   'filename_style': 'psy4v3r1/psy4v3r1-daily_',
#   'ocean_mesh': 'domain_ORCA0083-N006/coordinates.nc',
#   'bathymetry_mesh': 'domain_ORCA0083-N006/bathymetry_ORCA12_V3.3.nc',
#   'variables': {'U': 'vozocrtx',
#    'V': 'vomecrty',
#    'W': 'vovecrtz',
#    'conservative_temperature': 'votemper',
#    'absolute_salinity': 'vosaline'},
#   'dimensions': {'U': {'lon': 'glamf',
#     'lat': 'gphif',
#     'depth': 'depthw',
#     'time': 'time_counter'},
#    'V': {'lon': 'glamf',
#     'lat': 'gphif',
#     'depth': 'depthw',
#     'time': 'time_counter'},
#    'W': {'lon': 'glamf',
#     'lat': 'gphif',
#     'depth': 'depthw',
#     'time': 'time_counter'},
#    'conservative_temperature': {'lon': 'glamf',
#     'lat': 'gphif',
#     'depth': 'depthw',
#     'time': 'time_counter'},
#    'absolute_salinity': {'lon': 'glamf',
#     'lat': 'gphif',
#     'depth': 'depthw',
#     'time': 'time_counter'}},
#   'indices': {}},
#  'bgc': {'directory': 'data/input_data/MOi/',
#   'filename_style': 'biomer4v2r1/biomer4v2r1-weekly_',
#   'bgc_mesh': 'domain_ORCA025-N006/mesh_hgr_PSY4V3_deg.nc',
#   'variables': {'pp_phyto': 'nppv',
#    'bio_nanophy': 'phy',
#    'bio_diatom': 'phy2'},
#   'dimensions': {'pp_phyto': {'lon': 'glamf',
#     'lat': 'gphif',
#     'depth': 'depthw',
#     'time': 'time_counter'},
#    'bio_nanophy': {'lon': 'glamf',
#     'lat': 'gphif',
#     'depth': 'depthw',
#     'time': 'time_counter'},
#    'bio_diatom': {'lon': 'glamf',
#     'lat': 'gphif',
#     'depth': 'depthw',
#     'time': 'time_counter'}},
#   'constants': {'biofilm_density': 1388.0,
#    'algae_cell_volume': 2e-16,
#    'K': 1.3805834190672156e-23,
#    'R20': 1.1574074074074074e-06,
#    'Q10': 2.13,
#    'Gamma': 2.0,
#    'carbon_molecular_weight': 12.0,
#    'collision_probability': 1.0,
#    'algae_mortality_rate': 1.0,
#    'algae_respiration_f': 1.0}},
#  'stokes': {'directory': 'data/input_data/ERA5/waves/',
#   'filename_style': 'ERA5_global_waves_monthly_',
#   'variables': {'Stokes_U': 'ust', 'Stokes_V': 'vst', 'wave_Tp': 'pp1d'},
#   'dimensions': {'lat': 'latitude', 'lon': 'longitude', 'time': 'time'}},
#  'wind': {'directory': 'data/input_data/ERA5/wind/',
#   'filename_style': 'ERA5_global_wind_monthly_',
#   'variables': {'Wind_U': 'u10', 'Wind_V': 'v10'},
#   'dimensions': {'lat': 'latitude', 'lon': 'longitude', 'time': 'time'}},
#  'simulation': {'start_date': None,
#   'runtime': None,
#   'dt_write': None,
#   'dt_timestep': None},
#  'release_maps': {'coastal': 'data/release/generated_files/coastal_population_MPW_NEMO0083.csv',
#   'rivers': 'data/release/generated_files/river_emissions_NEMO0083.csv',
#   'fisheries': 'data/release/generated_files/agg_data_fisheries_info.csv',
#   'global_concentrations': None}}

# %%
# Set the simulation settings
settings['simulation'] = {
    'start_date': datetime.strptime('2019-01-10-00:00:00', '%Y-%m-%d-%H:%M:%S'), # Start date of simulation
    'runtime': timedelta(days=3),             # Runtime of simulation, use negative if releasing particles backwards in time
    'dt_write': timedelta(days=1),             # Timestep of output
    'dt_timestep': timedelta(minutes=20),       # Timestep of advection
    }

# %%
fieldset = PP.constructors.create_fieldset(settings)
# Out:
# WARNING: File data/input_data/MOi/domain_ORCA0083-N006/coordinates.nc could not be decoded properly by xarray (version 2023.6.0). It will be opened with no decoding. Filling values might be wrongly parsed.

# %%
fieldset.computeTimeChunk(0,1)
# Out:
# 86400

# %%
ax = plt.subplot(111, projection=ccrs.PlateCarree())

ax.pcolormesh(fieldset.U.grid.lon, fieldset.U.grid.lat, fieldset.U.data[0,0], transform=ccrs.PlateCarree())
plt.show()

# %%
# ax = plt.subplot(111, projection=ccrs.PlateCarree())

# ax.pcolormesh(fieldset.Stokes_U.grid.lon, fieldset.Stokes_U.grid.lat, fieldset.Stokes_U.data[0], transform=ccrs.PlateCarree())
# plt.show()

# %%
# ax = plt.subplot(111, projection=ccrs.PlateCarree())

# ax.pcolormesh(fieldset.pp_phyto.grid.lon, fieldset.pp_phyto.grid.lat, fieldset.pp_phyto.data[0,0], transform=ccrs.PlateCarree())
# plt.show()

# %%
# ax = plt.subplot(111, projection=ccrs.PlateCarree())

# ax.pcolormesh(fieldset.bio_diatom.grid.lon, fieldset.bio_diatom.grid.lat, fieldset.bio_diatom.data[0,0], transform=ccrs.PlateCarree())
# plt.show()

# %%
import numpy as np

# %%
# PlasticParticle = JITParticle.add_variables(
#     [
#         Variable("plastic_diameter", dtype=np.float32, initial=np.nan),
#         Variable("plastic_density", dtype=np.float32, initial=np.nan),
#         Variable('windage_coefficient', dtype=np.float32, initial=0.),
#         Variable('settling_velocity', dtype=np.float64, initial=0.),
#         Variable('seawater_density', dtype=np.float32, initial=np.nan),
#         Variable('absolute_salinity', dtype=np.float64, initial=np.nan),
#         Variable('algae_amount', dtype=np.float64, initial=0.)
#     ]
# )

# ## Is this a better way?
# class PlasticParticle(JITParticle):
#     def __init__(self):
#         self.add_variables([
#             Variable("plastic_diameter", dtype=np.float32, initial=np.nan),
#             Variable("plastic_density", dtype=np.float32, initial=np.nan),
#             Variable('windage_coefficient', dtype=np.float32, initial=0.),
#             Variable('settling_velocity', dtype=np.float64, initial=0.),
#             Variable('seawater_density', dtype=np.float32, initial=np.nan),
#             Variable('absolute_salinity', dtype=np.float64, initial=np.nan),
#             Variable('algae_amount', dtype=np.float64, initial=0.)
#             ])

# %%
## the usual parcels.ParticleSet.from_list() approach

# %%
## Define particle types and release locations

settings['release'] = {
    'wind_coefficient' : 0.01, # Percentage of wind to apply to particles
    'plastic_diameter' : 0.001, # Plastic particle diameter (m)
    'plastic_density' : 1020., # Plastic particle density (kg/m^3)
    'initialisation_type': 'coastal',
    #'continent': '',
    #'region': '',
    'subregion': 'Southern Europe',
    #'country': 'Greece',   
}

## Create the particleset
pset = PP.constructors.create_particleset_from_map(fieldset, settings)

# %%
pset
# Out:
# P[1704](lon=-31.268887, lat=39.440625, depth=0.000000, plastic_amount=2.835417, time=not_yet_set)
# P[1705](lon=-31.268604, lat=39.374840, depth=0.000000, plastic_amount=1.402523, time=not_yet_set)
# P[1706](lon=-31.185885, lat=39.637903, depth=0.000000, plastic_amount=1.010392, time=not_yet_set)
# P[1707](lon=-31.185319, lat=39.506577, depth=0.000000, plastic_amount=26.487350, time=not_yet_set)
# P[1708](lon=-31.184493, lat=39.309215, depth=0.000000, plastic_amount=0.278144, time=not_yet_set)
# P[1709](lon=-31.102296, lat=39.703706, depth=0.000000, plastic_amount=1.008799, time=not_yet_set)
# P[1710](lon=-31.101464, lat=39.506787, depth=0.000000, plastic_amount=26.488430, time=not_yet_set)
# P[1711](lon=-28.836292, lat=38.584876, depth=0.000000, plastic_amount=0.985270, time=not_yet_set)
# P[1712](lon=-28.836238, lat=38.518401, depth=0.000000, plastic_amount=0.986841, time=not_yet_set)
# P[1713](lon=-28.752572, lat=38.651342, depth=0.000000, plastic_amount=2.951711, time=not_yet_set)
# P[1714](lon=-28.752425, lat=38.451916, depth=0.000000, plastic_amount=5.971512, time=not_yet_set)
# P[1715](lon=-28.668794, lat=38.651376, depth=0.000000, plastic_amount=3.144610, time=not_yet_set)
# P[1716](lon=-28.668667, lat=38.451949, depth=0.000000, plastic_amount=19.031328, time=not_yet_set)
# P[1717](lon=-28.584979, lat=38.584980, depth=0.000000, plastic_amount=18.971003, time=not_yet_set)
# P[1718](lon=-28.584943, lat=38.518504, depth=0.000000, plastic_amount=19.001240, time=not_yet_set)
# P[1719](lon=-28.584908, lat=38.451978, depth=0.000000, plastic_amount=19.031528, time=not_yet_set)
# P[1720](lon=-28.501207, lat=38.585007, depth=0.000000, plastic_amount=5.595190, time=not_yet_set)
# P[1721](lon=-28.501122, lat=38.385426, depth=0.000000, plastic_amount=1.499220, time=not_yet_set)
# P[1722](lon=-28.417435, lat=38.585026, depth=0.000000, plastic_amount=2.980466, time=not_yet_set)
# P[1723](lon=-28.417369, lat=38.385445, depth=0.000000, plastic_amount=3.346122, time=not_yet_set)
# P[1724](lon=-28.333695, lat=38.717847, depth=0.000000, plastic_amount=0.711380, time=not_yet_set)
# P[1725](lon=-28.333647, lat=38.518563, depth=0.000000, plastic_amount=4.794407, time=not_yet_set)
# P[1726](lon=-28.333616, lat=38.385459, depth=0.000000, plastic_amount=9.369153, time=not_yet_set)
# P[1727](lon=-28.249920, lat=38.784187, depth=0.000000, plastic_amount=1.162964, time=not_yet_set)
# P[1728](lon=-28.249898, lat=38.651479, depth=0.000000, plastic_amount=6.917189, time=not_yet_set)
# P[1729](lon=-28.249880, lat=38.518575, depth=0.000000, plastic_amount=4.794455, time=not_yet_set)
# P[1730](lon=-28.249854, lat=38.318842, depth=0.000000, plastic_amount=9.384138, time=not_yet_set)
# P[1731](lon=-28.166125, lat=38.784191, depth=0.000000, plastic_amount=1.162969, time=not_yet_set)
# P[1732](lon=-28.166115, lat=38.585056, depth=0.000000, plastic_amount=3.322876, time=not_yet_set)
# P[1733](lon=-28.166113, lat=38.518579, depth=0.000000, plastic_amount=3.323683, time=not_yet_set)
# P[1734](lon=-28.166109, lat=38.385471, depth=0.000000, plastic_amount=3.298621, time=not_yet_set)
# P[1735](lon=-28.082354, lat=38.385470, depth=0.000000, plastic_amount=3.209015, time=not_yet_set)
# P[1736](lon=-28.082345, lat=38.518577, depth=0.000000, plastic_amount=1.751684, time=not_yet_set)
# P[1737](lon=-28.082341, lat=38.585055, depth=0.000000, plastic_amount=3.655324, time=not_yet_set)
# P[1738](lon=-28.082334, lat=38.717863, depth=0.000000, plastic_amount=3.312328, time=not_yet_set)
# P[1739](lon=-28.082321, lat=39.049012, depth=0.000000, plastic_amount=6.666481, time=not_yet_set)
# P[1740](lon=-27.998589, lat=38.452043, depth=0.000000, plastic_amount=3.203935, time=not_yet_set)
# P[1741](lon=-27.998568, lat=38.585049, depth=0.000000, plastic_amount=3.655348, time=not_yet_set)
# P[1742](lon=-27.998547, lat=38.717857, depth=0.000000, plastic_amount=1.565494, time=not_yet_set)
# P[1743](lon=-27.998507, lat=38.982876, depth=0.000000, plastic_amount=2.269847, time=not_yet_set)
# P[1744](lon=-27.998489, lat=39.115089, depth=0.000000, plastic_amount=6.655872, time=not_yet_set)
# P[1745](lon=-27.914810, lat=38.518560, depth=0.000000, plastic_amount=0.934169, time=not_yet_set)
# P[1746](lon=-27.914776, lat=38.651469, depth=0.000000, plastic_amount=2.131337, time=not_yet_set)
# P[1747](lon=-27.914675, lat=39.048998, depth=0.000000, plastic_amount=4.431919, time=not_yet_set)
# P[1748](lon=-27.831065, lat=38.452017, depth=0.000000, plastic_amount=0.525719, time=not_yet_set)
# P[1749](lon=-27.831018, lat=38.585025, depth=0.000000, plastic_amount=2.257951, time=not_yet_set)
# P[1750](lon=-27.747272, lat=38.518525, depth=0.000000, plastic_amount=2.261560, time=not_yet_set)
# P[1751](lon=-27.412080, lat=38.651295, depth=0.000000, plastic_amount=3.991005, time=not_yet_set)
# P[1752](lon=-27.412022, lat=38.717674, depth=0.000000, plastic_amount=3.984647, time=not_yet_set)
# P[1753](lon=-27.328360, lat=38.584823, depth=0.000000, plastic_amount=21.479435, time=not_yet_set)
# P[1754](lon=-27.328167, lat=38.783957, depth=0.000000, plastic_amount=3.730250, time=not_yet_set)
# P[1755](lon=-27.244297, lat=38.850184, depth=0.000000, plastic_amount=3.982281, time=not_yet_set)
# P[1756](lon=-27.160805, lat=38.584713, depth=0.000000, plastic_amount=43.067261, time=not_yet_set)
# P[1757](lon=-27.160492, lat=38.850124, depth=0.000000, plastic_amount=7.922418, time=not_yet_set)
# P[1758](lon=-27.076772, lat=38.783782, depth=0.000000, plastic_amount=12.917453, time=not_yet_set)
# P[1759](lon=-26.993248, lat=38.584583, depth=0.000000, plastic_amount=0.665024, time=not_yet_set)
# P[1760](lon=-26.993158, lat=38.651009, depth=0.000000, plastic_amount=12.958688, time=not_yet_set)
# P[1761](lon=-26.993066, lat=38.717386, depth=0.000000, plastic_amount=12.938049, time=not_yet_set)
# P[1762](lon=-25.905965, lat=37.849385, depth=0.000000, plastic_amount=4.977211, time=not_yet_set)
# P[1763](lon=-25.822418, lat=37.782247, depth=0.000000, plastic_amount=4.984988, time=not_yet_set)
# P[1764](lon=-25.822085, lat=37.916218, depth=0.000000, plastic_amount=4.969269, time=not_yet_set)
# P[1765](lon=-25.738880, lat=37.715056, depth=0.000000, plastic_amount=59.009087, time=not_yet_set)
# P[1766](lon=-25.655180, lat=37.714923, depth=0.000000, plastic_amount=92.143120, time=not_yet_set)
# P[1767](lon=-25.654827, lat=37.848988, depth=0.000000, plastic_amount=20.875534, time=not_yet_set)
# P[1768](lon=-25.654648, lat=37.915947, depth=0.000000, plastic_amount=16.276281, time=not_yet_set)
# P[1769](lon=-25.571480, lat=37.714785, depth=0.000000, plastic_amount=92.141243, time=not_yet_set)
# P[1770](lon=-25.571115, lat=37.848848, depth=0.000000, plastic_amount=23.323286, time=not_yet_set)
# P[1771](lon=-25.487778, lat=37.714641, depth=0.000000, plastic_amount=35.470978, time=not_yet_set)
# P[1772](lon=-25.487402, lat=37.848703, depth=0.000000, plastic_amount=23.322960, time=not_yet_set)
# P[1773](lon=-25.404268, lat=37.647391, depth=0.000000, plastic_amount=12.797956, time=not_yet_set)
# P[1774](lon=-25.403689, lat=37.848552, depth=0.000000, plastic_amount=48.013744, time=not_yet_set)
# P[1775](lon=-25.320375, lat=37.714342, depth=0.000000, plastic_amount=4.600795, time=not_yet_set)
# P[1776](lon=-25.319975, lat=37.848396, depth=0.000000, plastic_amount=48.012638, time=not_yet_set)
# P[1777](lon=-25.238968, lat=36.905695, depth=0.000000, plastic_amount=0.011565, time=not_yet_set)
# P[1778](lon=-25.236673, lat=37.714185, depth=0.000000, plastic_amount=5.932633, time=not_yet_set)
# P[1779](lon=-25.236051, lat=37.915187, depth=0.000000, plastic_amount=4.666979, time=not_yet_set)
# P[1780](lon=-25.155148, lat=36.973199, depth=0.000000, plastic_amount=6.264409, time=not_yet_set)
# P[1781](lon=-25.152972, lat=37.714023, depth=0.000000, plastic_amount=5.932554, time=not_yet_set)
# P[1782](lon=-25.152548, lat=37.848072, depth=0.000000, plastic_amount=7.003583, time=not_yet_set)
# P[1783](lon=-25.071507, lat=36.973050, depth=0.000000, plastic_amount=6.264225, time=not_yet_set)
# P[1784](lon=-25.069052, lat=37.780905, depth=0.000000, plastic_amount=7.014474, time=not_yet_set)
# P[1785](lon=-24.988061, lat=36.905254, depth=0.000000, plastic_amount=0.836327, time=not_yet_set)
# P[1786](lon=-18.081914, lat=27.691231, depth=0.000000, plastic_amount=1.918338, time=not_yet_set)
# P[1787](lon=-17.998625, lat=27.617270, depth=0.000000, plastic_amount=1.905686, time=not_yet_set)
# P[1788](lon=-17.998512, lat=27.765045, depth=0.000000, plastic_amount=1.915775, time=not_yet_set)
# P[1789](lon=-17.997587, lat=28.720915, depth=0.000000, plastic_amount=16.279186, time=not_yet_set)
# P[1790](lon=-17.997503, lat=28.794106, depth=0.000000, plastic_amount=2.061048, time=not_yet_set)
# P[1791](lon=-17.915225, lat=27.691131, depth=0.000000, plastic_amount=1.909346, time=not_yet_set)
# P[1792](lon=-17.914480, lat=28.500984, depth=0.000000, plastic_amount=18.147400, time=not_yet_set)
# P[1793](lon=-17.914319, lat=28.647604, depth=0.000000, plastic_amount=18.022327, time=not_yet_set)
# P[1794](lon=-17.914061, lat=28.867170, depth=0.000000, plastic_amount=1.162524, time=not_yet_set)
# P[1795](lon=-17.831208, lat=28.427534, depth=0.000000, plastic_amount=1.285566, time=not_yet_set)
# P[1796](lon=-17.831049, lat=28.574247, depth=0.000000, plastic_amount=18.122267, time=not_yet_set)
# P[1797](lon=-17.830707, lat=28.867091, depth=0.000000, plastic_amount=3.240784, time=not_yet_set)
# P[1798](lon=-17.747778, lat=28.500845, depth=0.000000, plastic_amount=2.681085, time=not_yet_set)
# P[1799](lon=-17.747614, lat=28.647458, depth=0.000000, plastic_amount=13.261635, time=not_yet_set)
# P[1800](lon=-17.747530, lat=28.720692, depth=0.000000, plastic_amount=13.243690, time=not_yet_set)
# P[1801](lon=-17.747443, lat=28.793876, depth=0.000000, plastic_amount=10.977147, time=not_yet_set)
# P[1802](lon=-17.331484, lat=28.059544, depth=0.000000, plastic_amount=5.531371, time=not_yet_set)
# P[1803](lon=-17.331413, lat=28.133155, depth=0.000000, plastic_amount=5.523993, time=not_yet_set)
# P[1804](lon=-17.331340, lat=28.206719, depth=0.000000, plastic_amount=4.632320, time=not_yet_set)
# P[1805](lon=-17.248206, lat=27.985824, depth=0.000000, plastic_amount=3.109088, time=not_yet_set)
# P[1806](lon=-17.247915, lat=28.280167, depth=0.000000, plastic_amount=1.075031, time=not_yet_set)
# P[1807](lon=-17.237484, lat=32.741524, depth=0.000000, plastic_amount=11.258040, time=not_yet_set)
# P[1808](lon=-17.237194, lat=32.811897, depth=0.000000, plastic_amount=11.241304, time=not_yet_set)
# P[1809](lon=-17.164859, lat=27.985763, depth=0.000000, plastic_amount=3.134489, time=not_yet_set)
# P[1810](lon=-17.164642, lat=28.206587, depth=0.000000, plastic_amount=3.121957, time=not_yet_set)
# P[1811](lon=-17.154344, lat=32.670860, depth=0.000000, plastic_amount=21.355732, time=not_yet_set)
# P[1812](lon=-17.153467, lat=32.881971, depth=0.000000, plastic_amount=3.946559, time=not_yet_set)
# P[1813](lon=-17.081442, lat=28.059355, depth=0.000000, plastic_amount=3.130229, time=not_yet_set)
# P[1814](lon=-17.081369, lat=28.132963, depth=0.000000, plastic_amount=3.126050, time=not_yet_set)
# P[1815](lon=-17.070919, lat=32.670620, depth=0.000000, plastic_amount=21.354383, time=not_yet_set)
# P[1816](lon=-17.070335, lat=32.811403, depth=0.000000, plastic_amount=8.003493, time=not_yet_set)
# P[1817](lon=-16.987495, lat=32.670380, depth=0.000000, plastic_amount=139.249390, time=not_yet_set)
# P[1818](lon=-16.986906, lat=32.811153, depth=0.000000, plastic_amount=4.578959, time=not_yet_set)
# P[1819](lon=-16.904359, lat=32.599673, depth=0.000000, plastic_amount=139.453278, time=not_yet_set)
# P[1820](lon=-16.903477, lat=32.810902, depth=0.000000, plastic_amount=6.949164, time=not_yet_set)
# P[1821](lon=-16.831325, lat=28.132765, depth=0.000000, plastic_amount=16.149832, time=not_yet_set)
# P[1822](lon=-16.831249, lat=28.206317, depth=0.000000, plastic_amount=15.448813, time=not_yet_set)
# P[1823](lon=-16.831170, lat=28.279822, depth=0.000000, plastic_amount=7.911853, time=not_yet_set)
# P[1824](lon=-16.831089, lat=28.353278, depth=0.000000, plastic_amount=7.901215, time=not_yet_set)
# P[1825](lon=-16.820937, lat=32.599432, depth=0.000000, plastic_amount=119.243881, time=not_yet_set)
# P[1826](lon=-16.820049, lat=32.810649, depth=0.000000, plastic_amount=22.717253, time=not_yet_set)
# P[1827](lon=-16.748053, lat=28.059099, depth=0.000000, plastic_amount=37.035538, time=not_yet_set)
# P[1828](lon=-16.747656, lat=28.426610, depth=0.000000, plastic_amount=9.635913, time=not_yet_set)
# P[1829](lon=-16.737221, lat=32.669642, depth=0.000000, plastic_amount=37.651752, time=not_yet_set)
# P[1830](lon=-16.736923, lat=32.740044, depth=0.000000, plastic_amount=27.665197, time=not_yet_set)
# P[1831](lon=-16.664705, lat=28.059033, depth=0.000000, plastic_amount=37.035168, time=not_yet_set)
# P[1832](lon=-16.664306, lat=28.426535, depth=0.000000, plastic_amount=26.185070, time=not_yet_set)
# P[1833](lon=-16.581358, lat=28.058967, depth=0.000000, plastic_amount=30.755283, time=not_yet_set)
# P[1834](lon=-16.580956, lat=28.426460, depth=0.000000, plastic_amount=137.111099, time=not_yet_set)
# P[1835](lon=-16.498011, lat=28.058901, depth=0.000000, plastic_amount=10.151289, time=not_yet_set)
# P[1836](lon=-16.497607, lat=28.426384, depth=0.000000, plastic_amount=137.107513, time=not_yet_set)
# P[1837](lon=-16.414587, lat=28.132426, depth=0.000000, plastic_amount=10.137503, time=not_yet_set)
# P[1838](lon=-16.414167, lat=28.499656, depth=0.000000, plastic_amount=58.469727, time=not_yet_set)
# P[1839](lon=-16.331159, lat=28.205898, depth=0.000000, plastic_amount=7.078480, time=not_yet_set)
# P[1840](lon=-16.331077, lat=28.279392, depth=0.000000, plastic_amount=18.420012, time=not_yet_set)
# P[1841](lon=-16.330993, lat=28.352836, depth=0.000000, plastic_amount=22.394953, time=not_yet_set)
# P[1842](lon=-16.330725, lat=28.572875, depth=0.000000, plastic_amount=58.387993, time=not_yet_set)
# P[1843](lon=-16.247557, lat=28.426154, depth=0.000000, plastic_amount=58.544827, time=not_yet_set)
# P[1844](lon=-16.247375, lat=28.572794, depth=0.000000, plastic_amount=57.502583, time=not_yet_set)
# P[1845](lon=-16.164116, lat=28.499417, depth=0.000000, plastic_amount=53.085934, time=not_yet_set)
# P[1846](lon=-15.831464, lat=27.837324, depth=0.000000, plastic_amount=5.278203, time=not_yet_set)
# P[1847](lon=-15.831390, lat=27.911050, depth=0.000000, plastic_amount=5.132202, time=not_yet_set)
# P[1848](lon=-15.831313, lat=27.984726, depth=0.000000, plastic_amount=2.761521, time=not_yet_set)
# P[1849](lon=-15.748191, lat=27.763487, depth=0.000000, plastic_amount=6.411530, time=not_yet_set)
# P[1850](lon=-15.747888, lat=28.058283, depth=0.000000, plastic_amount=9.256413, time=not_yet_set)
# P[1851](lon=-15.664917, lat=27.689606, depth=0.000000, plastic_amount=6.419931, time=not_yet_set)
# P[1852](lon=-15.664459, lat=28.131786, depth=0.000000, plastic_amount=15.367453, time=not_yet_set)
# P[1853](lon=-15.581572, lat=27.689544, depth=0.000000, plastic_amount=6.419749, time=not_yet_set)
# P[1854](lon=-15.581111, lat=28.131713, depth=0.000000, plastic_amount=64.940147, time=not_yet_set)
# P[1855](lon=-15.498156, lat=27.763296, depth=0.000000, plastic_amount=24.095594, time=not_yet_set)
# P[1856](lon=-15.497763, lat=28.131638, depth=0.000000, plastic_amount=145.441360, time=not_yet_set)
# P[1857](lon=-15.414811, lat=27.763232, depth=0.000000, plastic_amount=24.095116, time=not_yet_set)
# P[1858](lon=-15.414499, lat=28.057995, depth=0.000000, plastic_amount=145.635345, time=not_yet_set)
# P[1859](lon=-15.331390, lat=27.836928, depth=0.000000, plastic_amount=19.686586, time=not_yet_set)
# P[1860](lon=-15.331313, lat=27.910642, depth=0.000000, plastic_amount=39.374023, time=not_yet_set)
# P[1861](lon=-15.331234, lat=27.984307, depth=0.000000, plastic_amount=145.824814, time=not_yet_set)
# P[1862](lon=-14.497682, lat=28.057169, depth=0.000000, plastic_amount=2.042333, time=not_yet_set)
# P[1863](lon=-14.414422, lat=27.983497, depth=0.000000, plastic_amount=2.045039, time=not_yet_set)
# P[1864](lon=-14.414244, lat=28.130634, depth=0.000000, plastic_amount=2.039529, time=not_yet_set)
# P[1865](lon=-14.331075, lat=27.983420, depth=0.000000, plastic_amount=2.044971, time=not_yet_set)
# P[1866](lon=-14.330897, lat=28.130553, depth=0.000000, plastic_amount=2.039459, time=not_yet_set)
# P[1867](lon=-14.247641, lat=28.056932, depth=0.000000, plastic_amount=2.042157, time=not_yet_set)
# P[1868](lon=-14.247455, lat=28.203962, depth=0.000000, plastic_amount=2.036639, time=not_yet_set)
# P[1869](lon=-14.247359, lat=28.277403, depth=0.000000, plastic_amount=2.033877, time=not_yet_set)
# P[1870](lon=-14.164202, lat=28.130391, depth=0.000000, plastic_amount=2.039350, time=not_yet_set)
# P[1871](lon=-14.163911, lat=28.350705, depth=0.000000, plastic_amount=2.031062, time=not_yet_set)
# P[1872](lon=-14.163809, lat=28.424043, depth=0.000000, plastic_amount=2.028296, time=not_yet_set)
# P[1873](lon=-14.080854, lat=28.130309, depth=0.000000, plastic_amount=2.021399, time=not_yet_set)
# P[1874](lon=-14.080354, lat=28.497239, depth=0.000000, plastic_amount=4.844840, time=not_yet_set)
# P[1875](lon=-13.997411, lat=28.203709, depth=0.000000, plastic_amount=1.908679, time=not_yet_set)
# P[1876](lon=-13.996895, lat=28.570379, depth=0.000000, plastic_amount=4.838051, time=not_yet_set)
# P[1877](lon=-13.996783, lat=28.643563, depth=0.000000, plastic_amount=4.783830, time=not_yet_set)
# P[1878](lon=-13.996668, lat=28.716698, depth=0.000000, plastic_amount=2.480956, time=not_yet_set)
# P[1879](lon=-13.914063, lat=28.203624, depth=0.000000, plastic_amount=1.908632, time=not_yet_set)
# P[1880](lon=-13.913198, lat=28.789676, depth=0.000000, plastic_amount=2.651953, time=not_yet_set)
# P[1881](lon=-13.913076, lat=28.862707, depth=0.000000, plastic_amount=2.648294, time=not_yet_set)
# P[1882](lon=-13.830616, lat=28.276967, depth=0.000000, plastic_amount=1.638099, time=not_yet_set)
# P[1883](lon=-13.830515, lat=28.350346, depth=0.000000, plastic_amount=1.635868, time=not_yet_set)
# P[1884](lon=-13.830411, lat=28.423675, depth=0.000000, plastic_amount=4.850996, time=not_yet_set)
# P[1885](lon=-13.830304, lat=28.496954, depth=0.000000, plastic_amount=4.844365, time=not_yet_set)
# P[1886](lon=-13.829964, lat=28.716492, depth=0.000000, plastic_amount=2.480785, time=not_yet_set)
# P[1887](lon=-13.829845, lat=28.789571, depth=0.000000, plastic_amount=2.651843, time=not_yet_set)
# P[1888](lon=-13.829597, lat=28.935578, depth=0.000000, plastic_amount=2.644519, time=not_yet_set)
# P[1889](lon=-13.829468, lat=29.008505, depth=0.000000, plastic_amount=2.640852, time=not_yet_set)
# P[1890](lon=-13.746842, lat=28.570085, depth=0.000000, plastic_amount=4.837566, time=not_yet_set)
# P[1891](lon=-13.746728, lat=28.643262, depth=0.000000, plastic_amount=3.754635, time=not_yet_set)
# P[1892](lon=-13.746369, lat=28.862490, depth=0.000000, plastic_amount=10.494095, time=not_yet_set)
# P[1893](lon=-13.745981, lat=29.081265, depth=0.000000, plastic_amount=2.523024, time=not_yet_set)
# P[1894](lon=-13.663015, lat=28.862380, depth=0.000000, plastic_amount=14.660661, time=not_yet_set)
# P[1895](lon=-13.662625, lat=29.081148, depth=0.000000, plastic_amount=9.804443, time=not_yet_set)
# P[1896](lon=-13.579534, lat=28.935240, depth=0.000000, plastic_amount=92.705154, time=not_yet_set)
# P[1897](lon=-13.579132, lat=29.153849, depth=0.000000, plastic_amount=2.940148, time=not_yet_set)
# P[1898](lon=-13.578992, lat=29.226617, depth=0.000000, plastic_amount=2.936043, time=not_yet_set)
# P[1899](lon=-13.578848, lat=29.299334, depth=0.000000, plastic_amount=2.931937, time=not_yet_set)
# P[1900](lon=-13.496181, lat=28.935127, depth=0.000000, plastic_amount=92.701721, time=not_yet_set)
# P[1901](lon=-13.495341, lat=29.371868, depth=0.000000, plastic_amount=2.927711, time=not_yet_set)
# P[1902](lon=-13.412694, lat=29.007929, depth=0.000000, plastic_amount=2.948148, time=not_yet_set)
# P[1903](lon=-13.412558, lat=29.080792, depth=0.000000, plastic_amount=2.944046, time=not_yet_set)
# P[1904](lon=-13.412419, lat=29.153605, depth=0.000000, plastic_amount=2.052597, time=not_yet_set)
# P[1905](lon=-13.412277, lat=29.226367, depth=0.000000, plastic_amount=2.935833, time=not_yet_set)
# P[1906](lon=-13.412132, lat=29.299078, depth=0.000000, plastic_amount=2.931726, time=not_yet_set)
# P[1907](lon=-9.475950, lat=38.779997, depth=0.000000, plastic_amount=64.497726, time=not_yet_set)
# P[1908](lon=-9.474377, lat=38.844909, depth=0.000000, plastic_amount=16.299847, time=not_yet_set)
# P[1909](lon=-9.472787, lat=38.909766, depth=0.000000, plastic_amount=37.273453, time=not_yet_set)
# P[1910](lon=-9.393736, lat=38.713812, depth=0.000000, plastic_amount=180.261597, time=not_yet_set)
# P[1911](lon=-9.387384, lat=38.973303, depth=0.000000, plastic_amount=37.205170, time=not_yet_set)
# P[1912](lon=-9.385755, lat=39.038040, depth=0.000000, plastic_amount=37.143101, time=not_yet_set)
# P[1913](lon=-9.384109, lat=39.102723, depth=0.000000, plastic_amount=28.177124, time=not_yet_set)
# P[1914](lon=-9.382446, lat=39.167350, depth=0.000000, plastic_amount=28.130083, time=not_yet_set)
# P[1915](lon=-9.380767, lat=39.231922, depth=0.000000, plastic_amount=12.683787, time=not_yet_set)
# P[1916](lon=-9.379070, lat=39.296442, depth=0.000000, plastic_amount=77.900261, time=not_yet_set)
# P[1917](lon=-9.309967, lat=38.712589, depth=0.000000, plastic_amount=195.263535, time=not_yet_set)
# P[1918](lon=-9.293520, lat=39.359565, depth=0.000000, plastic_amount=8.789010, time=not_yet_set)
# P[1919](lon=-9.245601, lat=43.008438, depth=0.000000, plastic_amount=5.233185, time=not_yet_set)
# P[1920](lon=-9.242715, lat=43.069781, depth=0.000000, plastic_amount=2.990559, time=not_yet_set)
# P[1921](lon=-9.230829, lat=38.516238, depth=0.000000, plastic_amount=4.979945, time=not_yet_set)
# P[1922](lon=-9.229302, lat=38.581334, depth=0.000000, plastic_amount=70.666618, time=not_yet_set)
# P[1923](lon=-9.227758, lat=38.646375, depth=0.000000, plastic_amount=298.193115, time=not_yet_set)
# P[1924](lon=-9.226198, lat=38.711360, depth=0.000000, plastic_amount=297.694916, time=not_yet_set)
# P[1925](lon=-9.207939, lat=39.422601, depth=0.000000, plastic_amount=41.839989, time=not_yet_set)
# P[1926](lon=-9.206177, lat=39.486932, depth=0.000000, plastic_amount=10.615513, time=not_yet_set)
# P[1927](lon=-9.169781, lat=42.822029, depth=0.000000, plastic_amount=6.739063, time=not_yet_set)
# P[1928](lon=-9.166952, lat=42.883511, depth=0.000000, plastic_amount=6.727240, time=not_yet_set)
# P[1929](lon=-9.164100, lat=42.944942, depth=0.000000, plastic_amount=6.715961, time=not_yet_set)
# P[1930](lon=-9.155408, lat=43.128926, depth=0.000000, plastic_amount=2.985046, time=not_yet_set)
# P[1931](lon=-9.152464, lat=43.190152, depth=0.000000, plastic_amount=2.980277, time=not_yet_set)
# P[1932](lon=-9.148597, lat=38.449898, depth=0.000000, plastic_amount=25.059416, time=not_yet_set)
# P[1933](lon=-9.120542, lat=39.549818, depth=0.000000, plastic_amount=17.527861, time=not_yet_set)
# P[1934](lon=-9.118737, lat=39.614029, depth=0.000000, plastic_amount=17.498503, time=not_yet_set)
# P[1935](lon=-9.096582, lat=42.573555, depth=0.000000, plastic_amount=10.172538, time=not_yet_set)
# P[1936](lon=-9.093830, lat=42.635229, depth=0.000000, plastic_amount=10.155523, time=not_yet_set)
# P[1937](lon=-9.091056, lat=42.696852, depth=0.000000, plastic_amount=3.382684, time=not_yet_set)
# P[1938](lon=-9.088260, lat=42.758424, depth=0.000000, plastic_amount=3.377007, time=not_yet_set)
# P[1939](lon=-9.065077, lat=43.249143, depth=0.000000, plastic_amount=2.974257, time=not_yet_set)
# P[1940](lon=-9.064854, lat=38.448706, depth=0.000000, plastic_amount=25.057657, time=not_yet_set)
# P[1941](lon=-9.033044, lat=39.676764, depth=0.000000, plastic_amount=17.466663, time=not_yet_set)
# P[1942](lon=-9.031197, lat=39.740854, depth=0.000000, plastic_amount=5.509546, time=not_yet_set)
# P[1943](lon=-9.029332, lat=39.804890, depth=0.000000, plastic_amount=1.345793, time=not_yet_set)
# P[1944](lon=-9.015030, lat=42.509809, depth=0.000000, plastic_amount=13.658615, time=not_yet_set)
# P[1945](lon=-9.009665, lat=37.067305, depth=0.000000, plastic_amount=4.086171, time=not_yet_set)
# P[1946](lon=-8.981112, lat=38.447509, depth=0.000000, plastic_amount=18.277529, time=not_yet_set)
# P[1947](lon=-8.980656, lat=43.246947, depth=0.000000, plastic_amount=2.388263, time=not_yet_set)
# P[1948](lon=-8.943557, lat=39.867405, depth=0.000000, plastic_amount=6.385518, time=not_yet_set)
# P[1949](lon=-8.941648, lat=39.931319, depth=0.000000, plastic_amount=6.374801, time=not_yet_set)
# P[1950](lon=-8.939720, lat=39.995180, depth=0.000000, plastic_amount=5.522843, time=not_yet_set)
# P[1951](lon=-8.937774, lat=40.058986, depth=0.000000, plastic_amount=14.503007, time=not_yet_set)
# P[1952](lon=-8.933479, lat=42.446029, depth=0.000000, plastic_amount=20.862326, time=not_yet_set)
# P[1953](lon=-8.927998, lat=42.569477, depth=0.000000, plastic_amount=20.790674, time=not_yet_set)
# P[1954](lon=-8.927239, lat=37.000014, depth=0.000000, plastic_amount=4.092313, time=not_yet_set)
# P[1955](lon=-8.925224, lat=42.631122, depth=0.000000, plastic_amount=20.757370, time=not_yet_set)
# P[1956](lon=-8.924820, lat=37.132605, depth=0.000000, plastic_amount=1.190489, time=not_yet_set)
# P[1957](lon=-8.923589, lat=37.198817, depth=0.000000, plastic_amount=0.433064, time=not_yet_set)
# P[1958](lon=-8.897370, lat=38.446304, depth=0.000000, plastic_amount=90.086166, time=not_yet_set)
# P[1959](lon=-8.893212, lat=43.305823, depth=0.000000, plastic_amount=2.539120, time=not_yet_set)
# P[1960](lon=-8.877911, lat=41.761467, depth=0.000000, plastic_amount=89.948723, time=not_yet_set)
# P[1961](lon=-8.875410, lat=41.823779, depth=0.000000, plastic_amount=32.312927, time=not_yet_set)
# P[1962](lon=-8.872887, lat=41.886038, depth=0.000000, plastic_amount=32.258751, time=not_yet_set)
# P[1963](lon=-8.870343, lat=41.948243, depth=0.000000, plastic_amount=32.204296, time=not_yet_set)
# P[1964](lon=-8.867777, lat=42.010396, depth=0.000000, plastic_amount=20.005095, time=not_yet_set)
# P[1965](lon=-8.865190, lat=42.072498, depth=0.000000, plastic_amount=28.897388, time=not_yet_set)
# P[1966](lon=-8.862582, lat=42.134546, depth=0.000000, plastic_amount=140.742477, time=not_yet_set)
# P[1967](lon=-8.854626, lat=42.320378, depth=0.000000, plastic_amount=140.033661, time=not_yet_set)
# P[1968](lon=-8.851930, lat=42.382218, depth=0.000000, plastic_amount=36.113186, time=not_yet_set)
# P[1969](lon=-8.851887, lat=40.121214, depth=0.000000, plastic_amount=107.854202, time=not_yet_set)
# P[1970](lon=-8.849896, lat=40.184898, depth=0.000000, plastic_amount=107.672981, time=not_yet_set)
# P[1971](lon=-8.847887, lat=40.248531, depth=0.000000, plastic_amount=6.592861, time=not_yet_set)
# P[1972](lon=-8.846471, lat=42.505741, depth=0.000000, plastic_amount=20.820208, time=not_yet_set)
# P[1973](lon=-8.845858, lat=40.312108, depth=0.000000, plastic_amount=3.469177, time=not_yet_set)
# P[1974](lon=-8.843810, lat=40.375629, depth=0.000000, plastic_amount=5.557026, time=not_yet_set)
# P[1975](lon=-8.843709, lat=42.567424, depth=0.000000, plastic_amount=22.581787, time=not_yet_set)
# P[1976](lon=-8.843616, lat=36.999051, depth=0.000000, plastic_amount=3.064797, time=not_yet_set)
# P[1977](lon=-8.841743, lat=40.439099, depth=0.000000, plastic_amount=6.813107, time=not_yet_set)
# P[1978](lon=-8.840924, lat=42.629054, depth=0.000000, plastic_amount=22.543978, time=not_yet_set)
# P[1979](lon=-8.839658, lat=40.502515, depth=0.000000, plastic_amount=6.801649, time=not_yet_set)
# P[1980](lon=-8.838702, lat=37.263969, depth=0.000000, plastic_amount=2.385535, time=not_yet_set)
# P[1981](lon=-8.837438, lat=37.330060, depth=0.000000, plastic_amount=2.381449, time=not_yet_set)
# P[1982](lon=-8.836159, lat=37.396094, depth=0.000000, plastic_amount=2.302098, time=not_yet_set)
# P[1983](lon=-8.834865, lat=37.462073, depth=0.000000, plastic_amount=2.298419, time=not_yet_set)
# P[1984](lon=-8.833557, lat=37.527997, depth=0.000000, plastic_amount=2.170409, time=not_yet_set)
# P[1985](lon=-8.832233, lat=37.593865, depth=0.000000, plastic_amount=1.652255, time=not_yet_set)
# P[1986](lon=-8.830895, lat=37.659675, depth=0.000000, plastic_amount=7.055398, time=not_yet_set)
# P[1987](lon=-8.829541, lat=37.725431, depth=0.000000, plastic_amount=7.043263, time=not_yet_set)
# P[1988](lon=-8.828173, lat=37.791132, depth=0.000000, plastic_amount=13.878572, time=not_yet_set)
# P[1989](lon=-8.826789, lat=37.856778, depth=0.000000, plastic_amount=29.858471, time=not_yet_set)
# P[1990](lon=-8.825389, lat=37.922369, depth=0.000000, plastic_amount=32.400169, time=not_yet_set)
# P[1991](lon=-8.823974, lat=37.987905, depth=0.000000, plastic_amount=32.346291, time=not_yet_set)
# P[1992](lon=-8.822544, lat=38.053385, depth=0.000000, plastic_amount=32.294449, time=not_yet_set)
# P[1993](lon=-8.821098, lat=38.118809, depth=0.000000, plastic_amount=13.758886, time=not_yet_set)
# P[1994](lon=-8.819636, lat=38.184177, depth=0.000000, plastic_amount=0.947809, time=not_yet_set)
# P[1995](lon=-8.818158, lat=38.249490, depth=0.000000, plastic_amount=1.053837, time=not_yet_set)
# P[1996](lon=-8.816664, lat=38.314748, depth=0.000000, plastic_amount=1.592719, time=not_yet_set)
# P[1997](lon=-8.815155, lat=38.379950, depth=0.000000, plastic_amount=1.590064, time=not_yet_set)
# P[1998](lon=-8.805999, lat=41.447317, depth=0.000000, plastic_amount=72.304253, time=not_yet_set)
# P[1999](lon=-8.805722, lat=43.364607, depth=0.000000, plastic_amount=3.456800, time=not_yet_set)
# P[2000](lon=-8.803593, lat=41.509880, depth=0.000000, plastic_amount=32.256660, time=not_yet_set)
# P[2001](lon=-8.801166, lat=41.572389, depth=0.000000, plastic_amount=32.202366, time=not_yet_set)
# P[2002](lon=-8.798718, lat=41.634842, depth=0.000000, plastic_amount=90.234238, time=not_yet_set)
# P[2003](lon=-8.796249, lat=41.697243, depth=0.000000, plastic_amount=90.082367, time=not_yet_set)
# P[2004](lon=-8.775728, lat=42.194569, depth=0.000000, plastic_amount=140.477158, time=not_yet_set)
# P[2005](lon=-8.773066, lat=42.256496, depth=0.000000, plastic_amount=140.240860, time=not_yet_set)
# P[2006](lon=-8.758782, lat=37.064387, depth=0.000000, plastic_amount=36.786030, time=not_yet_set)
# P[2007](lon=-8.753575, lat=40.564253, depth=0.000000, plastic_amount=17.373127, time=not_yet_set)
# P[2008](lon=-8.751442, lat=40.627548, depth=0.000000, plastic_amount=17.342642, time=not_yet_set)
# P[2009](lon=-8.749289, lat=40.690789, depth=0.000000, plastic_amount=17.313465, time=not_yet_set)
# P[2010](lon=-8.747117, lat=40.753977, depth=0.000000, plastic_amount=10.796503, time=not_yet_set)
# P[2011](lon=-8.729020, lat=41.257545, depth=0.000000, plastic_amount=112.444397, time=not_yet_set)
# P[2012](lon=-8.726666, lat=41.320251, depth=0.000000, plastic_amount=154.157471, time=not_yet_set)
# P[2013](lon=-8.724292, lat=41.382905, depth=0.000000, plastic_amount=153.886353, time=not_yet_set)
# P[2014](lon=-8.721284, lat=43.362354, depth=0.000000, plastic_amount=4.352787, time=not_yet_set)
# P[2015](lon=-8.675155, lat=37.063404, depth=0.000000, plastic_amount=36.780449, time=not_yet_set)
# P[2016](lon=-8.660915, lat=40.815428, depth=0.000000, plastic_amount=22.201801, time=not_yet_set)
# P[2017](lon=-8.658694, lat=40.878494, depth=0.000000, plastic_amount=22.164415, time=not_yet_set)
# P[2018](lon=-8.656453, lat=40.941505, depth=0.000000, plastic_amount=79.437447, time=not_yet_set)
# P[2019](lon=-8.654193, lat=41.004464, depth=0.000000, plastic_amount=79.303246, time=not_yet_set)
# P[2020](lon=-8.651912, lat=41.067370, depth=0.000000, plastic_amount=166.508972, time=not_yet_set)
# P[2021](lon=-8.649611, lat=41.130223, depth=0.000000, plastic_amount=166.229385, time=not_yet_set)
# P[2022](lon=-8.647289, lat=41.193022, depth=0.000000, plastic_amount=165.948502, time=not_yet_set)
# P[2023](lon=-8.636846, lat=43.360091, depth=0.000000, plastic_amount=8.525176, time=not_yet_set)
# P[2024](lon=-8.591529, lat=37.062418, depth=0.000000, plastic_amount=11.330364, time=not_yet_set)
# P[2025](lon=-8.552411, lat=43.357818, depth=0.000000, plastic_amount=22.901791, time=not_yet_set)
# P[2026](lon=-8.507903, lat=37.061429, depth=0.000000, plastic_amount=11.327637, time=not_yet_set)
# P[2027](lon=-8.467978, lat=43.355537, depth=0.000000, plastic_amount=160.943039, time=not_yet_set)
# P[2028](lon=-8.424277, lat=37.060436, depth=0.000000, plastic_amount=17.160372, time=not_yet_set)
# P[2029](lon=-8.380402, lat=43.414131, depth=0.000000, plastic_amount=160.644241, time=not_yet_set)
# P[2030](lon=-8.340653, lat=37.059440, depth=0.000000, plastic_amount=17.159250, time=not_yet_set)
# P[2031](lon=-8.295960, lat=43.411814, depth=0.000000, plastic_amount=21.933098, time=not_yet_set)
# P[2032](lon=-8.292778, lat=43.472634, depth=0.000000, plastic_amount=21.896271, time=not_yet_set)
# P[2033](lon=-8.289571, lat=43.533405, depth=0.000000, plastic_amount=21.859665, time=not_yet_set)
# P[2034](lon=-8.257028, lat=37.058440, depth=0.000000, plastic_amount=35.866936, time=not_yet_set)
# P[2035](lon=-8.201864, lat=43.591750, depth=0.000000, plastic_amount=21.817970, time=not_yet_set)
# P[2036](lon=-8.173405, lat=37.057434, depth=0.000000, plastic_amount=74.557098, time=not_yet_set)
# P[2037](lon=-8.114109, lat=43.650002, depth=0.000000, plastic_amount=2.167086, time=not_yet_set)
# P[2038](lon=-8.089781, lat=37.056426, depth=0.000000, plastic_amount=74.552162, time=not_yet_set)
# P[2039](lon=-8.026306, lat=43.708160, depth=0.000000, plastic_amount=2.162840, time=not_yet_set)
# P[2040](lon=-8.007412, lat=36.989207, depth=0.000000, plastic_amount=71.296646, time=not_yet_set)
# P[2041](lon=-7.938455, lat=43.766227, depth=0.000000, plastic_amount=2.330184, time=not_yet_set)
# P[2042](lon=-7.923794, lat=36.988200, depth=0.000000, plastic_amount=71.285675, time=not_yet_set)
# P[2043](lon=-7.853950, lat=43.763768, depth=0.000000, plastic_amount=2.329751, time=not_yet_set)
# P[2044](lon=-7.840177, lat=36.987189, depth=0.000000, plastic_amount=89.567978, time=not_yet_set)
# P[2045](lon=-7.769447, lat=43.761299, depth=0.000000, plastic_amount=0.802239, time=not_yet_set)
# P[2046](lon=-7.755292, lat=37.052348, depth=0.000000, plastic_amount=18.554777, time=not_yet_set)
# P[2047](lon=-7.684946, lat=43.758820, depth=0.000000, plastic_amount=3.266561, time=not_yet_set)
# P[2048](lon=-7.671671, lat=37.051319, depth=0.000000, plastic_amount=31.354889, time=not_yet_set)
# P[2049](lon=-7.600448, lat=43.756331, depth=0.000000, plastic_amount=3.265944, time=not_yet_set)
# P[2050](lon=-7.586758, lat=37.116377, depth=0.000000, plastic_amount=31.298634, time=not_yet_set)
# P[2051](lon=-7.515952, lat=43.753831, depth=0.000000, plastic_amount=2.142704, time=not_yet_set)
# P[2052](lon=-7.501820, lat=37.181355, depth=0.000000, plastic_amount=61.315918, time=not_yet_set)
# P[2053](lon=-7.431458, lat=43.751321, depth=0.000000, plastic_amount=29.489826, time=not_yet_set)
# P[2054](lon=-7.418191, lat=37.180292, depth=0.000000, plastic_amount=61.306072, time=not_yet_set)
# P[2055](lon=-7.350410, lat=43.688412, depth=0.000000, plastic_amount=29.536499, time=not_yet_set)
# P[2056](lon=-7.334563, lat=37.179225, depth=0.000000, plastic_amount=28.402782, time=not_yet_set)
# P[2057](lon=-7.269363, lat=43.625475, depth=0.000000, plastic_amount=2.461844, time=not_yet_set)
# P[2058](lon=-7.250935, lat=37.178152, depth=0.000000, plastic_amount=28.397085, time=not_yet_set)
# P[2059](lon=-7.184900, lat=43.622970, depth=0.000000, plastic_amount=2.326600, time=not_yet_set)
# P[2060](lon=-7.167308, lat=37.177075, depth=0.000000, plastic_amount=20.611715, time=not_yet_set)
# P[2061](lon=-7.100440, lat=43.620454, depth=0.000000, plastic_amount=2.326151, time=not_yet_set)
# P[2062](lon=-7.083681, lat=37.175997, depth=0.000000, plastic_amount=29.353296, time=not_yet_set)
# P[2063](lon=-7.015982, lat=43.617927, depth=0.000000, plastic_amount=2.325444, time=not_yet_set)
# P[2064](lon=-7.000054, lat=37.174913, depth=0.000000, plastic_amount=69.228615, time=not_yet_set)
# P[2065](lon=-6.931527, lat=43.615391, depth=0.000000, plastic_amount=1.498882, time=not_yet_set)
# P[2066](lon=-6.916429, lat=37.173823, depth=0.000000, plastic_amount=71.191383, time=not_yet_set)
# P[2067](lon=-6.847073, lat=43.612845, depth=0.000000, plastic_amount=1.498588, time=not_yet_set)
# P[2068](lon=-6.834153, lat=37.106800, depth=0.000000, plastic_amount=36.425755, time=not_yet_set)
# P[2069](lon=-6.762622, lat=43.610290, depth=0.000000, plastic_amount=3.544736, time=not_yet_set)
# P[2070](lon=-6.750533, lat=37.105716, depth=0.000000, plastic_amount=5.678827, time=not_yet_set)
# P[2071](lon=-6.678174, lat=43.607726, depth=0.000000, plastic_amount=3.543876, time=not_yet_set)
# P[2072](lon=-6.668257, lat=37.038662, depth=0.000000, plastic_amount=1.706223, time=not_yet_set)
# P[2073](lon=-6.593728, lat=43.605152, depth=0.000000, plastic_amount=3.516209, time=not_yet_set)
# P[2074](lon=-6.585975, lat=36.971571, depth=0.000000, plastic_amount=0.832472, time=not_yet_set)
# P[2075](lon=-6.509284, lat=43.602567, depth=0.000000, plastic_amount=0.931199, time=not_yet_set)
# P[2076](lon=-6.502365, lat=36.970498, depth=0.000000, plastic_amount=0.832302, time=not_yet_set)
# P[2077](lon=-6.424842, lat=43.599972, depth=0.000000, plastic_amount=1.017774, time=not_yet_set)
# P[2078](lon=-6.423966, lat=36.704893, depth=0.000000, plastic_amount=18.268690, time=not_yet_set)
# P[2079](lon=-6.422687, lat=36.771112, depth=0.000000, plastic_amount=18.238098, time=not_yet_set)
# P[2080](lon=-6.421392, lat=36.837273, depth=0.000000, plastic_amount=15.640954, time=not_yet_set)
# P[2081](lon=-6.420082, lat=36.903375, depth=0.000000, plastic_amount=5.489246, time=not_yet_set)
# P[2082](lon=-6.341644, lat=36.637593, depth=0.000000, plastic_amount=59.076881, time=not_yet_set)
# P[2083](lon=-6.340403, lat=43.597367, depth=0.000000, plastic_amount=1.398737, time=not_yet_set)
# P[2084](lon=-6.261784, lat=36.437463, depth=0.000000, plastic_amount=321.205658, time=not_yet_set)
# P[2085](lon=-6.260557, lat=36.503890, depth=0.000000, plastic_amount=320.667603, time=not_yet_set)
# P[2086](lon=-6.259315, lat=36.570259, depth=0.000000, plastic_amount=320.131012, time=not_yet_set)
# P[2087](lon=-6.255967, lat=43.594753, depth=0.000000, plastic_amount=1.639225, time=not_yet_set)
# P[2088](lon=-6.180628, lat=36.303466, depth=0.000000, plastic_amount=12.688259, time=not_yet_set)
# P[2089](lon=-6.179426, lat=36.369997, depth=0.000000, plastic_amount=150.606522, time=not_yet_set)
# P[2090](lon=-6.171532, lat=43.592130, depth=0.000000, plastic_amount=6.069303, time=not_yet_set)
# P[2091](lon=-6.098253, lat=36.235912, depth=0.000000, plastic_amount=7.990687, time=not_yet_set)
# P[2092](lon=-6.087100, lat=43.589497, depth=0.000000, plastic_amount=10.452750, time=not_yet_set)
# P[2093](lon=-6.015873, lat=36.168319, depth=0.000000, plastic_amount=5.118302, time=not_yet_set)
# P[2094](lon=-6.002671, lat=43.586855, depth=0.000000, plastic_amount=62.583305, time=not_yet_set)
# P[2095](lon=-5.940195, lat=35.699438, depth=0.000000, plastic_amount=87.207603, time=not_yet_set)
# P[2096](lon=-5.939112, lat=35.766459, depth=0.000000, plastic_amount=87.062523, time=not_yet_set)
# P[2097](lon=-5.932316, lat=36.167362, depth=0.000000, plastic_amount=5.117496, time=not_yet_set)
# P[2098](lon=-5.918244, lat=43.584203, depth=0.000000, plastic_amount=62.567493, time=not_yet_set)
# P[2099](lon=-5.854478, lat=35.832513, depth=0.000000, plastic_amount=255.801743, time=not_yet_set)
# P[2100](lon=-5.849933, lat=36.099737, depth=0.000000, plastic_amount=5.125400, time=not_yet_set)
# P[2101](lon=-5.830184, lat=43.641678, depth=0.000000, plastic_amount=57.709362, time=not_yet_set)
# P[2102](lon=-5.770941, lat=35.831602, depth=0.000000, plastic_amount=255.738907, time=not_yet_set)
# P[2103](lon=-5.766382, lat=36.098783, depth=0.000000, plastic_amount=1.595985, time=not_yet_set)
# P[2104](lon=-5.749397, lat=43.578871, depth=0.000000, plastic_amount=38.416767, time=not_yet_set)
# P[2105](lon=-5.686283, lat=35.897562, depth=0.000000, plastic_amount=4.288988, time=not_yet_set)
# P[2106](lon=-5.683996, lat=36.031128, depth=0.000000, plastic_amount=1.417760, time=not_yet_set)
# P[2107](lon=-5.664977, lat=43.576190, depth=0.000000, plastic_amount=38.406933, time=not_yet_set)
# P[2108](lon=-5.602743, lat=35.896634, depth=0.000000, plastic_amount=4.288440, time=not_yet_set)
# P[2109](lon=-5.600449, lat=36.030177, depth=0.000000, plastic_amount=33.886604, time=not_yet_set)
# P[2110](lon=-5.580560, lat=43.573500, depth=0.000000, plastic_amount=38.398872, time=not_yet_set)
# P[2111](lon=-5.519204, lat=35.895702, depth=0.000000, plastic_amount=3.644381, time=not_yet_set)
# P[2112](lon=-5.516903, lat=36.029225, depth=0.000000, plastic_amount=43.258312, time=not_yet_set)
# P[2113](lon=-5.496145, lat=43.570801, depth=0.000000, plastic_amount=9.133891, time=not_yet_set)
# P[2114](lon=-5.435666, lat=35.894768, depth=0.000000, plastic_amount=131.711578, time=not_yet_set)
# P[2115](lon=-5.432180, lat=36.094933, depth=0.000000, plastic_amount=142.818604, time=not_yet_set)
# P[2116](lon=-5.430988, lat=36.161537, depth=0.000000, plastic_amount=142.579071, time=not_yet_set)
# P[2117](lon=-5.408040, lat=43.628139, depth=0.000000, plastic_amount=1.376907, time=not_yet_set)
# P[2118](lon=-5.354385, lat=35.760121, depth=0.000000, plastic_amount=65.717239, time=not_yet_set)
# P[2119](lon=-5.353263, lat=35.827005, depth=0.000000, plastic_amount=131.923340, time=not_yet_set)
# P[2120](lon=-5.346225, lat=36.227087, depth=0.000000, plastic_amount=134.095551, time=not_yet_set)
# P[2121](lon=-5.327323, lat=43.565372, depth=0.000000, plastic_amount=1.378954, time=not_yet_set)
# P[2122](lon=-5.271965, lat=35.692269, depth=0.000000, plastic_amount=62.656384, time=not_yet_set)
# P[2123](lon=-5.261439, lat=36.292550, depth=0.000000, plastic_amount=12.675638, time=not_yet_set)
# P[2124](lon=-5.260195, lat=36.358955, depth=0.000000, plastic_amount=15.530930, time=not_yet_set)
# P[2125](lon=-5.242916, lat=43.562643, depth=0.000000, plastic_amount=1.076581, time=not_yet_set)
# P[2126](lon=-5.175367, lat=36.424267, depth=0.000000, plastic_amount=15.502187, time=not_yet_set)
# P[2127](lon=-5.162212, lat=43.499859, depth=0.000000, plastic_amount=1.851810, time=not_yet_set)
# P[2128](lon=-5.090516, lat=36.489489, depth=0.000000, plastic_amount=17.101709, time=not_yet_set)
# P[2129](lon=-5.077821, lat=43.497128, depth=0.000000, plastic_amount=1.851412, time=not_yet_set)
# P[2130](lon=-5.006946, lat=36.488435, depth=0.000000, plastic_amount=38.282013, time=not_yet_set)
# P[2131](lon=-4.993433, lat=43.494389, depth=0.000000, plastic_amount=1.850791, time=not_yet_set)
# P[2132](lon=-4.923375, lat=36.487377, depth=0.000000, plastic_amount=38.275509, time=not_yet_set)
# P[2133](lon=-4.909047, lat=43.491642, depth=0.000000, plastic_amount=1.495585, time=not_yet_set)
# P[2134](lon=-4.839806, lat=36.486316, depth=0.000000, plastic_amount=38.270157, time=not_yet_set)
# P[2135](lon=-4.824664, lat=43.488885, depth=0.000000, plastic_amount=1.324214, time=not_yet_set)
# P[2136](lon=-4.756237, lat=36.485251, depth=0.000000, plastic_amount=38.262096, time=not_yet_set)
# P[2137](lon=-4.740284, lat=43.486118, depth=0.000000, plastic_amount=1.323765, time=not_yet_set)
# P[2138](lon=-4.671349, lat=36.550326, depth=0.000000, plastic_amount=231.687286, time=not_yet_set)
# P[2139](lon=-4.659646, lat=43.423351, depth=0.000000, plastic_amount=1.325669, time=not_yet_set)
# P[2140](lon=-4.587777, lat=36.549240, depth=0.000000, plastic_amount=231.654434, time=not_yet_set)
# P[2141](lon=-4.575282, lat=43.420584, depth=0.000000, plastic_amount=1.350986, time=not_yet_set)
# P[2142](lon=-4.502862, lat=36.614212, depth=0.000000, plastic_amount=110.363098, time=not_yet_set)
# P[2143](lon=-4.490920, lat=43.417807, depth=0.000000, plastic_amount=1.934638, time=not_yet_set)
# P[2144](lon=-4.417924, lat=36.679096, depth=0.000000, plastic_amount=110.155884, time=not_yet_set)
# P[2145](lon=-4.406561, lat=43.415020, depth=0.000000, plastic_amount=2.767563, time=not_yet_set)
# P[2146](lon=-4.334345, lat=36.677976, depth=0.000000, plastic_amount=46.702797, time=not_yet_set)
# P[2147](lon=-4.322205, lat=43.412225, depth=0.000000, plastic_amount=2.767234, time=not_yet_set)
# P[2148](lon=-4.250767, lat=36.676853, depth=0.000000, plastic_amount=45.339363, time=not_yet_set)
# P[2149](lon=-4.237851, lat=43.409421, depth=0.000000, plastic_amount=2.879527, time=not_yet_set)
# P[2150](lon=-4.165798, lat=36.741617, depth=0.000000, plastic_amount=28.643541, time=not_yet_set)
# P[2151](lon=-4.153500, lat=43.406609, depth=0.000000, plastic_amount=6.547352, time=not_yet_set)
# P[2152](lon=-4.082216, lat=36.740475, depth=0.000000, plastic_amount=18.909111, time=not_yet_set)
# P[2153](lon=-4.065333, lat=43.463646, depth=0.000000, plastic_amount=8.795253, time=not_yet_set)
# P[2154](lon=-3.998636, lat=36.739328, depth=0.000000, plastic_amount=18.904886, time=not_yet_set)
# P[2155](lon=-3.980976, lat=43.460794, depth=0.000000, plastic_amount=8.792160, time=not_yet_set)
# P[2156](lon=-3.915056, lat=36.738176, depth=0.000000, plastic_amount=10.746851, time=not_yet_set)
# P[2157](lon=-3.892753, lat=43.517702, depth=0.000000, plastic_amount=127.228127, time=not_yet_set)
# P[2158](lon=-3.831477, lat=36.737023, depth=0.000000, plastic_amount=9.688128, time=not_yet_set)
# P[2159](lon=-3.808390, lat=43.514813, depth=0.000000, plastic_amount=127.198990, time=not_yet_set)
# P[2160](lon=-3.747898, lat=36.735868, depth=0.000000, plastic_amount=10.127910, time=not_yet_set)
# P[2161](lon=-3.724030, lat=43.511915, depth=0.000000, plastic_amount=127.153587, time=not_yet_set)
# P[2162](lon=-3.664320, lat=36.734708, depth=0.000000, plastic_amount=11.296231, time=not_yet_set)
# P[2163](lon=-3.639673, lat=43.509010, depth=0.000000, plastic_amount=3.227166, time=not_yet_set)
# P[2164](lon=-3.580743, lat=36.733543, depth=0.000000, plastic_amount=17.352417, time=not_yet_set)
# P[2165](lon=-3.555318, lat=43.506092, depth=0.000000, plastic_amount=18.233477, time=not_yet_set)
# P[2166](lon=-3.497166, lat=36.732374, depth=0.000000, plastic_amount=17.348463, time=not_yet_set)
# P[2167](lon=-3.474890, lat=43.443494, depth=0.000000, plastic_amount=29.325157, time=not_yet_set)
# P[2168](lon=-3.413589, lat=36.731202, depth=0.000000, plastic_amount=17.345243, time=not_yet_set)
# P[2169](lon=-3.390552, lat=43.440579, depth=0.000000, plastic_amount=29.316786, time=not_yet_set)
# P[2170](lon=-3.330014, lat=36.730029, depth=0.000000, plastic_amount=7.320355, time=not_yet_set)
# P[2171](lon=-3.306216, lat=43.437654, depth=0.000000, plastic_amount=8.724008, time=not_yet_set)
# P[2172](lon=-3.246438, lat=36.728851, depth=0.000000, plastic_amount=3.272225, time=not_yet_set)
# P[2173](lon=-3.225810, lat=43.375052, depth=0.000000, plastic_amount=9.070728, time=not_yet_set)
# P[2174](lon=-3.162864, lat=36.727669, depth=0.000000, plastic_amount=8.988304, time=not_yet_set)
# P[2175](lon=-3.141490, lat=43.372128, depth=0.000000, plastic_amount=69.898750, time=not_yet_set)
# P[2176](lon=-3.079290, lat=36.726483, depth=0.000000, plastic_amount=8.986922, time=not_yet_set)
# P[2177](lon=-3.057174, lat=43.369195, depth=0.000000, plastic_amount=161.494019, time=not_yet_set)
# P[2178](lon=-2.995716, lat=36.725295, depth=0.000000, plastic_amount=8.984833, time=not_yet_set)
# P[2179](lon=-2.968902, lat=43.425863, depth=0.000000, plastic_amount=161.139404, time=not_yet_set)
# P[2180](lon=-2.912143, lat=36.724102, depth=0.000000, plastic_amount=11.967458, time=not_yet_set)
# P[2181](lon=-2.880582, lat=43.482429, depth=0.000000, plastic_amount=13.169972, time=not_yet_set)
# P[2182](lon=-2.828571, lat=36.722906, depth=0.000000, plastic_amount=11.965603, time=not_yet_set)
# P[2183](lon=-2.796252, lat=43.479430, depth=0.000000, plastic_amount=12.525850, time=not_yet_set)
# P[2184](lon=-2.744999, lat=36.721706, depth=0.000000, plastic_amount=11.962794, time=not_yet_set)
# P[2185](lon=-2.715946, lat=43.416925, depth=0.000000, plastic_amount=12.542764, time=not_yet_set)
# P[2186](lon=-2.661428, lat=36.720503, depth=0.000000, plastic_amount=48.440834, time=not_yet_set)
# P[2187](lon=-2.631632, lat=43.413927, depth=0.000000, plastic_amount=4.596530, time=not_yet_set)
# P[2188](lon=-2.576373, lat=36.784878, depth=0.000000, plastic_amount=48.353226, time=not_yet_set)
# P[2189](lon=-2.547322, lat=43.410921, depth=0.000000, plastic_amount=31.108219, time=not_yet_set)
# P[2190](lon=-2.492799, lat=36.783657, depth=0.000000, plastic_amount=36.166897, time=not_yet_set)
# P[2191](lon=-2.467035, lat=43.348415, depth=0.000000, plastic_amount=31.150488, time=not_yet_set)
# P[2192](lon=-2.409226, lat=36.782433, depth=0.000000, plastic_amount=21.088671, time=not_yet_set)
# ...
# P[4205](lon=26.767555, lat=37.649585, depth=0.000000, plastic_amount=0.927150, time=not_yet_set)
# P[4206](lon=26.768963, lat=39.199590, depth=0.000000, plastic_amount=2.960097, time=not_yet_set)
# P[4207](lon=26.775591, lat=37.818871, depth=0.000000, plastic_amount=3.789928, time=not_yet_set)
# P[4208](lon=26.782894, lat=39.414719, depth=0.000000, plastic_amount=2.976010, time=not_yet_set)
# P[4209](lon=26.789516, lat=38.099096, depth=0.000000, plastic_amount=1.685715, time=not_yet_set)
# P[4210](lon=26.792382, lat=38.154854, depth=0.000000, plastic_amount=1.681299, time=not_yet_set)
# P[4211](lon=26.793657, lat=39.575115, depth=0.000000, plastic_amount=2.752984, time=not_yet_set)
# P[4212](lon=26.816303, lat=38.597523, depth=0.000000, plastic_amount=15.695798, time=not_yet_set)
# P[4213](lon=26.823332, lat=37.019250, depth=0.000000, plastic_amount=2.198738, time=not_yet_set)
# P[4214](lon=26.825704, lat=37.076821, depth=0.000000, plastic_amount=2.193368, time=not_yet_set)
# P[4215](lon=26.825736, lat=38.761973, depth=0.000000, plastic_amount=4.399296, time=not_yet_set)
# P[4216](lon=26.830521, lat=37.191663, depth=0.000000, plastic_amount=1.860763, time=not_yet_set)
# P[4217](lon=26.835439, lat=37.306119, depth=0.000000, plastic_amount=1.851655, time=not_yet_set)
# P[4218](lon=26.837935, lat=37.363201, depth=0.000000, plastic_amount=1.216023, time=not_yet_set)
# P[4219](lon=26.838714, lat=38.979934, depth=0.000000, plastic_amount=1.302136, time=not_yet_set)
# P[4220](lon=26.845378, lat=39.088361, depth=0.000000, plastic_amount=1.296015, time=not_yet_set)
# P[4221](lon=26.848754, lat=39.142437, depth=0.000000, plastic_amount=2.774078, time=not_yet_set)
# P[4222](lon=26.850802, lat=37.647150, depth=0.000000, plastic_amount=1.772731, time=not_yet_set)
# P[4223](lon=26.851466, lat=35.425886, depth=0.000000, plastic_amount=0.301426, time=not_yet_set)
# P[4224](lon=26.858835, lat=37.816363, depth=0.000000, plastic_amount=2.376251, time=not_yet_set)
# P[4225](lon=26.866082, lat=39.411438, depth=0.000000, plastic_amount=3.099690, time=not_yet_set)
# P[4226](lon=26.869637, lat=39.464965, depth=0.000000, plastic_amount=3.091526, time=not_yet_set)
# P[4227](lon=26.869914, lat=38.040632, depth=0.000000, plastic_amount=1.688689, time=not_yet_set)
# P[4228](lon=26.873222, lat=39.518400, depth=0.000000, plastic_amount=3.083987, time=not_yet_set)
# P[4229](lon=26.876838, lat=39.571745, depth=0.000000, plastic_amount=3.077070, time=not_yet_set)
# P[4230](lon=26.904249, lat=36.959432, depth=0.000000, plastic_amount=2.203301, time=not_yet_set)
# P[4231](lon=26.908948, lat=38.759023, depth=0.000000, plastic_amount=4.396026, time=not_yet_set)
# P[4232](lon=26.908966, lat=37.074623, depth=0.000000, plastic_amount=2.192518, time=not_yet_set)
# P[4233](lon=26.911361, lat=37.132072, depth=0.000000, plastic_amount=2.187143, time=not_yet_set)
# P[4234](lon=26.912147, lat=38.813626, depth=0.000000, plastic_amount=4.385212, time=not_yet_set)
# P[4235](lon=26.915375, lat=38.868136, depth=0.000000, plastic_amount=4.374459, time=not_yet_set)
# P[4236](lon=26.918632, lat=38.922553, depth=0.000000, plastic_amount=4.363767, time=not_yet_set)
# P[4237](lon=26.933026, lat=35.363977, depth=0.000000, plastic_amount=0.302078, time=not_yet_set)
# P[4238](lon=26.934048, lat=37.644715, depth=0.000000, plastic_amount=3.324777, time=not_yet_set)
# P[4239](lon=26.936508, lat=35.484501, depth=0.000000, plastic_amount=0.300659, time=not_yet_set)
# P[4240](lon=26.942077, lat=37.813855, depth=0.000000, plastic_amount=11.438521, time=not_yet_set)
# P[4241](lon=26.953149, lat=38.038023, depth=0.000000, plastic_amount=1.687965, time=not_yet_set)
# P[4242](lon=26.980626, lat=36.783828, depth=0.000000, plastic_amount=0.919520, time=not_yet_set)
# P[4243](lon=26.982898, lat=36.841745, depth=0.000000, plastic_amount=2.213456, time=not_yet_set)
# P[4244](lon=26.989856, lat=37.014902, depth=0.000000, plastic_amount=2.197220, time=not_yet_set)
# P[4245](lon=27.017294, lat=37.642282, depth=0.000000, plastic_amount=3.323658, time=not_yet_set)
# P[4246](lon=27.018048, lat=35.422692, depth=0.000000, plastic_amount=0.623494, time=not_yet_set)
# P[4247](lon=27.022617, lat=37.755087, depth=0.000000, plastic_amount=11.464645, time=not_yet_set)
# P[4248](lon=27.036384, lat=38.035417, depth=0.000000, plastic_amount=1.634860, time=not_yet_set)
# P[4249](lon=27.061646, lat=36.723755, depth=0.000000, plastic_amount=0.927524, time=not_yet_set)
# P[4250](lon=27.068456, lat=36.897435, depth=0.000000, plastic_amount=2.207033, time=not_yet_set)
# P[4251](lon=27.070774, lat=36.955132, depth=0.000000, plastic_amount=2.201605, time=not_yet_set)
# P[4252](lon=27.100539, lat=37.639848, depth=0.000000, plastic_amount=1.833999, time=not_yet_set)
# P[4253](lon=27.103088, lat=35.481266, depth=0.000000, plastic_amount=0.621792, time=not_yet_set)
# P[4254](lon=27.104859, lat=35.541340, depth=0.000000, plastic_amount=1.146682, time=not_yet_set)
# P[4255](lon=27.105858, lat=37.752604, depth=0.000000, plastic_amount=8.030056, time=not_yet_set)
# P[4256](lon=27.106652, lat=35.601312, depth=0.000000, plastic_amount=1.143902, time=not_yet_set)
# P[4257](lon=27.108465, lat=35.661182, depth=0.000000, plastic_amount=0.201967, time=not_yet_set)
# P[4258](lon=27.112156, lat=35.780619, depth=0.000000, plastic_amount=0.102486, time=not_yet_set)
# P[4259](lon=27.119616, lat=38.032809, depth=0.000000, plastic_amount=1.565436, time=not_yet_set)
# P[4260](lon=27.140494, lat=36.605455, depth=0.000000, plastic_amount=0.503216, time=not_yet_set)
# P[4261](lon=27.144913, lat=36.721695, depth=0.000000, plastic_amount=0.930072, time=not_yet_set)
# P[4262](lon=27.151718, lat=36.895309, depth=0.000000, plastic_amount=4.468120, time=not_yet_set)
# P[4263](lon=27.156377, lat=37.010560, depth=0.000000, plastic_amount=4.225073, time=not_yet_set)
# P[4264](lon=27.158743, lat=37.068035, depth=0.000000, plastic_amount=4.214684, time=not_yet_set)
# P[4265](lon=27.173462, lat=37.410835, depth=0.000000, plastic_amount=4.155585, time=not_yet_set)
# P[4266](lon=27.176004, lat=37.467625, depth=0.000000, plastic_amount=4.145347, time=not_yet_set)
# P[4267](lon=27.178571, lat=37.524319, depth=0.000000, plastic_amount=4.135132, time=not_yet_set)
# P[4268](lon=27.181164, lat=37.580917, depth=0.000000, plastic_amount=2.888600, time=not_yet_set)
# P[4269](lon=27.184627, lat=35.419495, depth=0.000000, plastic_amount=3.628237, time=not_yet_set)
# P[4270](lon=27.189098, lat=37.750122, depth=0.000000, plastic_amount=8.026671, time=not_yet_set)
# P[4271](lon=27.193584, lat=35.719254, depth=0.000000, plastic_amount=0.199117, time=not_yet_set)
# P[4272](lon=27.197317, lat=35.838450, depth=0.000000, plastic_amount=0.102222, time=not_yet_set)
# P[4273](lon=27.200044, lat=37.974376, depth=0.000000, plastic_amount=4.893682, time=not_yet_set)
# P[4274](lon=27.221590, lat=36.545196, depth=0.000000, plastic_amount=0.504374, time=not_yet_set)
# P[4275](lon=27.225958, lat=36.661589, depth=0.000000, plastic_amount=0.501833, time=not_yet_set)
# P[4276](lon=27.230422, lat=36.777586, depth=0.000000, plastic_amount=5.595391, time=not_yet_set)
# P[4277](lon=27.237295, lat=36.950835, depth=0.000000, plastic_amount=5.554226, time=not_yet_set)
# P[4278](lon=27.239636, lat=37.008387, depth=0.000000, plastic_amount=4.223758, time=not_yet_set)
# P[4279](lon=27.244389, lat=37.123197, depth=0.000000, plastic_amount=4.202986, time=not_yet_set)
# P[4280](lon=27.254196, lat=37.351633, depth=0.000000, plastic_amount=4.164493, time=not_yet_set)
# P[4281](lon=27.269664, lat=35.478032, depth=0.000000, plastic_amount=3.618089, time=not_yet_set)
# P[4282](lon=27.271433, lat=35.538065, depth=0.000000, plastic_amount=3.609292, time=not_yet_set)
# P[4283](lon=27.272337, lat=37.747640, depth=0.000000, plastic_amount=8.025229, time=not_yet_set)
# P[4284](lon=27.273223, lat=35.597997, depth=0.000000, plastic_amount=3.124063, time=not_yet_set)
# P[4285](lon=27.275032, lat=37.803824, depth=0.000000, plastic_amount=8.004124, time=not_yet_set)
# P[4286](lon=27.275035, lat=35.657827, depth=0.000000, plastic_amount=0.102919, time=not_yet_set)
# P[4287](lon=27.277753, lat=37.859911, depth=0.000000, plastic_amount=7.984374, time=not_yet_set)
# P[4288](lon=27.278722, lat=35.777186, depth=0.000000, plastic_amount=0.102418, time=not_yet_set)
# P[4289](lon=27.280501, lat=37.915901, depth=0.000000, plastic_amount=7.965969, time=not_yet_set)
# P[4290](lon=27.283276, lat=37.971795, depth=0.000000, plastic_amount=4.891965, time=not_yet_set)
# P[4291](lon=27.300587, lat=36.426458, depth=0.000000, plastic_amount=0.309202, time=not_yet_set)
# P[4292](lon=27.307029, lat=36.601429, depth=0.000000, plastic_amount=0.387373, time=not_yet_set)
# P[4293](lon=27.315950, lat=36.833331, depth=0.000000, plastic_amount=5.579109, time=not_yet_set)
# P[4294](lon=27.320554, lat=36.948685, depth=0.000000, plastic_amount=5.551669, time=not_yet_set)
# P[4295](lon=27.330056, lat=37.178211, depth=0.000000, plastic_amount=4.190648, time=not_yet_set)
# P[4296](lon=27.337444, lat=37.349321, depth=0.000000, plastic_amount=4.162472, time=not_yet_set)
# P[4297](lon=27.381758, lat=36.366009, depth=0.000000, plastic_amount=0.309853, time=not_yet_set)
# P[4298](lon=27.385979, lat=36.482912, depth=0.000000, plastic_amount=0.308333, time=not_yet_set)
# P[4299](lon=27.394705, lat=36.715519, depth=0.000000, plastic_amount=0.782105, time=not_yet_set)
# P[4300](lon=27.401499, lat=36.888931, depth=0.000000, plastic_amount=5.563289, time=not_yet_set)
# P[4301](lon=27.403812, lat=36.946538, depth=0.000000, plastic_amount=5.549572, time=not_yet_set)
# P[4302](lon=27.410897, lat=37.118760, depth=0.000000, plastic_amount=4.199387, time=not_yet_set)
# P[4303](lon=27.418205, lat=37.290095, depth=0.000000, plastic_amount=4.171127, time=not_yet_set)
# P[4304](lon=27.467125, lat=36.422563, depth=0.000000, plastic_amount=0.309002, time=not_yet_set)
# P[4305](lon=27.475752, lat=36.655483, depth=0.000000, plastic_amount=0.783801, time=not_yet_set)
# P[4306](lon=27.480206, lat=36.771344, depth=0.000000, plastic_amount=0.779943, time=not_yet_set)
# P[4307](lon=27.487069, lat=36.944391, depth=0.000000, plastic_amount=4.229310, time=not_yet_set)
# P[4308](lon=27.494150, lat=37.116543, depth=0.000000, plastic_amount=4.198055, time=not_yet_set)
# P[4309](lon=27.501453, lat=37.287808, depth=0.000000, plastic_amount=1.177903, time=not_yet_set)
# P[4310](lon=27.559015, lat=36.653449, depth=0.000000, plastic_amount=0.783453, time=not_yet_set)
# P[4311](lon=27.563466, lat=36.769266, depth=0.000000, plastic_amount=0.779591, time=not_yet_set)
# P[4312](lon=27.572659, lat=36.999703, depth=0.000000, plastic_amount=4.216910, time=not_yet_set)
# P[4313](lon=27.579810, lat=37.171490, depth=0.000000, plastic_amount=4.185694, time=not_yet_set)
# P[4314](lon=27.582243, lat=37.228555, depth=0.000000, plastic_amount=2.744001, time=not_yet_set)
# P[4315](lon=27.642276, lat=36.651415, depth=0.000000, plastic_amount=0.783167, time=not_yet_set)
# P[4316](lon=27.648985, lat=36.824921, depth=0.000000, plastic_amount=0.777377, time=not_yet_set)
# P[4317](lon=27.655913, lat=36.997533, depth=0.000000, plastic_amount=4.215304, time=not_yet_set)
# P[4318](lon=27.698889, lat=35.887358, depth=0.000000, plastic_amount=0.062383, time=not_yet_set)
# P[4319](lon=27.700804, lat=35.946580, depth=0.000000, plastic_amount=0.133784, time=not_yet_set)
# P[4320](lon=27.702741, lat=36.005701, depth=0.000000, plastic_amount=0.327399, time=not_yet_set)
# P[4321](lon=27.704700, lat=36.064722, depth=0.000000, plastic_amount=0.326552, time=not_yet_set)
# P[4322](lon=27.706681, lat=36.123642, depth=0.000000, plastic_amount=0.325749, time=not_yet_set)
# P[4323](lon=27.708684, lat=36.182461, depth=0.000000, plastic_amount=0.325377, time=not_yet_set)
# P[4324](lon=27.727748, lat=36.707293, depth=0.000000, plastic_amount=0.781109, time=not_yet_set)
# P[4325](lon=27.732242, lat=36.822820, depth=0.000000, plastic_amount=0.777139, time=not_yet_set)
# P[4326](lon=27.739164, lat=36.995362, depth=0.000000, plastic_amount=4.213990, time=not_yet_set)
# P[4327](lon=27.780273, lat=35.826300, depth=0.000000, plastic_amount=0.062512, time=not_yet_set)
# P[4328](lon=27.793979, lat=36.239297, depth=0.000000, plastic_amount=0.364035, time=not_yet_set)
# P[4329](lon=27.796027, lat=36.297893, depth=0.000000, plastic_amount=0.363137, time=not_yet_set)
# P[4330](lon=27.811006, lat=36.705237, depth=0.000000, plastic_amount=0.780651, time=not_yet_set)
# P[4331](lon=27.815497, lat=36.820719, depth=0.000000, plastic_amount=0.776785, time=not_yet_set)
# P[4332](lon=27.824769, lat=37.050486, depth=0.000000, plastic_amount=1.269018, time=not_yet_set)
# P[4333](lon=27.865441, lat=35.883849, depth=0.000000, plastic_amount=0.118332, time=not_yet_set)
# P[4334](lon=27.881363, lat=36.354462, depth=0.000000, plastic_amount=0.629511, time=not_yet_set)
# P[4335](lon=27.894264, lat=36.703182, depth=0.000000, plastic_amount=0.780361, time=not_yet_set)
# P[4336](lon=27.898752, lat=36.818620, depth=0.000000, plastic_amount=0.776496, time=not_yet_set)
# P[4337](lon=27.908018, lat=37.048294, depth=0.000000, plastic_amount=1.187220, time=not_yet_set)
# P[4338](lon=27.950626, lat=35.941255, depth=0.000000, plastic_amount=0.393839, time=not_yet_set)
# P[4339](lon=27.952559, lat=36.000314, depth=0.000000, plastic_amount=0.656082, time=not_yet_set)
# P[4340](lon=27.966719, lat=36.410889, depth=0.000000, plastic_amount=1.420881, time=not_yet_set)
# P[4341](lon=27.977520, lat=36.701127, depth=0.000000, plastic_amount=1.741591, time=not_yet_set)
# P[4342](lon=27.982005, lat=36.816519, depth=0.000000, plastic_amount=1.732711, time=not_yet_set)
# P[4343](lon=27.984284, lat=36.874065, depth=0.000000, plastic_amount=1.728659, time=not_yet_set)
# P[4344](lon=27.991265, lat=37.046102, depth=0.000000, plastic_amount=1.187023, time=not_yet_set)
# P[4345](lon=28.037784, lat=36.057456, depth=0.000000, plastic_amount=1.219663, time=not_yet_set)
# P[4346](lon=28.049981, lat=36.408945, depth=0.000000, plastic_amount=8.802123, time=not_yet_set)
# P[4347](lon=28.058569, lat=36.641248, depth=0.000000, plastic_amount=1.744894, time=not_yet_set)
# P[4348](lon=28.060775, lat=36.699072, depth=0.000000, plastic_amount=1.740569, time=not_yet_set)
# P[4349](lon=28.069836, lat=36.929366, depth=0.000000, plastic_amount=1.723315, time=not_yet_set)
# P[4350](lon=28.074512, lat=37.043911, depth=0.000000, plastic_amount=1.172973, time=not_yet_set)
# P[4351](lon=28.123029, lat=36.114454, depth=0.000000, plastic_amount=2.187276, time=not_yet_set)
# P[4352](lon=28.125027, lat=36.173164, depth=0.000000, plastic_amount=4.445632, time=not_yet_set)
# P[4353](lon=28.133242, lat=36.407000, depth=0.000000, plastic_amount=28.882973, time=not_yet_set)
# P[4354](lon=28.139645, lat=36.581315, depth=0.000000, plastic_amount=1.748601, time=not_yet_set)
# P[4355](lon=28.155409, lat=36.984521, depth=0.000000, plastic_amount=1.718371, time=not_yet_set)
# P[4356](lon=28.210310, lat=36.229897, depth=0.000000, plastic_amount=4.433363, time=not_yet_set)
# P[4357](lon=28.212352, lat=36.288386, depth=0.000000, plastic_amount=4.422378, time=not_yet_set)
# P[4358](lon=28.214415, lat=36.346774, depth=0.000000, plastic_amount=21.039104, time=not_yet_set)
# P[4359](lon=28.218612, lat=36.463242, depth=0.000000, plastic_amount=49.559151, time=not_yet_set)
# P[4360](lon=28.225079, lat=36.637187, depth=0.000000, plastic_amount=1.743735, time=not_yet_set)
# P[4361](lon=28.227283, lat=36.694965, depth=0.000000, plastic_amount=1.739644, time=not_yet_set)
# P[4362](lon=28.299761, lat=36.403116, depth=0.000000, plastic_amount=49.661011, time=not_yet_set)
# P[4363](lon=28.312760, lat=36.750569, depth=0.000000, plastic_amount=1.734279, time=not_yet_set)
# P[4364](lon=28.315009, lat=36.808124, depth=0.000000, plastic_amount=1.729954, time=not_yet_set)
# P[4365](lon=28.398256, lat=36.806025, depth=0.000000, plastic_amount=1.729308, time=not_yet_set)
# P[4366](lon=28.481504, lat=36.803928, depth=0.000000, plastic_amount=1.728779, time=not_yet_set)
# P[4367](lon=28.562506, lat=36.744344, depth=0.000000, plastic_amount=3.415866, time=not_yet_set)
# P[4368](lon=28.643534, lat=36.684704, depth=0.000000, plastic_amount=3.423169, time=not_yet_set)

# %%
fig = plt.figure()
ax = plt.axes(projection=ccrs.PlateCarree())
ax.scatter(pset.lon, pset.lat, c=np.log(pset.plastic_amount), s=2, transform=ccrs.PlateCarree())
ax.coastlines()
ax.gridlines(draw_labels=True)
plt.title("Initial particle positions")
plt.show()

fig = plt.figure()
ax = plt.axes(projection=ccrs.PlateCarree())
ax.scatter(pset.lon, pset.lat, c=np.log(pset.plastic_amount), s=2, transform=ccrs.PlateCarree())
ax.coastlines()
ax.gridlines(draw_labels=True)
ax.set_xlim([np.min(pset.lon)-25, np.max(pset.lon)+25])
ax.set_ylim([np.min(pset.lat)-25, np.max(pset.lat)+25])
plt.title("Initial particle positions")
plt.show()
# Out:
# /Users/denes001/anaconda3/envs/py3_parcels/lib/python3.11/site-packages/shapely/predicates.py:798: RuntimeWarning: invalid value encountered in intersects
#   return lib.intersects(a, b, **kwargs)

# %%
kernels = PP.constructors.create_kernel(fieldset, pset)

# %%
kernels = kernels[1:]

# %%
## Define the runtime, the timestepping, and the output frequency of the simulation
runtime = settings['simulation']['runtime']
dt_timestep = settings['simulation']['dt_timestep']
dt_write = settings['simulation']['dt_write']

# %%
## Create the particle file where output will be stored
pfile = ParticleFile('tes2.zarr', pset, outputdt=dt_write)
pfile.add_metadata('PlasticParcels_settings', str(settings))

## Execute the simulation
pset.execute(kernels, runtime=runtime, dt=dt_timestep, output_file=pfile)
# Out:
# INFO: Output files are stored in tes2.zarr.
# 100%|██████████| 259200.0/259200.0 [00:05<00:00, 49692.38it/s]

# %%
fig = plt.figure()
ax = plt.axes(projection=ccrs.PlateCarree())
ax.scatter(pset.lon, pset.lat, c=np.log(pset.plastic_amount), s=5, transform=ccrs.PlateCarree())
ax.coastlines()
ax.gridlines(draw_labels=True)
plt.title("Final particle positions")
plt.show()

fig = plt.figure()
ax = plt.axes(projection=ccrs.PlateCarree())
ax.scatter(pset.lon, pset.lat, c=np.log(pset.plastic_amount), s=5, transform=ccrs.PlateCarree())
ax.coastlines()
ax.gridlines(draw_labels=True)
ax.set_xlim([np.min(pset.lon)-25, np.max(pset.lon)+25])
ax.set_ylim([np.min(pset.lat)-25, np.max(pset.lat)+25])
plt.title("Final particle positions")
plt.show()
# Out:
# /Users/denes001/anaconda3/envs/py3_parcels/lib/python3.11/site-packages/shapely/predicates.py:798: RuntimeWarning: invalid value encountered in intersects
#   return lib.intersects(a, b, **kwargs)

# %%
particle_locations = pd.read_csv(settings['release_maps']['coastal'])

# %%
particle_locations['MPW_Cell']

# %%
import xarray as xr
ds = xr.open_zarr('tes2.zarr')

# %%
test = ds.attrs['Settings']

# %%
test

# %% [markdown]
# # Create a Parcels fieldset
# We now create the fieldset that contains all the required fields (ocean velocities, temperature and salinity, ocean biology, winds and waves, etc.).
#
# We loaded the default settings above, which we will pass into the `create_fieldset` PlasticParcels function. This removes a lot of the complexity when creating fieldsets with a large number of underlying fields. What is produced is a Parcels fieldset object.

# %%
fieldset = create_fieldset(model_settings, particle_settings)

print("Time origin of data: ", fieldset.time_origin)

# %% [markdown]
# To list all the fields that are present we use `.get_fields()` method to return a list of the fields, which we can then utilise and analyse.

# %%
for parcels_field in fieldset.get_fields():
    print(parcels_field.name)

# %% [markdown]
# ## Plotting Parcels `fields`
# Parcels fields are not loaded into memory immediately, rather the fields are only loaded when they are required (deferred load). Often the hydrodynamic data alone can be hundreds of GBs. To visualise these fields we can load in the first timestep of data.
#
# We do this using the `.computeTimeChunk(time, dt)` method, which takes as input a model time to load, and a number of timesteps to load. Once loaded, we plot the resulting fields using the `pcolormesh` matplotlib function. Below is a small snippet of code used to plot these fields.
#
# **A key highlight here is that Parcels handles different spatial grids and temporal resolutions automatically, and can even use different interpolation methods on each.**

# %% [markdown]
# <div class="alert alert-info">
# Note - The plots below are indicative only. Since the data is on a C-grid, and the plotting assumes we are passing T-points, there is a slight spatial shift to the data. This is only an issue with our basic plotting below, Parcels correctly interprets the grids.
# </div>

# %%
## Load data into memory
fieldset.computeTimeChunk(0,1)

# %%
## Plotting function
def plot_field(lons, lats, data, title):
    fig = plt.figure()
    ax = plt.axes(projection=ccrs.PlateCarree())
    colors = ax.pcolormesh(lons, lats, data, transform=ccrs.PlateCarree())
    ax.coastlines()
    ax.gridlines(draw_labels=True)
    plt.title(title)
    plt.colorbar(colors)
    plt.show()

# %% [markdown]
# Note that some fields have no depth component (e.g. bathymetry, wind, waves), and so the shape of their data is different, and should be indexed differently.

# %%
print("The usual shape order is (time, depth, latitude, longitude)")
print("Ocean U velocity data shape:", fieldset.U.data.shape)
print("Ocean V velocity data shape:", fieldset.V.data.shape)
print("Wind U velocity data shape:", fieldset.Wind_U.data.shape)
print("Wind V velocity data shape:", fieldset.Wind_U.data.shape)
print("Bathymetry shape:", fieldset.bathymetry.data.shape)

# %% [markdown]
# Plot the ocean surface velocity fields

# %%
## Plot velocity fields
plot_field(fieldset.U.grid.lon, fieldset.U.grid.lat, fieldset.U.data[0,0], "Surface velocity in i-direction (m/s)")
plot_field(fieldset.V.grid.lon, fieldset.V.grid.lat, fieldset.V.data[0,0], "Surface velocity in j-direction (m/s)")

# %% [markdown]
# <div class="alert alert-info">
# Note: The U,V fields are on a curvilinear grid, and the velocities are in the i- and j-directions. Parcels automatically rotates these vectors into the zonal- and meridional-directions when performing interpolation.
# </div>

# %% [markdown]
# Plot the model bathymetry field

# %%
## Plot bathymetry
plot_field(fieldset.bathymetry.grid.lon, fieldset.bathymetry.grid.lat, fieldset.bathymetry.data[0], "Depth (m)")

# %% [markdown]
# Plot the 10m-wind velocity fields

# %%
## Plot Wind velocity fields
plot_field(fieldset.Wind_U.grid.lon, fieldset.Wind_U.grid.lat, fieldset.Wind_U.data[0], "Zonal wind velocity (m/s)")
plot_field(fieldset.Wind_V.grid.lon, fieldset.Wind_V.grid.lat, fieldset.Wind_V.data[0], "Meridional wind velocity (m/s)")

# %% [markdown]
# Plot vertical eddy diffusivity

# %%
## Plot Vertical Diffusivity field
plot_field(fieldset.mixing_kz.grid.lon, fieldset.mixing_kz.grid.lat, fieldset.mixing_kz.data[0,0], "Vertical eddy diffusivity at surface (m$^2$/s)")

# %% [markdown]
# Plot biology related fields

# %%
## Plot pp_phyto
plot_field(fieldset.pp_phyto.grid.lon, fieldset.pp_phyto.grid.lat, fieldset.pp_phyto.data[0,0], "Total Primary Production of Phyto (mg m$^{-3}$/d)")
plot_field(fieldset.bio_diatom.grid.lon, fieldset.bio_diatom.grid.lat, fieldset.bio_diatom.data[0,0], "Mole concentration of Diatoms\n expressed as carbon in sea water")
plot_field(fieldset.pp_phyto.grid.lon, fieldset.pp_phyto.grid.lat, fieldset.pp_phyto.data[0,0], "Mole concentration of nanophytoplankton\n expressed as carbon in sea water")

# %% [markdown]
# # Parcels can also be used as a standalone field interpolator
# There are two ways to access the data in each Parcels field object. Firstly, as above, accessing the data directly and using the grid indices directly.
#
# Another way to access the field data is to pass the field a (time, depth, latitude, longitude) tuple, from which Parcels will interpolate the data for you.
#
# <div class="alert alert-info">
# Note: The U,V fields are on a curvilinear grid, and the velocities are in the i- and j-directions. The UV field is a Parcels VectorField which references the U and V fields, appropriately rotating and scaling the i/j-vectors into zonal- and meridional-directions. Other velocity fields (e.g. wind) need their units to be converted when loaded as a field.
# </div>

# %%
# Sample the U,V ocean velocities at the ocean surface somewhere in the Mediterranean
poi = [35.25, 20.11] # Point of Interest: 35.25deg North, 20.11deg East

U_value = fieldset.U[0,0,poi[0],poi[1]]
V_value = fieldset.V[0,0,poi[0],poi[1]]
print("Surface velocities in the i-, j-directions:", U_value, V_value, " (degrees/s).")

U_value, V_value = fieldset.UV[0,0,poi[0],poi[1]]
print("Surface velocities in the zonal-, meridional-directions:", U_value, V_value, " (degrees/s)")

# %% [markdown]
# We can also convert the values back into units of m/s by using the applyConversion parameter

# %%
U_value, V_value = fieldset.UV.eval(0, 0, poi[0],poi[1], applyConversion=False)
print("Surface velocities in the zonal-, meridional-directions:", U_value, V_value, " (m/s)")

# %%
## Determine the ocean depth at the point of interest
print(fieldset.bathymetry[0,0,poi[0], poi[1]])

# %%
## Determine the wind velocity at the point of interest
Wind_U_value = fieldset.Wind_U[0,0,poi[0],poi[1]]
Wind_V_value = fieldset.Wind_V[0,0,poi[0],poi[1]]
print("Surface wind velocities: ", Wind_U_value, Wind_V_value, " (degrees/s).")

Wind_U_value = fieldset.Wind_U.eval(0, 0, poi[0],poi[1], applyConversion=False)
Wind_V_value = fieldset.Wind_V.eval(0, 0, poi[0],poi[1], applyConversion=False)
print("Surface wind velocities: ", Wind_U_value, Wind_V_value, " (m/s).")

# %% [markdown]
# # Particle Sets
# We will now create some particle sets which represent release locations for microplastic particles.
#
# In the first instance, we will create a basic particle set using Parcels. Since our microplastic particles require additional variables (e.g. windage coefficients and settling velocities), we will still use the PlasticParcels helper functions.
#
# In the second instance, we will use PlasticParcels to create more complicated particle sets that replicate likely microplastic release locations. These release locations are determined using a range of datasets.

# %% [markdown]
# ## Creating a simple particle set
# Parcels includes a number of methods to create particle sets.
#
# The most commonly used is `ParticleSet.from_list()`, which allows you to pass through a list of longitudes, latitudes, depths, and times.
#
# Below, we randomly place particles in a box at different depths, and given these particles a wind coefficient, density, and diameter.

# %%
## Number of particles to release
n_particles = 100

## Randomly place particle release locations on a grid
lons = np.random.uniform(2,7,n_particles)
lats = np.random.uniform(37,42,n_particles)

## Randomly place the particles between the ocean surface and 50m depth
depths = np.random.uniform(0,50, n_particles)

## Create a dictionary of lists containing release location information 
release_locations = {'lons': lons,
                     'lats': lats,
                     'depths': depths
}

## Define particle properties
wind_coefficient = 0.01 # Percent of wind speed to apply
plastic_density = 1020. # Particle density (kg/m^3)
plastic_diameter = 0.001 # Partice diameter (m)
## Particleset settings
particle_settings.update({'release_locations': release_locations, # A dictionary of lons, lats, depths (optional), and times (optional)
                          'windage_coefficient': wind_coefficient, # A float or Nx1 array of windage coefficients, values in [0,1] [percent of wind speed]
                          'particle_density': plastic_density, # A float or Nx1 array of particle densities [kg m-3]
                          'particle_diameter': plastic_diameter, # A float or Nx1 array of particle lengths [m]
                          'write_output_option': 'none' # Option to write variables. Options: 'none' (default), 'tracer' (saves tracer fields), 'dynamic' (saves all variables that change spatiotemporally), 'all' (saves all variables)
                           })

# %%
## Create the particle set, and kernels required for the simulation
pset = create_particleset(fieldset, particle_settings)
kernels = create_kernel(fieldset, pset)

# %% [markdown]
# Let's take a look at the particle set

# %%
print(pset)

# %% [markdown]
# These particle sets can be indexed by particle id

# %%
print("Information saved for particle_id = 4:", pset[4])

# %% [markdown]
# Plot the particles, and list the kernels that will be used

# %%
fig = plt.figure()
ax = plt.axes(projection=ccrs.PlateCarree())
ax.scatter(pset.lon, pset.lat, s=2, transform=ccrs.PlateCarree())
ax.coastlines()
ax.gridlines(draw_labels=True)
plt.title("Initial particle positions")
plt.show()

fig = plt.figure()
ax = plt.axes(projection=ccrs.PlateCarree())
ax.scatter(pset.lon, pset.lat, s=2, transform=ccrs.PlateCarree())
ax.coastlines()
ax.gridlines(draw_labels=True)
ax.set_xlim([np.min(pset.lon)-25, np.max(pset.lon)+25])
ax.set_ylim([np.min(pset.lat)-25, np.max(pset.lat)+25])
plt.title("Initial particle positions")
plt.show()

# %% [markdown]
# List the kernels that will be used in the particle advection.
# For documentation on the kernels, see `PlasticParcels/kernels.py`

# %%
kernels

# %% [markdown]
# We will now advect these particles. We first need to create a Parcels `ParticleFile` where we will store our output. To advect the particles, we simply use the `execute` method.

# %%
## Define the runtime, the timestepping, and the output frequency of the simulation
runtime = particle_settings['runtime']
dt_timestep = particle_settings['dt_timestep']
dt_write = particle_settings['dt_write']

## Create the particle file where output will be stored
pfile = ParticleFile('simple_release.zarr', pset, outputdt=dt_write)

## Execute the simulation
pset.execute(kernels, runtime=runtime, dt=dt_timestep, output_file=pfile)

# %% [markdown]
# Plot the final locations of the particles

# %%
fig = plt.figure()
ax = plt.axes(projection=ccrs.PlateCarree())
ax.scatter(pset.lon, pset.lat, s=2, transform=ccrs.PlateCarree())
ax.coastlines()
ax.gridlines(draw_labels=True)
plt.title("Final particle positions")
plt.show()

fig = plt.figure()
ax = plt.axes(projection=ccrs.PlateCarree())
ax.scatter(pset.lon, pset.lat, s=2, transform=ccrs.PlateCarree())
ax.coastlines()
ax.gridlines(draw_labels=True)
ax.set_xlim([np.min(pset.lon)-25, np.max(pset.lon)+25])
ax.set_ylim([np.min(pset.lat)-25, np.max(pset.lat)+25])
plt.title("Final particle positions")
plt.show()

# %% [markdown]
# <div class="alert alert-info">
# To analyse the output, you can follow the Parcels tutorial here: https://docs.oceanparcels.org/en/latest/examples/tutorial_output.html
# </div>

# %% [markdown]
# ## Creating a more likely plastic particle release map
#
# ### Plastics emitted on the coast
# We use the mismanaged plastic waste estimates by country from Jambeck et. al "Plastic waste inputs from land into the ocean", Science (2015) (DOI: 10.1126/science.1260352) combined with the NASA GPW v4.11 global population dataset (see https://sedac.ciesin.columbia.edu/data/set/gpw-v4-population-density-rev11/) and the Natural Earth coastline vector dataset (see https://www.naturalearthdata.com/) in order to create a likely 'coastal' particle release map.

# %%
# File locations
coastal = './../../data/release/generated_files/coastal_population_MPW_NEMO0083.csv'
rivers = './../../data/release/generated_files/river_emissions_NEMO0083.csv'
fisheries = './../../data/release/generated_files/agg_data_fisheries_info.csv'

# Read and print coastal dataset
plastic_release = pd.read_csv(coastal)
plastic_release

# %% [markdown]
# ### Particles emitted at river outlets
# We use the  from Meijer et. al "More than 1000 rivers account for 80% of global riverine plastic emissions into the ocean" Science Advances (2021) (DOI: 10.1126/sciadv.aaz5803) combined with the Natural Earth coastline vector dataset to create a likely 'river' particle release map.

# %%
# Read and print coastal dataset
plastic_release = pd.read_csv(rivers)
plastic_release

# %% [markdown]
# ### Particles emitted from fishing-related activity
# Lastly, we use the Global Fishing Watch public fishing effort dataset (see https://globalfishingwatch.org/data-download/datasets/public-fishing-effort) combined with the Natural Earth coastline vector dataset to create a likely 'fisheries' particle release map.

# %%
# Read and print coastal dataset
plastic_release = pd.read_csv(fisheries)
plastic_release

# %%
del(plastic_release)

# %% [markdown]
# ### Create a particle set with these release settings

# %%
## First we need to remove the release locations we used in the basic example above
del(particle_settings['release_locations'])

# %%
## Remove any settings previously applied
settings_to_remove = ['release_type', 'particle_density', 'particle_diameter', 'windage_coefficient',
                      'continent', 'subregion', 'region', 'subregion', 'country']

for setting in settings_to_remove:
    if setting in particle_settings.keys():
        del(particle_settings[setting])


## Update your new settings here
new_settings = {'release_type': 'coastal',
                #'continent': '',
                #'region': '',
                #'subregion': 'Southern Europe',
                'country': 'Greece',
                'windage_coefficient' : 0.01, # Percentage of wind to apply to particles
                'particle_diameter' : 0.001, # Plastic particle diameter (m)
                'particle_density' : 1020. # Plastic particle density (kg/m^3)
}
particle_settings.update(new_settings)

## Create the particleset
pset = create_particleset_from_file(fieldset, particle_settings)

# %%
## Plot the particles initial positions
fig = plt.figure()
ax = plt.axes(projection=ccrs.PlateCarree())
ax.scatter(pset.lon, pset.lat, s=2, transform=ccrs.PlateCarree())
ax.coastlines()
ax.gridlines(draw_labels=True)
plt.title("Initial particle positions")
plt.show()

# %%
## Define the runtime, the timestepping, and the output frequency of the simulation
runtime = particle_settings['runtime']
dt_timestep = particle_settings['dt_timestep']
dt_write = particle_settings['dt_write']

## Create the particle file where output will be stored
pfile = ParticleFile('advanced_release.zarr', pset, outputdt=dt_write)

## Execute the simulation
pset.execute(kernels, runtime=runtime, dt=dt_timestep, output_file=pfile)

# %%
## Plot the particles final positions
fig = plt.figure()
ax = plt.axes(projection=ccrs.PlateCarree())
ax.scatter(pset.lon, pset.lat, s=2, transform=ccrs.PlateCarree())
ax.coastlines()
ax.gridlines(draw_labels=True)
plt.title("Final particle positions")
plt.show()

# %% [markdown]
# # Particle Trajectory Analysis
# You can now analyse your particle sets. Rather than re-invent the wheel, we point you to the Parcels tutorial https://docs.oceanparcels.org/en/latest/examples/tutorial_output.html which explains how to read and analyse Parcels particle trajectory datasets.
