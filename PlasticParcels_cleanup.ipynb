# %% [markdown]
# # PlasticParcels DRAKKAR Tutorial
# In this tutorial we will introduce you to some of the basic Parcels functions, as well as utilise the PlasticParcels tool for simulating microplastic pollution in the Mediterranean sea.
#
# By the end of this tutorial you should be able to create and visual hydrodynamic (and other) fields, create particle sets that represent marine microplastic pollution release locations, and apply physics parameterisations to simulate the dispersal of microplastics in the ocean.
#
# We will start by importing a number of necessary packages.

# %%
## Library imports
import os
import numpy as np
import pandas as pd
from datetime import datetime, timedelta

# Parcels and PlasticParcels imports
from parcels import ParticleFile, JITParticle, Variable
#from PlasticParcels import create_fieldset, create_particleset, create_kernel, load_default_settings, create_particleset_from_file, load_test_settings
#from utils import select_files, create_directory, getclosest_ij
#import PlasticParcels
## Plotting imports
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

# %%
from PlasticParcels import constructors

# %%
import PlasticParcels as PP

# %% [markdown]
# # Model settings
# Using PlasticParcels, we will load the default settings for our sumulations, using the `load_default_settings` function.
#
# This returns two dictionary of parameters, one used for fieldset creation, the other for particleset creation.
#
# You can update the parameters by updating the dictionaries as necessary.
#
# The description of each parameter can be found in the PlasticParcels/helper.py file.

# %%
settings = PP.constructors.load_default_settings()

# %%
## View settings
settings
# Out:
# {'mode': '3D',
#  'allow_time_extrapolation': False,
#  'verbose_delete': False,
#  'mixing_f': False,
#  'biofouling_f': False,
#  'stokes_f': False,
#  'wind_f': False,
#  'ocean': {'directory': 'data/input_data/MOi/',
#   'filename_style': 'psy4v3r1/psy4v3r1-daily_',
#   'ocean_mesh': 'domain_ORCA0083-N006/coordinates.nc',
#   'bathymetry_mesh': 'domain_ORCA0083-N006/bathymetry_ORCA12_V3.3.nc',
#   'variables': {'U': 'vozocrtx',
#    'V': 'vomecrty',
#    'W': 'vovecrtz',
#    'conservative_temperature': 'votemper',
#    'absolute_salinity': 'vosaline'},
#   'dimensions': {'U': {'lon': 'glamf',
#     'lat': 'gphif',
#     'depth': 'depthw',
#     'time': 'time_counter'},
#    'V': {'lon': 'glamf',
#     'lat': 'gphif',
#     'depth': 'depthw',
#     'time': 'time_counter'},
#    'W': {'lon': 'glamf',
#     'lat': 'gphif',
#     'depth': 'depthw',
#     'time': 'time_counter'},
#    'conservative_temperature': {'lon': 'glamf',
#     'lat': 'gphif',
#     'depth': 'depthw',
#     'time': 'time_counter'},
#    'absolute_salinity': {'lon': 'glamf',
#     'lat': 'gphif',
#     'depth': 'depthw',
#     'time': 'time_counter'}},
#   'indices': {}},
#  'bgc': {'directory': 'data/input_data/MOi/',
#   'filename_style': 'biomer4v2r1/biomer4v2r1-weekly_',
#   'bgc_mesh': 'domain_ORCA025-N006/mesh_hgr_PSY4V3_deg.nc',
#   'variables': {'pp_phyto': 'nppv',
#    'bio_nanophy': 'phy',
#    'bio_diatom': 'phy2'},
#   'dimensions': {'pp_phyto': {'lon': 'glamf',
#     'lat': 'gphif',
#     'depth': 'depthw',
#     'time': 'time_counter'},
#    'bio_nanophy': {'lon': 'glamf',
#     'lat': 'gphif',
#     'depth': 'depthw',
#     'time': 'time_counter'},
#    'bio_diatom': {'lon': 'glamf',
#     'lat': 'gphif',
#     'depth': 'depthw',
#     'time': 'time_counter'}},
#   'constants': {'biofilm_density': 1388.0,
#    'algae_cell_volume': 2e-16,
#    'K': 1.3805834190672156e-23,
#    'R20': 1.1574074074074074e-06,
#    'Q10': 2.13,
#    'Gamma': 2.0,
#    'carbon_molecular_weight': 12.0,
#    'collision_probability': 1.0,
#    'algae_mortality_rate': 1.0,
#    'algae_respiration_f': 1.0}},
#  'stokes': {'directory': 'data/input_data/ERA5/waves/',
#   'filename_style': 'ERA5_global_waves_monthly_',
#   'variables': {'Stokes_U': 'ust', 'Stokes_V': 'vst', 'wave_Tp': 'pp1d'},
#   'dimensions': {'lat': 'latitude', 'lon': 'longitude', 'time': 'time'}},
#  'wind': {'directory': 'data/input_data/ERA5/wind/',
#   'filename_style': 'ERA5_global_wind_monthly_',
#   'variables': {'Wind_U': 'u10', 'Wind_V': 'v10'},
#   'dimensions': {'lat': 'latitude', 'lon': 'longitude', 'time': 'time'}},
#  'simulation': {'start_date': None,
#   'runtime': None,
#   'dt_write': None,
#   'dt_timestep': None},
#  'release_maps': {'coastal': 'data/release/generated_files/coastal_population_MPW_NEMO0083.csv',
#   'rivers': 'data/release/generated_files/river_emissions_NEMO0083.csv',
#   'fisheries': 'data/release/generated_files/agg_data_fisheries_info.csv',
#   'global_concentrations': None}}

# %%
# Set the simulation settings
settings['simulation'] = {
    'start_date': datetime.strptime('2019-01-10-00:00:00', '%Y-%m-%d-%H:%M:%S'), # Start date of simulation
    'runtime': timedelta(days=3),             # Runtime of simulation, use negative if releasing particles backwards in time
    'dt_write': timedelta(days=1),             # Timestep of output
    'dt_timestep': timedelta(minutes=20),       # Timestep of advection
    }

# %%
fieldset = PP.constructors.create_fieldset(settings)
# Out:
# WARNING: File data/input_data/MOi/domain_ORCA0083-N006/coordinates.nc could not be decoded properly by xarray (version 2023.6.0). It will be opened with no decoding. Filling values might be wrongly parsed.

# %%
# fieldset.computeTimeChunk(0,1)

# %%
# ax = plt.subplot(111, projection=ccrs.PlateCarree())

# ax.pcolormesh(fieldset.U.grid.lon, fieldset.U.grid.lat, fieldset.U.data[0,0], transform=ccrs.PlateCarree())
# plt.show()

# %%
# ax = plt.subplot(111, projection=ccrs.PlateCarree())

# ax.pcolormesh(fieldset.Stokes_U.grid.lon, fieldset.Stokes_U.grid.lat, fieldset.Stokes_U.data[0], transform=ccrs.PlateCarree())
# plt.show()

# %%
# ax = plt.subplot(111, projection=ccrs.PlateCarree())

# ax.pcolormesh(fieldset.pp_phyto.grid.lon, fieldset.pp_phyto.grid.lat, fieldset.pp_phyto.data[0,0], transform=ccrs.PlateCarree())
# plt.show()

# %%
# ax = plt.subplot(111, projection=ccrs.PlateCarree())

# ax.pcolormesh(fieldset.bio_diatom.grid.lon, fieldset.bio_diatom.grid.lat, fieldset.bio_diatom.data[0,0], transform=ccrs.PlateCarree())
# plt.show()

# %%
import numpy as np

# %%
# PlasticParticle = JITParticle.add_variables(
#     [
#         Variable("plastic_diameter", dtype=np.float32, initial=np.nan),
#         Variable("plastic_density", dtype=np.float32, initial=np.nan),
#         Variable('windage_coefficient', dtype=np.float32, initial=0.),
#         Variable('settling_velocity', dtype=np.float64, initial=0.),
#         Variable('seawater_density', dtype=np.float32, initial=np.nan),
#         Variable('absolute_salinity', dtype=np.float64, initial=np.nan),
#         Variable('algae_amount', dtype=np.float64, initial=0.)
#     ]
# )

# ## Is this a better way?
# class PlasticParticle(JITParticle):
#     def __init__(self):
#         self.add_variables([
#             Variable("plastic_diameter", dtype=np.float32, initial=np.nan),
#             Variable("plastic_density", dtype=np.float32, initial=np.nan),
#             Variable('windage_coefficient', dtype=np.float32, initial=0.),
#             Variable('settling_velocity', dtype=np.float64, initial=0.),
#             Variable('seawater_density', dtype=np.float32, initial=np.nan),
#             Variable('absolute_salinity', dtype=np.float64, initial=np.nan),
#             Variable('algae_amount', dtype=np.float64, initial=0.)
#             ])

# %%
## the usual parcels.ParticleSet.from_list() approach

# %%
## Define particle types and release locations

settings['release'] = {
    'wind_coefficient' : 0.01, # Percentage of wind to apply to particles
    'plastic_diameter' : 0.001, # Plastic particle diameter (m)
    'plastic_density' : 1020., # Plastic particle density (kg/m^3)
    'initialisation_type': 'coastal',
    #'continent': '',
    #'region': '',
    #'subregion': 'Southern Europe',
    'country': 'Greece',   
}

## Create the particleset
pset = PP.constructors.create_particleset_from_map(fieldset, settings)

# %%
pset
# Out:
# P[0](lon=19.488523, lat=40.203019, depth=0.000000, plastic_amount=0.269071, time=not_yet_set)
# P[1](lon=19.567968, lat=40.144193, depth=0.000000, plastic_amount=0.269532, time=not_yet_set)
# P[2](lon=19.621123, lat=39.695211, depth=0.000000, plastic_amount=2.737762, time=not_yet_set)
# P[3](lon=19.624786, lat=39.751186, depth=0.000000, plastic_amount=2.731236, time=not_yet_set)
# P[4](lon=19.628482, lat=39.807080, depth=0.000000, plastic_amount=2.725215, time=not_yet_set)
# P[5](lon=19.651334, lat=40.140756, depth=0.000000, plastic_amount=0.253085, time=not_yet_set)
# P[6](lon=19.700856, lat=39.635970, depth=0.000000, plastic_amount=3.072560, time=not_yet_set)
# P[7](lon=19.715573, lat=39.859595, depth=0.000000, plastic_amount=2.766703, time=not_yet_set)
# P[8](lon=19.730808, lat=40.081933, depth=0.000000, plastic_amount=0.253493, time=not_yet_set)
# P[9](lon=19.777052, lat=39.520535, depth=0.000000, plastic_amount=2.717590, time=not_yet_set)
# P[10](lon=19.780620, lat=39.576700, depth=0.000000, plastic_amount=13.214730, time=not_yet_set)
# P[11](lon=19.784219, lat=39.632782, depth=0.000000, plastic_amount=13.185479, time=not_yet_set)
# P[12](lon=19.798935, lat=39.856297, depth=0.000000, plastic_amount=2.765388, time=not_yet_set)
# P[13](lon=19.814170, lat=40.078521, depth=0.000000, plastic_amount=0.395594, time=not_yet_set)
# P[14](lon=19.856876, lat=39.461183, depth=0.000000, plastic_amount=2.736611, time=not_yet_set)
# P[15](lon=19.871210, lat=39.685563, depth=0.000000, plastic_amount=16.717516, time=not_yet_set)
# P[16](lon=19.882296, lat=39.852996, depth=0.000000, plastic_amount=3.171006, time=not_yet_set)
# P[17](lon=19.893672, lat=40.019702, depth=0.000000, plastic_amount=0.396386, time=not_yet_set)
# P[18](lon=19.936730, lat=39.401800, depth=0.000000, plastic_amount=3.081037, time=not_yet_set)
# P[19](lon=19.943771, lat=39.514262, depth=0.000000, plastic_amount=5.522049, time=not_yet_set)
# P[20](lon=19.947339, lat=39.570370, depth=0.000000, plastic_amount=16.779398, time=not_yet_set)
# P[21](lon=19.950938, lat=39.626397, depth=0.000000, plastic_amount=16.742172, time=not_yet_set)
# P[22](lon=19.958231, lat=39.738207, depth=0.000000, plastic_amount=4.397409, time=not_yet_set)
# P[23](lon=19.961926, lat=39.793990, depth=0.000000, plastic_amount=11.842827, time=not_yet_set)
# P[24](lon=19.965654, lat=39.849692, depth=0.000000, plastic_amount=11.816694, time=not_yet_set)
# P[25](lon=19.969413, lat=39.905313, depth=0.000000, plastic_amount=11.790442, time=not_yet_set)
# P[26](lon=19.973204, lat=39.960854, depth=0.000000, plastic_amount=9.331182, time=not_yet_set)
# P[27](lon=20.016613, lat=39.342388, depth=0.000000, plastic_amount=3.086517, time=not_yet_set)
# P[28](lon=20.023592, lat=39.454959, depth=0.000000, plastic_amount=3.291826, time=not_yet_set)
# P[29](lon=20.037926, lat=39.679123, depth=0.000000, plastic_amount=2.122800, time=not_yet_set)
# P[30](lon=20.099967, lat=39.339327, depth=0.000000, plastic_amount=2.921349, time=not_yet_set)
# P[31](lon=20.106946, lat=39.451845, depth=0.000000, plastic_amount=5.521252, time=not_yet_set)
# P[32](lon=20.117647, lat=39.620009, depth=0.000000, plastic_amount=1.265575, time=not_yet_set)
# P[33](lon=20.186793, lat=39.392538, depth=0.000000, plastic_amount=3.296116, time=not_yet_set)
# P[34](lon=20.193835, lat=39.504841, depth=0.000000, plastic_amount=5.505919, time=not_yet_set)
# P[35](lon=20.197401, lat=39.560868, depth=0.000000, plastic_amount=5.493615, time=not_yet_set)
# P[36](lon=20.201000, lat=39.616812, depth=0.000000, plastic_amount=1.102312, time=not_yet_set)
# P[37](lon=20.266672, lat=39.333202, depth=0.000000, plastic_amount=0.805624, time=not_yet_set)
# P[38](lon=20.270145, lat=39.389449, depth=0.000000, plastic_amount=0.839767, time=not_yet_set)
# P[39](lon=20.273649, lat=39.445614, depth=0.000000, plastic_amount=5.373405, time=not_yet_set)
# P[40](lon=20.286868, lat=38.188133, depth=0.000000, plastic_amount=0.525382, time=not_yet_set)
# P[41](lon=20.346579, lat=39.273838, depth=0.000000, plastic_amount=2.854872, time=not_yet_set)
# P[42](lon=20.367365, lat=38.127617, depth=0.000000, plastic_amount=3.810921, time=not_yet_set)
# P[43](lon=20.373100, lat=38.243467, depth=0.000000, plastic_amount=4.787668, time=not_yet_set)
# P[44](lon=20.376009, lat=38.301263, depth=0.000000, plastic_amount=4.776942, time=not_yet_set)
# P[45](lon=20.429926, lat=39.270800, depth=0.000000, plastic_amount=2.853300, time=not_yet_set)
# P[46](lon=20.450714, lat=38.125092, depth=0.000000, plastic_amount=9.677454, time=not_yet_set)
# P[47](lon=20.462296, lat=38.356351, depth=0.000000, plastic_amount=0.700454, time=not_yet_set)
# P[48](lon=20.465263, lat=38.413950, depth=0.000000, plastic_amount=0.698879, time=not_yet_set)
# P[49](lon=20.509861, lat=39.211429, depth=0.000000, plastic_amount=2.736567, time=not_yet_set)
# P[50](lon=20.531237, lat=38.064562, depth=0.000000, plastic_amount=9.696119, time=not_yet_set)
# P[51](lon=20.551604, lat=38.468787, depth=0.000000, plastic_amount=0.697183, time=not_yet_set)
# P[52](lon=20.563872, lat=38.697890, depth=0.000000, plastic_amount=0.855541, time=not_yet_set)
# P[53](lon=20.567012, lat=38.754953, depth=0.000000, plastic_amount=0.936416, time=not_yet_set)
# P[54](lon=20.589825, lat=39.152026, depth=0.000000, plastic_amount=2.234813, time=not_yet_set)
# P[55](lon=20.600872, lat=37.770855, depth=0.000000, plastic_amount=0.460130, time=not_yet_set)
# P[56](lon=20.603559, lat=37.829270, depth=0.000000, plastic_amount=0.459090, time=not_yet_set)
# P[57](lon=20.606274, lat=37.887598, depth=0.000000, plastic_amount=0.458055, time=not_yet_set)
# P[58](lon=20.614584, lat=38.062059, depth=0.000000, plastic_amount=2.119923, time=not_yet_set)
# P[59](lon=20.626052, lat=38.293464, depth=0.000000, plastic_amount=1.283450, time=not_yet_set)
# P[60](lon=20.637973, lat=38.523490, depth=0.000000, plastic_amount=0.889520, time=not_yet_set)
# P[61](lon=20.644106, lat=38.637989, depth=0.000000, plastic_amount=1.042704, time=not_yet_set)
# P[62](lon=20.653526, lat=38.809100, depth=0.000000, plastic_amount=17.584188, time=not_yet_set)
# P[63](lon=20.659953, lat=38.922748, depth=0.000000, plastic_amount=17.505014, time=not_yet_set)
# P[64](lon=20.663212, lat=38.979445, depth=0.000000, plastic_amount=11.243915, time=not_yet_set)
# P[65](lon=20.666500, lat=39.036061, depth=0.000000, plastic_amount=9.238216, time=not_yet_set)
# P[66](lon=20.669819, lat=39.092591, depth=0.000000, plastic_amount=1.481215, time=not_yet_set)
# P[67](lon=20.681557, lat=37.709994, depth=0.000000, plastic_amount=0.279452, time=not_yet_set)
# P[68](lon=20.692362, lat=37.943382, depth=0.000000, plastic_amount=0.469578, time=not_yet_set)
# P[69](lon=20.697930, lat=38.059555, depth=0.000000, plastic_amount=1.100482, time=not_yet_set)
# P[70](lon=20.706488, lat=38.233165, depth=0.000000, plastic_amount=1.285820, time=not_yet_set)
# P[71](lon=20.712333, lat=38.348470, depth=0.000000, plastic_amount=1.280024, time=not_yet_set)
# P[72](lon=20.721317, lat=38.520786, depth=0.000000, plastic_amount=0.812607, time=not_yet_set)
# P[73](lon=20.730560, lat=38.692332, depth=0.000000, plastic_amount=2.588300, time=not_yet_set)
# P[74](lon=20.733699, lat=38.749342, depth=0.000000, plastic_amount=7.147496, time=not_yet_set)
# P[75](lon=20.736868, lat=38.806267, depth=0.000000, plastic_amount=17.576511, time=not_yet_set)
# P[76](lon=20.740067, lat=38.863109, depth=0.000000, plastic_amount=17.536911, time=not_yet_set)
# P[77](lon=20.764902, lat=37.707634, depth=0.000000, plastic_amount=2.435065, time=not_yet_set)
# P[78](lon=20.772965, lat=37.882736, depth=0.000000, plastic_amount=4.120481, time=not_yet_set)
# P[79](lon=20.781274, lat=38.057050, depth=0.000000, plastic_amount=1.100124, time=not_yet_set)
# P[80](lon=20.786950, lat=38.172828, depth=0.000000, plastic_amount=0.966817, time=not_yet_set)
# P[81](lon=20.798641, lat=38.403340, depth=0.000000, plastic_amount=0.816010, time=not_yet_set)
# P[82](lon=20.801636, lat=38.460755, depth=0.000000, plastic_amount=0.814298, time=not_yet_set)
# P[83](lon=20.817041, lat=38.746535, depth=0.000000, plastic_amount=1.800366, time=not_yet_set)
# P[84](lon=20.845612, lat=37.646755, depth=0.000000, plastic_amount=3.630476, time=not_yet_set)
# P[85](lon=20.856307, lat=37.880305, depth=0.000000, plastic_amount=8.017504, time=not_yet_set)
# P[86](lon=20.867440, lat=38.112451, depth=0.000000, plastic_amount=1.096763, time=not_yet_set)
# P[87](lon=20.900380, lat=38.743726, depth=0.000000, plastic_amount=0.873038, time=not_yet_set)
# P[88](lon=20.931588, lat=37.702912, depth=0.000000, plastic_amount=10.968659, time=not_yet_set)
# P[89](lon=20.936934, lat=37.819639, depth=0.000000, plastic_amount=10.919047, time=not_yet_set)
# P[90](lon=20.974389, lat=38.569860, depth=0.000000, plastic_amount=0.572036, time=not_yet_set)
# P[91](lon=20.977468, lat=38.626965, depth=0.000000, plastic_amount=0.876625, time=not_yet_set)
# P[92](lon=20.980578, lat=38.683983, depth=0.000000, plastic_amount=0.874642, time=not_yet_set)
# P[93](lon=21.017588, lat=37.758933, depth=0.000000, plastic_amount=2.503674, time=not_yet_set)
# P[94](lon=21.048660, lat=38.395373, depth=0.000000, plastic_amount=1.058104, time=not_yet_set)
# P[95](lon=21.051653, lat=38.452711, depth=0.000000, plastic_amount=0.813266, time=not_yet_set)
# P[96](lon=21.054675, lat=38.509961, depth=0.000000, plastic_amount=0.783566, time=not_yet_set)
# P[97](lon=21.106327, lat=37.872999, depth=0.000000, plastic_amount=2.779693, time=not_yet_set)
# P[98](lon=21.109069, lat=37.931094, depth=0.000000, plastic_amount=2.697491, time=not_yet_set)
# P[99](lon=21.129032, lat=38.335317, depth=0.000000, plastic_amount=2.143434, time=not_yet_set)
# P[100](lon=21.186952, lat=37.812405, depth=0.000000, plastic_amount=4.609828, time=not_yet_set)
# P[101](lon=21.195175, lat=37.986617, depth=0.000000, plastic_amount=2.647561, time=not_yet_set)
# P[102](lon=21.212367, lat=38.332684, depth=0.000000, plastic_amount=2.142550, time=not_yet_set)
# P[103](lon=21.264942, lat=37.693456, depth=0.000000, plastic_amount=4.825788, time=not_yet_set)
# P[104](lon=21.267601, lat=37.751768, depth=0.000000, plastic_amount=4.815538, time=not_yet_set)
# P[105](lon=21.270288, lat=37.809991, depth=0.000000, plastic_amount=4.803863, time=not_yet_set)
# P[106](lon=21.278510, lat=37.984132, depth=0.000000, plastic_amount=1.948127, time=not_yet_set)
# P[107](lon=21.295700, lat=38.330049, depth=0.000000, plastic_amount=2.141823, time=not_yet_set)
# P[108](lon=21.345645, lat=37.632713, depth=0.000000, plastic_amount=7.329991, time=not_yet_set)
# P[109](lon=21.364639, lat=38.039492, depth=0.000000, plastic_amount=1.892736, time=not_yet_set)
# P[110](lon=21.367461, lat=38.097251, depth=0.000000, plastic_amount=1.888437, time=not_yet_set)
# P[111](lon=21.370312, lat=38.154923, depth=0.000000, plastic_amount=1.062503, time=not_yet_set)
# P[112](lon=21.381996, lat=38.384735, depth=0.000000, plastic_amount=2.135865, time=not_yet_set)
# P[113](lon=21.428979, lat=37.630370, depth=0.000000, plastic_amount=10.191470, time=not_yet_set)
# P[114](lon=21.456523, lat=38.209920, depth=0.000000, plastic_amount=3.648193, time=not_yet_set)
# P[115](lon=21.465325, lat=38.382072, depth=0.000000, plastic_amount=2.134977, time=not_yet_set)
# P[116](lon=21.509708, lat=37.569611, depth=0.000000, plastic_amount=10.213064, time=not_yet_set)
# P[117](lon=21.539852, lat=38.207333, depth=0.000000, plastic_amount=6.471337, time=not_yet_set)
# P[118](lon=21.545691, lat=38.322139, depth=0.000000, plastic_amount=2.139126, time=not_yet_set)
# P[119](lon=21.570776, lat=37.037724, depth=0.000000, plastic_amount=2.321514, time=not_yet_set)
# P[120](lon=21.573147, lat=37.096923, depth=0.000000, plastic_amount=2.415778, time=not_yet_set)
# P[121](lon=21.575543, lat=37.156033, depth=0.000000, plastic_amount=2.573634, time=not_yet_set)
# P[122](lon=21.577966, lat=37.215054, depth=0.000000, plastic_amount=4.107001, time=not_yet_set)
# P[123](lon=21.587912, lat=37.450235, depth=0.000000, plastic_amount=3.291285, time=not_yet_set)
# P[124](lon=21.590463, lat=37.508807, depth=0.000000, plastic_amount=3.283771, time=not_yet_set)
# P[125](lon=21.623180, lat=38.204744, depth=0.000000, plastic_amount=12.312961, time=not_yet_set)
# P[126](lon=21.629019, lat=38.319501, depth=0.000000, plastic_amount=0.835849, time=not_yet_set)
# P[127](lon=21.647148, lat=36.857536, depth=0.000000, plastic_amount=1.401012, time=not_yet_set)
# P[128](lon=21.649443, lat=36.916984, depth=0.000000, plastic_amount=1.397817, time=not_yet_set)
# P[129](lon=21.651764, lat=36.976342, depth=0.000000, plastic_amount=1.917721, time=not_yet_set)
# P[130](lon=21.663745, lat=37.271778, depth=0.000000, plastic_amount=4.096094, time=not_yet_set)
# P[131](lon=21.666218, lat=37.330595, depth=0.000000, plastic_amount=4.086736, time=not_yet_set)
# P[132](lon=21.668718, lat=37.389324, depth=0.000000, plastic_amount=1.415795, time=not_yet_set)
# P[133](lon=21.706507, lat=38.202155, depth=0.000000, plastic_amount=52.260674, time=not_yet_set)
# P[134](lon=21.712346, lat=38.316861, depth=0.000000, plastic_amount=52.021900, time=not_yet_set)
# P[135](lon=21.728211, lat=36.795971, depth=0.000000, plastic_amount=0.744045, time=not_yet_set)
# P[136](lon=21.792736, lat=38.256935, depth=0.000000, plastic_amount=52.131847, time=not_yet_set)
# P[137](lon=21.795670, lat=38.314220, depth=0.000000, plastic_amount=52.004166, time=not_yet_set)
# P[138](lon=21.798631, lat=38.371416, depth=0.000000, plastic_amount=23.730331, time=not_yet_set)
# P[139](lon=21.811544, lat=36.793945, depth=0.000000, plastic_amount=0.723500, time=not_yet_set)
# P[140](lon=21.881954, lat=38.368750, depth=0.000000, plastic_amount=14.152944, time=not_yet_set)
# P[141](lon=21.884943, lat=38.425831, depth=0.000000, plastic_amount=14.120600, time=not_yet_set)
# P[142](lon=21.892629, lat=36.732353, depth=0.000000, plastic_amount=2.607292, time=not_yet_set)
# P[143](lon=21.962314, lat=38.308936, depth=0.000000, plastic_amount=3.537744, time=not_yet_set)
# P[144](lon=21.968264, lat=38.423138, depth=0.000000, plastic_amount=1.448754, time=not_yet_set)
# P[145](lon=21.978205, lat=36.789889, depth=0.000000, plastic_amount=3.977608, time=not_yet_set)
# P[146](lon=21.980474, lat=36.849341, depth=0.000000, plastic_amount=3.969045, time=not_yet_set)
# P[147](lon=21.982769, lat=36.908701, depth=0.000000, plastic_amount=1.721706, time=not_yet_set)
# P[148](lon=21.985088, lat=36.967970, depth=0.000000, plastic_amount=14.081750, time=not_yet_set)
# P[149](lon=21.987433, lat=37.027147, depth=0.000000, plastic_amount=14.051447, time=not_yet_set)
# P[150](lon=22.045634, lat=38.306292, depth=0.000000, plastic_amount=15.060108, time=not_yet_set)
# P[151](lon=22.051582, lat=38.420445, depth=0.000000, plastic_amount=1.090384, time=not_yet_set)
# P[152](lon=22.070760, lat=37.025030, depth=0.000000, plastic_amount=24.061647, time=not_yet_set)
# P[153](lon=22.126021, lat=38.246467, depth=0.000000, plastic_amount=15.087214, time=not_yet_set)
# P[154](lon=22.131912, lat=38.360743, depth=0.000000, plastic_amount=0.772715, time=not_yet_set)
# P[155](lon=22.151744, lat=36.963778, depth=0.000000, plastic_amount=24.108202, time=not_yet_set)
# P[156](lon=22.154087, lat=37.022911, depth=0.000000, plastic_amount=24.052826, time=not_yet_set)
# P[157](lon=22.209339, lat=38.243847, depth=0.000000, plastic_amount=3.861370, time=not_yet_set)
# P[158](lon=22.215228, lat=38.358075, depth=0.000000, plastic_amount=1.819084, time=not_yet_set)
# P[159](lon=22.230458, lat=36.843189, depth=0.000000, plastic_amount=1.987151, time=not_yet_set)
# P[160](lon=22.232752, lat=36.902481, depth=0.000000, plastic_amount=1.951270, time=not_yet_set)
# P[161](lon=22.289754, lat=38.184006, depth=0.000000, plastic_amount=4.200849, time=not_yet_set)
# P[162](lon=22.298542, lat=38.355403, depth=0.000000, plastic_amount=1.818458, time=not_yet_set)
# P[163](lon=22.309271, lat=36.722321, depth=0.000000, plastic_amount=0.708325, time=not_yet_set)
# P[164](lon=22.311515, lat=36.781774, depth=0.000000, plastic_amount=1.990594, time=not_yet_set)
# P[165](lon=22.373069, lat=38.181411, depth=0.000000, plastic_amount=4.198721, time=not_yet_set)
# P[166](lon=22.383865, lat=36.481667, depth=0.000000, plastic_amount=0.285439, time=not_yet_set)
# P[167](lon=22.384841, lat=38.409662, depth=0.000000, plastic_amount=6.891942, time=not_yet_set)
# P[168](lon=22.386012, lat=36.541466, depth=0.000000, plastic_amount=0.321510, time=not_yet_set)
# P[169](lon=22.388183, lat=36.601173, depth=0.000000, plastic_amount=0.711345, time=not_yet_set)
# P[170](lon=22.390377, lat=36.660789, depth=0.000000, plastic_amount=0.709710, time=not_yet_set)
# P[171](lon=22.456382, lat=38.178815, depth=0.000000, plastic_amount=2.708175, time=not_yet_set)
# P[172](lon=22.465069, lat=36.419873, depth=0.000000, plastic_amount=0.286017, time=not_yet_set)
# P[173](lon=22.465166, lat=38.350060, depth=0.000000, plastic_amount=0.747852, time=not_yet_set)
# P[174](lon=22.468151, lat=38.406963, depth=0.000000, plastic_amount=6.888978, time=not_yet_set)
# P[175](lon=22.536822, lat=38.118981, depth=0.000000, plastic_amount=5.326966, time=not_yet_set)
# P[176](lon=22.545521, lat=38.290417, depth=0.000000, plastic_amount=0.479014, time=not_yet_set)
# P[177](lon=22.550516, lat=36.477821, depth=0.000000, plastic_amount=0.282951, time=not_yet_set)
# P[178](lon=22.552663, lat=36.537577, depth=0.000000, plastic_amount=0.344378, time=not_yet_set)
# P[179](lon=22.554833, lat=36.597242, depth=0.000000, plastic_amount=0.343585, time=not_yet_set)
# P[180](lon=22.557028, lat=36.656816, depth=0.000000, plastic_amount=2.560405, time=not_yet_set)
# P[181](lon=22.559245, lat=36.716295, depth=0.000000, plastic_amount=2.554488, time=not_yet_set)
# P[182](lon=22.561488, lat=36.775682, depth=0.000000, plastic_amount=2.548596, time=not_yet_set)
# P[183](lon=22.567677, lat=40.019455, depth=0.000000, plastic_amount=1.496459, time=not_yet_set)
# P[184](lon=22.571577, lat=40.073784, depth=0.000000, plastic_amount=1.448460, time=not_yet_set)
# P[185](lon=22.575511, lat=40.128030, depth=0.000000, plastic_amount=14.128959, time=not_yet_set)
# P[186](lon=22.579477, lat=40.182190, depth=0.000000, plastic_amount=14.096687, time=not_yet_set)
# P[187](lon=22.583475, lat=40.236267, depth=0.000000, plastic_amount=14.955000, time=not_yet_set)
# P[188](lon=22.587506, lat=40.290263, depth=0.000000, plastic_amount=14.920880, time=not_yet_set)
# P[189](lon=22.620133, lat=38.116407, depth=0.000000, plastic_amount=5.324284, time=not_yet_set)
# P[190](lon=22.631785, lat=38.344711, depth=0.000000, plastic_amount=1.172762, time=not_yet_set)
# P[191](lon=22.644811, lat=36.773651, depth=0.000000, plastic_amount=2.547696, time=not_yet_set)
# P[192](lon=22.650960, lat=40.015967, depth=0.000000, plastic_amount=1.495848, time=not_yet_set)
# P[193](lon=22.674847, lat=40.340512, depth=0.000000, plastic_amount=5.800764, time=not_yet_set)
# P[194](lon=22.678944, lat=40.394313, depth=0.000000, plastic_amount=2.131997, time=not_yet_set)
# P[195](lon=22.683075, lat=40.448033, depth=0.000000, plastic_amount=1.617998, time=not_yet_set)
# P[196](lon=22.687239, lat=40.501671, depth=0.000000, plastic_amount=1.324866, time=not_yet_set)
# P[197](lon=22.691436, lat=40.555226, depth=0.000000, plastic_amount=1.642113, time=not_yet_set)
# P[198](lon=22.700602, lat=38.056561, depth=0.000000, plastic_amount=29.239044, time=not_yet_set)
# P[199](lon=22.715092, lat=38.342038, depth=0.000000, plastic_amount=1.172268, time=not_yet_set)
# P[200](lon=22.726541, lat=39.903686, depth=0.000000, plastic_amount=1.203512, time=not_yet_set)
# P[201](lon=22.728131, lat=36.771619, depth=0.000000, plastic_amount=1.578222, time=not_yet_set)
# P[202](lon=22.730375, lat=39.958123, depth=0.000000, plastic_amount=0.748497, time=not_yet_set)
# P[203](lon=22.754443, lat=37.418327, depth=0.000000, plastic_amount=3.504982, time=not_yet_set)
# P[204](lon=22.756988, lat=37.476569, depth=0.000000, plastic_amount=13.118718, time=not_yet_set)
# P[205](lon=22.759559, lat=37.534720, depth=0.000000, plastic_amount=27.931038, time=not_yet_set)
# P[206](lon=22.770507, lat=40.497914, depth=0.000000, plastic_amount=8.290431, time=not_yet_set)
# P[207](lon=22.774703, lat=40.551440, depth=0.000000, plastic_amount=10.468804, time=not_yet_set)
# P[208](lon=22.783910, lat=38.054013, depth=0.000000, plastic_amount=29.233871, time=not_yet_set)
# P[209](lon=22.795444, lat=38.282472, depth=0.000000, plastic_amount=2.613688, time=not_yet_set)
# P[210](lon=22.806022, lat=39.845758, depth=0.000000, plastic_amount=0.393048, time=not_yet_set)
# P[211](lon=22.809209, lat=36.710264, depth=0.000000, plastic_amount=1.219395, time=not_yet_set)
# P[212](lon=22.811451, lat=36.769586, depth=0.000000, plastic_amount=1.216573, time=not_yet_set)
# P[213](lon=22.830278, lat=37.240839, depth=0.000000, plastic_amount=0.685246, time=not_yet_set)
# P[214](lon=22.832745, lat=37.299332, depth=0.000000, plastic_amount=0.661827, time=not_yet_set)
# P[215](lon=22.835239, lat=37.357734, depth=0.000000, plastic_amount=3.511519, time=not_yet_set)
# P[216](lon=22.842873, lat=37.532389, depth=0.000000, plastic_amount=27.913792, time=not_yet_set)
# P[217](lon=22.846178, lat=39.182156, depth=0.000000, plastic_amount=1.082616, time=not_yet_set)
# P[218](lon=22.849612, lat=40.440579, depth=0.000000, plastic_amount=17.172153, time=not_yet_set)
# P[219](lon=22.853055, lat=39.293046, depth=0.000000, plastic_amount=9.520848, time=not_yet_set)
# P[220](lon=22.857967, lat=40.547653, depth=0.000000, plastic_amount=250.111557, time=not_yet_set)
# P[221](lon=22.862196, lat=40.601067, depth=0.000000, plastic_amount=249.541183, time=not_yet_set)
# P[222](lon=22.864404, lat=37.994148, depth=0.000000, plastic_amount=30.691927, time=not_yet_set)
# P[223](lon=22.867217, lat=38.051463, depth=0.000000, plastic_amount=16.082407, time=not_yet_set)
# P[224](lon=22.873438, lat=36.170374, depth=0.000000, plastic_amount=0.359770, time=not_yet_set)
# P[225](lon=22.874426, lat=39.623652, depth=0.000000, plastic_amount=0.903585, time=not_yet_set)
# P[226](lon=22.875465, lat=36.230511, depth=0.000000, plastic_amount=0.300506, time=not_yet_set)
# P[227](lon=22.875824, lat=38.222865, depth=0.000000, plastic_amount=0.198687, time=not_yet_set)
# P[228](lon=22.877516, lat=36.290554, depth=0.000000, plastic_amount=0.299812, time=not_yet_set)
# P[229](lon=22.878097, lat=39.678456, depth=0.000000, plastic_amount=0.901503, time=not_yet_set)
# P[230](lon=22.881801, lat=39.733174, depth=0.000000, plastic_amount=0.899595, time=not_yet_set)
# P[231](lon=22.885536, lat=39.787805, depth=0.000000, plastic_amount=0.393796, time=not_yet_set)
# P[232](lon=22.888119, lat=36.589378, depth=0.000000, plastic_amount=0.961872, time=not_yet_set)
# P[233](lon=22.890312, lat=36.648861, depth=0.000000, plastic_amount=1.221796, time=not_yet_set)
# P[234](lon=22.911152, lat=37.180061, depth=0.000000, plastic_amount=0.664662, time=not_yet_set)
# P[235](lon=22.926077, lat=39.123537, depth=0.000000, plastic_amount=0.916331, time=not_yet_set)
# P[236](lon=22.926186, lat=37.530060, depth=0.000000, plastic_amount=2.669252, time=not_yet_set)
# P[237](lon=22.928750, lat=40.383221, depth=0.000000, plastic_amount=7.389300, time=not_yet_set)
# P[238](lon=22.932891, lat=39.234546, depth=0.000000, plastic_amount=53.688801, time=not_yet_set)
# P[239](lon=22.939827, lat=39.345208, depth=0.000000, plastic_amount=53.440159, time=not_yet_set)
# P[240](lon=22.941230, lat=40.543864, depth=0.000000, plastic_amount=250.054535, time=not_yet_set)
# P[241](lon=22.945457, lat=40.597247, depth=0.000000, plastic_amount=249.432861, time=not_yet_set)
# P[242](lon=22.953363, lat=38.106112, depth=0.000000, plastic_amount=2.002357, time=not_yet_set)
# P[243](lon=22.954757, lat=36.108344, depth=0.000000, plastic_amount=0.538294, time=not_yet_set)
# P[244](lon=22.957708, lat=39.620358, depth=0.000000, plastic_amount=0.146064, time=not_yet_set)
# P[245](lon=22.959127, lat=38.220238, depth=0.000000, plastic_amount=1.993052, time=not_yet_set)
# P[246](lon=22.962910, lat=36.348626, depth=0.000000, plastic_amount=0.897102, time=not_yet_set)
# P[247](lon=22.969270, lat=36.527852, depth=0.000000, plastic_amount=1.094126, time=not_yet_set)
# P[248](lon=22.989661, lat=37.060519, depth=0.000000, plastic_amount=0.188103, time=not_yet_set)
# P[249](lon=22.992051, lat=37.119242, depth=0.000000, plastic_amount=0.187666, time=not_yet_set)
# P[250](lon=23.002675, lat=39.009191, depth=0.000000, plastic_amount=0.760128, time=not_yet_set)
# P[251](lon=23.006006, lat=39.064884, depth=0.000000, plastic_amount=0.824205, time=not_yet_set)
# P[252](lon=23.006926, lat=37.469646, depth=0.000000, plastic_amount=1.053877, time=not_yet_set)
# P[253](lon=23.012014, lat=40.379521, depth=0.000000, plastic_amount=4.572158, time=not_yet_set)
# P[254](lon=23.023113, lat=39.342054, depth=0.000000, plastic_amount=17.244383, time=not_yet_set)
# P[255](lon=23.025474, lat=37.874297, depth=0.000000, plastic_amount=7.840953, time=not_yet_set)
# P[256](lon=23.028232, lat=37.931743, depth=0.000000, plastic_amount=7.821469, time=not_yet_set)
# P[257](lon=23.033745, lat=39.507318, depth=0.000000, plastic_amount=1.078546, time=not_yet_set)
# P[258](lon=23.036668, lat=38.103536, depth=0.000000, plastic_amount=2.001678, time=not_yet_set)
# P[259](lon=23.037352, lat=39.562233, depth=0.000000, plastic_amount=0.145601, time=not_yet_set)
# P[260](lon=23.038079, lat=36.106546, depth=0.000000, plastic_amount=0.562894, time=not_yet_set)
# P[261](lon=23.042431, lat=38.217613, depth=0.000000, plastic_amount=1.992691, time=not_yet_set)
# P[262](lon=23.046230, lat=36.346743, depth=0.000000, plastic_amount=0.896733, time=not_yet_set)
# P[263](lon=23.050447, lat=36.466278, depth=0.000000, plastic_amount=3.397700, time=not_yet_set)
# P[264](lon=23.056949, lat=36.644882, depth=0.000000, plastic_amount=2.131208, time=not_yet_set)
# P[265](lon=23.059165, lat=36.704231, depth=0.000000, plastic_amount=2.126251, time=not_yet_set)
# P[266](lon=23.063669, lat=36.822648, depth=0.000000, plastic_amount=0.242306, time=not_yet_set)
# P[267](lon=23.065959, lat=36.881718, depth=0.000000, plastic_amount=0.132830, time=not_yet_set)
# P[268](lon=23.068273, lat=36.940695, depth=0.000000, plastic_amount=0.132521, time=not_yet_set)
# P[269](lon=23.070611, lat=36.999579, depth=0.000000, plastic_amount=0.132214, time=not_yet_set)
# P[270](lon=23.085965, lat=39.006200, depth=0.000000, plastic_amount=2.189426, time=not_yet_set)
# P[271](lon=23.087693, lat=37.409189, depth=0.000000, plastic_amount=1.558278, time=not_yet_set)
# P[272](lon=23.091186, lat=40.322168, depth=0.000000, plastic_amount=5.009683, time=not_yet_set)
# P[273](lon=23.102915, lat=39.283664, depth=0.000000, plastic_amount=5.945736, time=not_yet_set)
# P[274](lon=23.108780, lat=37.871820, depth=0.000000, plastic_amount=1.282059, time=not_yet_set)
# P[275](lon=23.111537, lat=37.929241, depth=0.000000, plastic_amount=1.581756, time=not_yet_set)
# P[276](lon=23.113451, lat=39.449104, depth=0.000000, plastic_amount=1.158598, time=not_yet_set)
# P[277](lon=23.119971, lat=38.100958, depth=0.000000, plastic_amount=1.609651, time=not_yet_set)
# P[278](lon=23.120629, lat=39.558965, depth=0.000000, plastic_amount=0.448007, time=not_yet_set)
# P[279](lon=23.123403, lat=36.164916, depth=0.000000, plastic_amount=0.561405, time=not_yet_set)
# P[280](lon=23.125428, lat=36.224991, depth=0.000000, plastic_amount=0.560105, time=not_yet_set)
# P[281](lon=23.125732, lat=38.214988, depth=0.000000, plastic_amount=0.843941, time=not_yet_set)
# P[282](lon=23.127478, lat=36.284973, depth=0.000000, plastic_amount=0.133312, time=not_yet_set)
# P[283](lon=23.133764, lat=36.464355, depth=0.000000, plastic_amount=3.396521, time=not_yet_set)
# P[284](lon=23.138075, lat=36.583474, depth=0.000000, plastic_amount=3.380772, time=not_yet_set)
# P[285](lon=23.144721, lat=36.761451, depth=0.000000, plastic_amount=2.120561, time=not_yet_set)
# P[286](lon=23.168486, lat=37.348686, depth=0.000000, plastic_amount=2.791401, time=not_yet_set)
# P[287](lon=23.169253, lat=39.003207, depth=0.000000, plastic_amount=2.188201, time=not_yet_set)
# P[288](lon=23.170391, lat=40.264791, depth=0.000000, plastic_amount=5.019090, time=not_yet_set)
# P[289](lon=23.179329, lat=39.169865, depth=0.000000, plastic_amount=0.819609, time=not_yet_set)
# P[290](lon=23.181331, lat=37.638854, depth=0.000000, plastic_amount=1.455262, time=not_yet_set)
# P[291](lon=23.182747, lat=39.225244, depth=0.000000, plastic_amount=0.817710, time=not_yet_set)
# P[292](lon=23.183979, lat=37.696613, depth=0.000000, plastic_amount=1.451866, time=not_yet_set)
# P[293](lon=23.186654, lat=37.754279, depth=0.000000, plastic_amount=3.300664, time=not_yet_set)
# P[294](lon=23.189355, lat=37.811855, depth=0.000000, plastic_amount=3.292961, time=not_yet_set)
# P[295](lon=23.193188, lat=39.390859, depth=0.000000, plastic_amount=1.160622, time=not_yet_set)
# P[296](lon=23.197623, lat=37.984043, depth=0.000000, plastic_amount=1.616523, time=not_yet_set)
# P[297](lon=23.200303, lat=39.500837, depth=0.000000, plastic_amount=1.155234, time=not_yet_set)
# P[298](lon=23.203271, lat=38.098379, depth=0.000000, plastic_amount=1.608985, time=not_yet_set)
# P[299](lon=23.206137, lat=38.155414, depth=0.000000, plastic_amount=0.530725, time=not_yet_set)
# P[300](lon=23.219224, lat=36.522014, depth=0.000000, plastic_amount=0.288297, time=not_yet_set)
# P[301](lon=23.241686, lat=40.099616, depth=0.000000, plastic_amount=1.588563, time=not_yet_set)
# P[302](lon=23.245642, lat=40.153544, depth=0.000000, plastic_amount=9.535212, time=not_yet_set)
# P[303](lon=23.249630, lat=40.207386, depth=0.000000, plastic_amount=9.513323, time=not_yet_set)
# P[304](lon=23.251795, lat=37.346425, depth=0.000000, plastic_amount=2.322660, time=not_yet_set)
# P[305](lon=23.253651, lat=40.261147, depth=0.000000, plastic_amount=9.491331, time=not_yet_set)
# P[306](lon=23.255867, lat=39.055828, depth=0.000000, plastic_amount=1.597768, time=not_yet_set)
# P[307](lon=23.259224, lat=39.111354, depth=0.000000, plastic_amount=0.735300, time=not_yet_set)
# P[308](lon=23.262016, lat=37.578645, depth=0.000000, plastic_amount=1.208942, time=not_yet_set)
# P[309](lon=23.267283, lat=37.694208, depth=0.000000, plastic_amount=1.451618, time=not_yet_set)
# P[310](lon=23.269478, lat=39.277405, depth=0.000000, plastic_amount=0.565848, time=not_yet_set)
# P[311](lon=23.272957, lat=39.332582, depth=0.000000, plastic_amount=0.485518, time=not_yet_set)
# P[312](lon=23.280925, lat=37.981513, depth=0.000000, plastic_amount=1.615982, time=not_yet_set)
# P[313](lon=23.317138, lat=39.988012, depth=0.000000, plastic_amount=0.902810, time=not_yet_set)
# P[314](lon=23.321026, lat=40.042076, depth=0.000000, plastic_amount=1.124520, time=not_yet_set)
# P[315](lon=23.335824, lat=38.997220, depth=0.000000, plastic_amount=0.470617, time=not_yet_set)
# P[316](lon=23.337619, lat=37.402331, depth=0.000000, plastic_amount=0.948390, time=not_yet_set)
# P[317](lon=23.345321, lat=37.576287, depth=0.000000, plastic_amount=1.344283, time=not_yet_set)
# P[318](lon=23.345893, lat=39.163716, depth=0.000000, plastic_amount=2.024909, time=not_yet_set)
# P[319](lon=23.347941, lat=37.634089, depth=0.000000, plastic_amount=1.454092, time=not_yet_set)
# P[320](lon=23.349310, lat=39.219039, depth=0.000000, plastic_amount=2.020559, time=not_yet_set)
# P[321](lon=23.353260, lat=37.749419, depth=0.000000, plastic_amount=3.297975, time=not_yet_set)
# P[322](lon=23.364224, lat=37.978984, depth=0.000000, plastic_amount=11.582073, time=not_yet_set)
# P[323](lon=23.396546, lat=39.930392, depth=0.000000, plastic_amount=0.804482, time=not_yet_set)
# P[324](lon=23.412159, lat=40.146371, depth=0.000000, plastic_amount=1.615658, time=not_yet_set)
# P[325](lon=23.415811, lat=38.938579, depth=0.000000, plastic_amount=0.431852, time=not_yet_set)
# P[326](lon=23.416144, lat=40.200156, depth=0.000000, plastic_amount=1.612247, time=not_yet_set)
# P[327](lon=23.420162, lat=40.253858, depth=0.000000, plastic_amount=1.608206, time=not_yet_set)
# P[328](lon=23.420924, lat=37.400044, depth=0.000000, plastic_amount=1.490935, time=not_yet_set)
# P[329](lon=23.425787, lat=39.105256, depth=0.000000, plastic_amount=2.028485, time=not_yet_set)
# P[330](lon=23.426031, lat=37.516060, depth=0.000000, plastic_amount=1.483964, time=not_yet_set)
# P[331](lon=23.431244, lat=37.631706, depth=0.000000, plastic_amount=1.477024, time=not_yet_set)
# P[332](lon=23.432588, lat=39.215935, depth=0.000000, plastic_amount=2.019050, time=not_yet_set)
# P[333](lon=23.439261, lat=37.804493, depth=0.000000, plastic_amount=4.499053, time=not_yet_set)
# P[334](lon=23.447523, lat=37.976457, depth=0.000000, plastic_amount=21.908297, time=not_yet_set)
# P[335](lon=23.479807, lat=39.926921, depth=0.000000, plastic_amount=1.127356, time=not_yet_set)
# P[336](lon=23.491464, lat=40.088944, depth=0.000000, plastic_amount=1.911392, time=not_yet_set)
# P[337](lon=23.499093, lat=38.935611, depth=0.000000, plastic_amount=0.779247, time=not_yet_set)
# P[338](lon=23.503415, lat=40.250212, depth=0.000000, plastic_amount=1.034677, time=not_yet_set)
# P[339](lon=23.506769, lat=37.455786, depth=0.000000, plastic_amount=1.486975, time=not_yet_set)
# P[340](lon=23.512450, lat=39.157561, depth=0.000000, plastic_amount=2.022813, time=not_yet_set)
# P[341](lon=23.514016, lat=35.306269, depth=0.000000, plastic_amount=0.182342, time=not_yet_set)
# P[342](lon=23.515730, lat=35.367570, depth=0.000000, plastic_amount=0.594188, time=not_yet_set)
# P[343](lon=23.517191, lat=37.686986, depth=0.000000, plastic_amount=3.303832, time=not_yet_set)
# P[344](lon=23.517466, lat=35.428775, depth=0.000000, plastic_amount=0.593150, time=not_yet_set)
# P[345](lon=23.519222, lat=35.489885, depth=0.000000, plastic_amount=0.591780, time=not_yet_set)
# P[346](lon=23.522562, lat=37.802037, depth=0.000000, plastic_amount=4.497572, time=not_yet_set)
# P[347](lon=23.528040, lat=37.916721, depth=0.000000, plastic_amount=152.593750, time=not_yet_set)
# P[348](lon=23.563066, lat=39.923450, depth=0.000000, plastic_amount=1.476716, time=not_yet_set)
# P[349](lon=23.570801, lat=40.031494, depth=0.000000, plastic_amount=1.469873, time=not_yet_set)
# P[350](lon=23.579110, lat=38.876959, depth=0.000000, plastic_amount=0.807136, time=not_yet_set)
# P[351](lon=23.586664, lat=40.246564, depth=0.000000, plastic_amount=1.034141, time=not_yet_set)
# P[352](lon=23.595645, lat=35.243351, depth=0.000000, plastic_amount=0.737023, time=not_yet_set)
# P[353](lon=23.595726, lat=39.154483, depth=0.000000, plastic_amount=2.022043, time=not_yet_set)
# P[354](lon=23.603162, lat=37.742126, depth=0.000000, plastic_amount=2.402487, time=not_yet_set)
# P[355](lon=23.604321, lat=35.549282, depth=0.000000, plastic_amount=4.680054, time=not_yet_set)
# P[356](lon=23.611337, lat=37.914216, depth=0.000000, plastic_amount=261.863434, time=not_yet_set)
# P[357](lon=23.634341, lat=38.369125, depth=0.000000, plastic_amount=14.685347, time=not_yet_set)
# P[358](lon=23.646322, lat=39.919978, depth=0.000000, plastic_amount=1.476107, time=not_yet_set)
# P[359](lon=23.654055, lat=40.027962, depth=0.000000, plastic_amount=1.469550, time=not_yet_set)
# P[360](lon=23.659157, lat=38.818274, depth=0.000000, plastic_amount=0.140533, time=not_yet_set)
# P[361](lon=23.665898, lat=40.189305, depth=0.000000, plastic_amount=0.652234, time=not_yet_set)
# P[362](lon=23.675618, lat=39.096104, depth=0.000000, plastic_amount=1.072914, time=not_yet_set)
# P[363](lon=23.678965, lat=35.241826, depth=0.000000, plastic_amount=0.736844, time=not_yet_set)
# P[364](lon=23.682412, lat=39.206619, depth=0.000000, plastic_amount=1.452665, time=not_yet_set)
# P[365](lon=23.687639, lat=35.547665, depth=0.000000, plastic_amount=4.679435, time=not_yet_set)
# P[366](lon=23.694631, lat=37.911711, depth=0.000000, plastic_amount=312.230865, time=not_yet_set)
# P[367](lon=23.703210, lat=40.668807, depth=0.000000, plastic_amount=2.969307, time=not_yet_set)
# P[368](lon=23.707524, lat=40.721671, depth=0.000000, plastic_amount=2.961854, time=not_yet_set)
# P[369](lon=23.717628, lat=38.366417, depth=0.000000, plastic_amount=10.773165, time=not_yet_set)
# P[370](lon=23.720629, lat=38.422849, depth=0.000000, plastic_amount=32.233654, time=not_yet_set)
# P[371](lon=23.733426, lat=39.970511, depth=0.000000, plastic_amount=0.595963, time=not_yet_set)
# P[372](lon=23.739234, lat=38.759554, depth=0.000000, plastic_amount=0.098720, time=not_yet_set)
# P[373](lon=23.745166, lat=40.132019, depth=0.000000, plastic_amount=0.653206, time=not_yet_set)
# P[374](lon=23.753156, lat=40.239269, depth=0.000000, plastic_amount=0.650178, time=not_yet_set)
# P[375](lon=23.757200, lat=40.292767, depth=0.000000, plastic_amount=0.534654, time=not_yet_set)
# P[376](lon=23.761277, lat=40.346180, depth=0.000000, plastic_amount=0.490728, time=not_yet_set)
# P[377](lon=23.762271, lat=39.148327, depth=0.000000, plastic_amount=0.748082, time=not_yet_set)
# P[378](lon=23.762285, lat=35.240303, depth=0.000000, plastic_amount=0.698113, time=not_yet_set)
# P[379](lon=23.770957, lat=35.546046, depth=0.000000, plastic_amount=3.195050, time=not_yet_set)
# P[380](lon=23.775175, lat=37.851984, depth=0.000000, plastic_amount=68.197868, time=not_yet_set)
# P[381](lon=23.782163, lat=40.612003, depth=0.000000, plastic_amount=2.973572, time=not_yet_set)
# P[382](lon=23.795100, lat=40.770503, depth=0.000000, plastic_amount=1.863521, time=not_yet_set)
# P[383](lon=23.800915, lat=38.363711, depth=0.000000, plastic_amount=9.626162, time=not_yet_set)
# P[384](lon=23.803915, lat=38.420116, depth=0.000000, plastic_amount=9.601918, time=not_yet_set)
# P[385](lon=23.820555, lat=40.020901, depth=0.000000, plastic_amount=0.476631, time=not_yet_set)
# P[386](lon=23.822512, lat=38.756664, depth=0.000000, plastic_amount=0.193175, time=not_yet_set)
# P[387](lon=23.824467, lat=40.074707, depth=0.000000, plastic_amount=0.597973, time=not_yet_set)
# P[388](lon=23.832388, lat=40.182064, depth=0.000000, plastic_amount=0.595197, time=not_yet_set)
# P[389](lon=23.842162, lat=39.090002, depth=0.000000, plastic_amount=0.749554, time=not_yet_set)
# P[390](lon=23.844517, lat=40.342472, depth=0.000000, plastic_amount=1.134161, time=not_yet_set)
# P[391](lon=23.845606, lat=35.238782, depth=0.000000, plastic_amount=0.603126, time=not_yet_set)
# P[392](lon=23.848951, lat=39.200406, depth=0.000000, plastic_amount=0.746178, time=not_yet_set)
# P[393](lon=23.852768, lat=40.448989, depth=0.000000, plastic_amount=1.124960, time=not_yet_set)
# P[394](lon=23.854275, lat=35.544426, depth=0.000000, plastic_amount=3.228604, time=not_yet_set)
# P[395](lon=23.855746, lat=37.792211, depth=0.000000, plastic_amount=18.224497, time=not_yet_set)
# P[396](lon=23.856943, lat=40.502125, depth=0.000000, plastic_amount=1.097130, time=not_yet_set)
# P[397](lon=23.861151, lat=40.555175, depth=0.000000, plastic_amount=1.063513, time=not_yet_set)
# P[398](lon=23.878324, lat=40.766551, depth=0.000000, plastic_amount=1.467511, time=not_yet_set)
# P[399](lon=23.881229, lat=38.304534, depth=0.000000, plastic_amount=2.920314, time=not_yet_set)
# P[400](lon=23.887198, lat=38.417382, depth=0.000000, plastic_amount=3.093626, time=not_yet_set)
# P[401](lon=23.899924, lat=39.963507, depth=0.000000, plastic_amount=0.470885, time=not_yet_set)
# P[402](lon=23.902618, lat=38.697931, depth=0.000000, plastic_amount=0.300787, time=not_yet_set)
# P[403](lon=23.915630, lat=40.178445, depth=0.000000, plastic_amount=0.434849, time=not_yet_set)
# P[404](lon=23.927753, lat=40.338762, depth=0.000000, plastic_amount=1.179712, time=not_yet_set)
# P[405](lon=23.928810, lat=39.142169, depth=0.000000, plastic_amount=0.331823, time=not_yet_set)
# P[406](lon=23.928924, lat=35.237259, depth=0.000000, plastic_amount=0.144763, time=not_yet_set)
# P[407](lon=23.936001, lat=40.445219, depth=0.000000, plastic_amount=1.174009, time=not_yet_set)
# P[408](lon=23.936345, lat=37.732395, depth=0.000000, plastic_amount=7.849291, time=not_yet_set)
# P[409](lon=23.937592, lat=35.542806, depth=0.000000, plastic_amount=20.581806, time=not_yet_set)
# P[410](lon=23.939124, lat=39.307300, depth=0.000000, plastic_amount=0.329492, time=not_yet_set)
# P[411](lon=23.961546, lat=40.762598, depth=0.000000, plastic_amount=1.466855, time=not_yet_set)
# P[412](lon=23.961572, lat=38.245315, depth=0.000000, plastic_amount=2.153924, time=not_yet_set)
# P[413](lon=23.970479, lat=38.414648, depth=0.000000, plastic_amount=2.465050, time=not_yet_set)
# P[414](lon=23.985895, lat=38.695065, depth=0.000000, plastic_amount=1.206488, time=not_yet_set)
# P[415](lon=23.987047, lat=40.013835, depth=0.000000, plastic_amount=0.304131, time=not_yet_set)
# P[416](lon=23.994897, lat=40.121246, depth=0.000000, plastic_amount=0.361698, time=not_yet_set)
# P[417](lon=24.002530, lat=34.866013, depth=0.000000, plastic_amount=0.090026, time=not_yet_set)
# P[418](lon=24.006915, lat=40.281727, depth=0.000000, plastic_amount=1.169595, time=not_yet_set)
# P[419](lon=24.010571, lat=35.174359, depth=0.000000, plastic_amount=0.047760, time=not_yet_set)
# P[420](lon=24.016971, lat=37.672537, depth=0.000000, plastic_amount=6.647662, time=not_yet_set)
# P[421](lon=24.018919, lat=39.249209, depth=0.000000, plastic_amount=0.330111, time=not_yet_set)
# P[422](lon=24.019231, lat=40.441449, depth=0.000000, plastic_amount=1.173241, time=not_yet_set)
# P[423](lon=24.020908, lat=35.541187, depth=0.000000, plastic_amount=74.086472, time=not_yet_set)
# P[424](lon=24.025885, lat=39.358978, depth=0.000000, plastic_amount=0.328562, time=not_yet_set)
# P[425](lon=24.027798, lat=37.901687, depth=0.000000, plastic_amount=21.010952, time=not_yet_set)
# P[426](lon=24.030572, lat=37.958744, depth=0.000000, plastic_amount=20.961378, time=not_yet_set)
# P[427](lon=24.033375, lat=38.015709, depth=0.000000, plastic_amount=20.915247, time=not_yet_set)
# P[428](lon=24.036204, lat=38.072584, depth=0.000000, plastic_amount=12.474775, time=not_yet_set)
# P[429](lon=24.039060, lat=38.129367, depth=0.000000, plastic_amount=8.157077, time=not_yet_set)
# P[430](lon=24.041944, lat=38.186058, depth=0.000000, plastic_amount=4.897938, time=not_yet_set)
# P[431](lon=24.044764, lat=40.758645, depth=0.000000, plastic_amount=0.431695, time=not_yet_set)
# P[432](lon=24.050763, lat=38.355584, depth=0.000000, plastic_amount=2.472508, time=not_yet_set)
# P[433](lon=24.053760, lat=38.411914, depth=0.000000, plastic_amount=2.466260, time=not_yet_set)
# P[434](lon=24.069169, lat=38.692201, depth=0.000000, plastic_amount=1.207007, time=not_yet_set)
# P[435](lon=24.074197, lat=40.064019, depth=0.000000, plastic_amount=0.280280, time=not_yet_set)
# P[436](lon=24.084303, lat=34.802662, depth=0.000000, plastic_amount=0.090208, time=not_yet_set)
# P[437](lon=24.087418, lat=34.926445, depth=0.000000, plastic_amount=0.089793, time=not_yet_set)
# P[438](lon=24.090148, lat=40.278045, depth=0.000000, plastic_amount=0.216957, time=not_yet_set)
# P[439](lon=24.093889, lat=35.172855, depth=0.000000, plastic_amount=0.119836, time=not_yet_set)
# P[440](lon=24.098322, lat=40.384551, depth=0.000000, plastic_amount=0.215949, time=not_yet_set)
# P[441](lon=24.102448, lat=35.478691, depth=0.000000, plastic_amount=74.236282, time=not_yet_set)
# P[442](lon=24.102928, lat=37.727531, depth=0.000000, plastic_amount=4.777951, time=not_yet_set)
# P[443](lon=24.105621, lat=37.784839, depth=0.000000, plastic_amount=3.616250, time=not_yet_set)
# P[444](lon=24.105647, lat=39.300975, depth=0.000000, plastic_amount=0.329207, time=not_yet_set)
# P[445](lon=24.108340, lat=37.842055, depth=0.000000, plastic_amount=4.423719, time=not_yet_set)
# P[446](lon=24.122344, lat=38.126759, depth=0.000000, plastic_amount=2.447588, time=not_yet_set)
# P[447](lon=24.125227, lat=38.183425, depth=0.000000, plastic_amount=2.441818, time=not_yet_set)
# P[448](lon=24.127980, lat=40.754692, depth=0.000000, plastic_amount=0.285090, time=not_yet_set)
# P[449](lon=24.128138, lat=38.240000, depth=0.000000, plastic_amount=0.822579, time=not_yet_set)
# P[450](lon=24.131076, lat=38.296483, depth=0.000000, plastic_amount=0.565293, time=not_yet_set)
# P[451](lon=24.146194, lat=38.577542, depth=0.000000, plastic_amount=1.415022, time=not_yet_set)
# P[452](lon=24.152442, lat=38.689337, depth=0.000000, plastic_amount=1.206146, time=not_yet_set)
# P[453](lon=24.169169, lat=34.863191, depth=0.000000, plastic_amount=0.089980, time=not_yet_set)
# P[454](lon=24.169344, lat=40.221013, depth=0.000000, plastic_amount=0.090199, time=not_yet_set)
# P[455](lon=24.173379, lat=40.274363, depth=0.000000, plastic_amount=0.089989, time=not_yet_set)
# P[456](lon=24.177208, lat=35.171350, depth=0.000000, plastic_amount=0.205919, time=not_yet_set)
# P[457](lon=24.181550, lat=40.380810, depth=0.000000, plastic_amount=0.089570, time=not_yet_set)
# P[458](lon=24.185762, lat=35.477092, depth=0.000000, plastic_amount=6.913116, time=not_yet_set)
# P[459](lon=24.202771, lat=38.067417, depth=0.000000, plastic_amount=0.483422, time=not_yet_set)
# P[460](lon=24.211194, lat=40.750736, depth=0.000000, plastic_amount=2.091752, time=not_yet_set)
# P[461](lon=24.217321, lat=38.350166, depth=0.000000, plastic_amount=0.777766, time=not_yet_set)
# P[462](lon=24.220315, lat=38.406443, depth=0.000000, plastic_amount=0.775926, time=not_yet_set)
# P[463](lon=24.223338, lat=38.462628, depth=0.000000, plastic_amount=0.795971, time=not_yet_set)
# P[464](lon=24.226389, lat=38.518723, depth=0.000000, plastic_amount=0.874829, time=not_yet_set)
# P[465](lon=24.232576, lat=38.630646, depth=0.000000, plastic_amount=1.207703, time=not_yet_set)
# P[466](lon=24.248575, lat=40.163956, depth=0.000000, plastic_amount=0.090353, time=not_yet_set)
# P[467](lon=24.260524, lat=35.169846, depth=0.000000, plastic_amount=0.219908, time=not_yet_set)
# P[468](lon=24.260674, lat=40.323915, depth=0.000000, plastic_amount=0.089722, time=not_yet_set)
# P[469](lon=24.264205, lat=37.607864, depth=0.000000, plastic_amount=0.443379, time=not_yet_set)
# P[470](lon=24.266843, lat=37.665310, depth=0.000000, plastic_amount=0.442398, time=not_yet_set)
# P[471](lon=24.267323, lat=35.414555, depth=0.000000, plastic_amount=2.384101, time=not_yet_set)
# P[472](lon=24.286054, lat=38.064835, depth=0.000000, plastic_amount=1.398734, time=not_yet_set)
# P[473](lon=24.294697, lat=38.234682, depth=0.000000, plastic_amount=0.442475, time=not_yet_set)
# P[474](lon=24.297634, lat=38.291115, depth=0.000000, plastic_amount=0.357442, time=not_yet_set)
# P[475](lon=24.298774, lat=40.799265, depth=0.000000, plastic_amount=11.651681, time=not_yet_set)
# P[476](lon=24.303175, lat=40.851666, depth=0.000000, plastic_amount=21.421892, time=not_yet_set)
# P[477](lon=24.307612, lat=40.903985, depth=0.000000, plastic_amount=21.372311, time=not_yet_set)
# P[478](lon=24.308805, lat=36.674015, depth=0.000000, plastic_amount=0.172193, time=not_yet_set)
# P[479](lon=24.311036, lat=36.732938, depth=0.000000, plastic_amount=0.165331, time=not_yet_set)
# P[480](lon=24.327838, lat=40.106871, depth=0.000000, plastic_amount=0.090517, time=not_yet_set)
# P[481](lon=24.337211, lat=37.374866, depth=0.000000, plastic_amount=0.277904, time=not_yet_set)
# P[482](lon=24.339743, lat=37.432659, depth=0.000000, plastic_amount=0.277246, time=not_yet_set)
# P[483](lon=24.339834, lat=40.266995, depth=0.000000, plastic_amount=0.089884, time=not_yet_set)
# P[484](lon=24.343840, lat=35.168343, depth=0.000000, plastic_amount=1.086391, time=not_yet_set)
# P[485](lon=24.344884, lat=37.547965, depth=0.000000, plastic_amount=0.243361, time=not_yet_set)
# P[486](lon=24.350638, lat=35.412973, depth=0.000000, plastic_amount=1.737679, time=not_yet_set)
# P[487](lon=24.352794, lat=37.720228, depth=0.000000, plastic_amount=0.441065, time=not_yet_set)
# P[488](lon=24.366510, lat=38.005478, depth=0.000000, plastic_amount=2.607790, time=not_yet_set)
# P[489](lon=24.375067, lat=38.175525, depth=0.000000, plastic_amount=0.443298, time=not_yet_set)
# P[490](lon=24.389900, lat=36.613003, depth=0.000000, plastic_amount=0.172539, time=not_yet_set)
# P[491](lon=24.395283, lat=40.952141, depth=0.000000, plastic_amount=21.338049, time=not_yet_set)
# P[492](lon=24.396591, lat=36.789707, depth=0.000000, plastic_amount=2.318974, time=not_yet_set)
# P[493](lon=24.410637, lat=37.140560, depth=0.000000, plastic_amount=0.349372, time=not_yet_set)
# P[494](lon=24.415031, lat=40.156708, depth=0.000000, plastic_amount=0.090285, time=not_yet_set)
# P[495](lon=24.417997, lat=37.314713, depth=0.000000, plastic_amount=0.278457, time=not_yet_set)
# P[496](lon=24.418359, lat=38.958248, depth=0.000000, plastic_amount=0.226287, time=not_yet_set)
# P[497](lon=24.419028, lat=40.210053, depth=0.000000, plastic_amount=0.090056, time=not_yet_set)
# P[498](lon=24.425591, lat=37.488022, depth=0.000000, plastic_amount=0.243843, time=not_yet_set)
# P[499](lon=24.427155, lat=35.166837, depth=0.000000, plastic_amount=1.086254, time=not_yet_set)
# ...
# P[874](lon=26.757203, lat=37.422521, depth=0.000000, plastic_amount=1.213820, time=not_yet_set)
# P[875](lon=26.758827, lat=39.037280, depth=0.000000, plastic_amount=1.299461, time=not_yet_set)
# P[876](lon=26.767555, lat=37.649585, depth=0.000000, plastic_amount=0.927150, time=not_yet_set)
# P[877](lon=26.768963, lat=39.199590, depth=0.000000, plastic_amount=2.960097, time=not_yet_set)
# P[878](lon=26.775591, lat=37.818871, depth=0.000000, plastic_amount=3.789928, time=not_yet_set)
# P[879](lon=26.782894, lat=39.414719, depth=0.000000, plastic_amount=2.976010, time=not_yet_set)
# P[880](lon=26.789516, lat=38.099096, depth=0.000000, plastic_amount=1.685715, time=not_yet_set)
# P[881](lon=26.792382, lat=38.154854, depth=0.000000, plastic_amount=1.681299, time=not_yet_set)
# P[882](lon=26.793657, lat=39.575115, depth=0.000000, plastic_amount=2.752984, time=not_yet_set)
# P[883](lon=26.816303, lat=38.597523, depth=0.000000, plastic_amount=15.695798, time=not_yet_set)
# P[884](lon=26.823332, lat=37.019250, depth=0.000000, plastic_amount=2.198738, time=not_yet_set)
# P[885](lon=26.825704, lat=37.076821, depth=0.000000, plastic_amount=2.193368, time=not_yet_set)
# P[886](lon=26.825736, lat=38.761973, depth=0.000000, plastic_amount=4.399296, time=not_yet_set)
# P[887](lon=26.830521, lat=37.191663, depth=0.000000, plastic_amount=1.860763, time=not_yet_set)
# P[888](lon=26.835439, lat=37.306119, depth=0.000000, plastic_amount=1.851655, time=not_yet_set)
# P[889](lon=26.837935, lat=37.363201, depth=0.000000, plastic_amount=1.216023, time=not_yet_set)
# P[890](lon=26.838714, lat=38.979934, depth=0.000000, plastic_amount=1.302136, time=not_yet_set)
# P[891](lon=26.845378, lat=39.088361, depth=0.000000, plastic_amount=1.296015, time=not_yet_set)
# P[892](lon=26.848754, lat=39.142437, depth=0.000000, plastic_amount=2.774078, time=not_yet_set)
# P[893](lon=26.850802, lat=37.647150, depth=0.000000, plastic_amount=1.772731, time=not_yet_set)
# P[894](lon=26.851466, lat=35.425886, depth=0.000000, plastic_amount=0.301426, time=not_yet_set)
# P[895](lon=26.858835, lat=37.816363, depth=0.000000, plastic_amount=2.376251, time=not_yet_set)
# P[896](lon=26.866082, lat=39.411438, depth=0.000000, plastic_amount=3.099690, time=not_yet_set)
# P[897](lon=26.869637, lat=39.464965, depth=0.000000, plastic_amount=3.091526, time=not_yet_set)
# P[898](lon=26.869914, lat=38.040632, depth=0.000000, plastic_amount=1.688689, time=not_yet_set)
# P[899](lon=26.873222, lat=39.518400, depth=0.000000, plastic_amount=3.083987, time=not_yet_set)
# P[900](lon=26.876838, lat=39.571745, depth=0.000000, plastic_amount=3.077070, time=not_yet_set)
# P[901](lon=26.904249, lat=36.959432, depth=0.000000, plastic_amount=2.203301, time=not_yet_set)
# P[902](lon=26.908948, lat=38.759023, depth=0.000000, plastic_amount=4.396026, time=not_yet_set)
# P[903](lon=26.908966, lat=37.074623, depth=0.000000, plastic_amount=2.192518, time=not_yet_set)
# P[904](lon=26.911361, lat=37.132072, depth=0.000000, plastic_amount=2.187143, time=not_yet_set)
# P[905](lon=26.912147, lat=38.813626, depth=0.000000, plastic_amount=4.385212, time=not_yet_set)
# P[906](lon=26.915375, lat=38.868136, depth=0.000000, plastic_amount=4.374459, time=not_yet_set)
# P[907](lon=26.918632, lat=38.922553, depth=0.000000, plastic_amount=4.363767, time=not_yet_set)
# P[908](lon=26.933026, lat=35.363977, depth=0.000000, plastic_amount=0.302078, time=not_yet_set)
# P[909](lon=26.934048, lat=37.644715, depth=0.000000, plastic_amount=3.324777, time=not_yet_set)
# P[910](lon=26.936508, lat=35.484501, depth=0.000000, plastic_amount=0.300659, time=not_yet_set)
# P[911](lon=26.942077, lat=37.813855, depth=0.000000, plastic_amount=11.438521, time=not_yet_set)
# P[912](lon=26.953149, lat=38.038023, depth=0.000000, plastic_amount=1.687965, time=not_yet_set)
# P[913](lon=26.980626, lat=36.783828, depth=0.000000, plastic_amount=0.919520, time=not_yet_set)
# P[914](lon=26.982898, lat=36.841745, depth=0.000000, plastic_amount=2.213456, time=not_yet_set)
# P[915](lon=26.989856, lat=37.014902, depth=0.000000, plastic_amount=2.197220, time=not_yet_set)
# P[916](lon=27.017294, lat=37.642282, depth=0.000000, plastic_amount=3.323658, time=not_yet_set)
# P[917](lon=27.018048, lat=35.422692, depth=0.000000, plastic_amount=0.623494, time=not_yet_set)
# P[918](lon=27.022617, lat=37.755087, depth=0.000000, plastic_amount=11.464645, time=not_yet_set)
# P[919](lon=27.036384, lat=38.035417, depth=0.000000, plastic_amount=1.634860, time=not_yet_set)
# P[920](lon=27.061646, lat=36.723755, depth=0.000000, plastic_amount=0.927524, time=not_yet_set)
# P[921](lon=27.068456, lat=36.897435, depth=0.000000, plastic_amount=2.207033, time=not_yet_set)
# P[922](lon=27.070774, lat=36.955132, depth=0.000000, plastic_amount=2.201605, time=not_yet_set)
# P[923](lon=27.100539, lat=37.639848, depth=0.000000, plastic_amount=1.833999, time=not_yet_set)
# P[924](lon=27.103088, lat=35.481266, depth=0.000000, plastic_amount=0.621792, time=not_yet_set)
# P[925](lon=27.104859, lat=35.541340, depth=0.000000, plastic_amount=1.146682, time=not_yet_set)
# P[926](lon=27.105858, lat=37.752604, depth=0.000000, plastic_amount=8.030056, time=not_yet_set)
# P[927](lon=27.106652, lat=35.601312, depth=0.000000, plastic_amount=1.143902, time=not_yet_set)
# P[928](lon=27.108465, lat=35.661182, depth=0.000000, plastic_amount=0.201967, time=not_yet_set)
# P[929](lon=27.112156, lat=35.780619, depth=0.000000, plastic_amount=0.102486, time=not_yet_set)
# P[930](lon=27.119616, lat=38.032809, depth=0.000000, plastic_amount=1.565436, time=not_yet_set)
# P[931](lon=27.140494, lat=36.605455, depth=0.000000, plastic_amount=0.503216, time=not_yet_set)
# P[932](lon=27.144913, lat=36.721695, depth=0.000000, plastic_amount=0.930072, time=not_yet_set)
# P[933](lon=27.151718, lat=36.895309, depth=0.000000, plastic_amount=4.468120, time=not_yet_set)
# P[934](lon=27.156377, lat=37.010560, depth=0.000000, plastic_amount=4.225073, time=not_yet_set)
# P[935](lon=27.158743, lat=37.068035, depth=0.000000, plastic_amount=4.214684, time=not_yet_set)
# P[936](lon=27.173462, lat=37.410835, depth=0.000000, plastic_amount=4.155585, time=not_yet_set)
# P[937](lon=27.176004, lat=37.467625, depth=0.000000, plastic_amount=4.145347, time=not_yet_set)
# P[938](lon=27.178571, lat=37.524319, depth=0.000000, plastic_amount=4.135132, time=not_yet_set)
# P[939](lon=27.181164, lat=37.580917, depth=0.000000, plastic_amount=2.888600, time=not_yet_set)
# P[940](lon=27.184627, lat=35.419495, depth=0.000000, plastic_amount=3.628237, time=not_yet_set)
# P[941](lon=27.189098, lat=37.750122, depth=0.000000, plastic_amount=8.026671, time=not_yet_set)
# P[942](lon=27.193584, lat=35.719254, depth=0.000000, plastic_amount=0.199117, time=not_yet_set)
# P[943](lon=27.197317, lat=35.838450, depth=0.000000, plastic_amount=0.102222, time=not_yet_set)
# P[944](lon=27.200044, lat=37.974376, depth=0.000000, plastic_amount=4.893682, time=not_yet_set)
# P[945](lon=27.221590, lat=36.545196, depth=0.000000, plastic_amount=0.504374, time=not_yet_set)
# P[946](lon=27.225958, lat=36.661589, depth=0.000000, plastic_amount=0.501833, time=not_yet_set)
# P[947](lon=27.230422, lat=36.777586, depth=0.000000, plastic_amount=5.595391, time=not_yet_set)
# P[948](lon=27.237295, lat=36.950835, depth=0.000000, plastic_amount=5.554226, time=not_yet_set)
# P[949](lon=27.239636, lat=37.008387, depth=0.000000, plastic_amount=4.223758, time=not_yet_set)
# P[950](lon=27.244389, lat=37.123197, depth=0.000000, plastic_amount=4.202986, time=not_yet_set)
# P[951](lon=27.254196, lat=37.351633, depth=0.000000, plastic_amount=4.164493, time=not_yet_set)
# P[952](lon=27.269664, lat=35.478032, depth=0.000000, plastic_amount=3.618089, time=not_yet_set)
# P[953](lon=27.271433, lat=35.538065, depth=0.000000, plastic_amount=3.609292, time=not_yet_set)
# P[954](lon=27.272337, lat=37.747640, depth=0.000000, plastic_amount=8.025229, time=not_yet_set)
# P[955](lon=27.273223, lat=35.597997, depth=0.000000, plastic_amount=3.124063, time=not_yet_set)
# P[956](lon=27.275032, lat=37.803824, depth=0.000000, plastic_amount=8.004124, time=not_yet_set)
# P[957](lon=27.275035, lat=35.657827, depth=0.000000, plastic_amount=0.102919, time=not_yet_set)
# P[958](lon=27.277753, lat=37.859911, depth=0.000000, plastic_amount=7.984374, time=not_yet_set)
# P[959](lon=27.278722, lat=35.777186, depth=0.000000, plastic_amount=0.102418, time=not_yet_set)
# P[960](lon=27.280501, lat=37.915901, depth=0.000000, plastic_amount=7.965969, time=not_yet_set)
# P[961](lon=27.283276, lat=37.971795, depth=0.000000, plastic_amount=4.891965, time=not_yet_set)
# P[962](lon=27.300587, lat=36.426458, depth=0.000000, plastic_amount=0.309202, time=not_yet_set)
# P[963](lon=27.307029, lat=36.601429, depth=0.000000, plastic_amount=0.387373, time=not_yet_set)
# P[964](lon=27.315950, lat=36.833331, depth=0.000000, plastic_amount=5.579109, time=not_yet_set)
# P[965](lon=27.320554, lat=36.948685, depth=0.000000, plastic_amount=5.551669, time=not_yet_set)
# P[966](lon=27.330056, lat=37.178211, depth=0.000000, plastic_amount=4.190648, time=not_yet_set)
# P[967](lon=27.337444, lat=37.349321, depth=0.000000, plastic_amount=4.162472, time=not_yet_set)
# P[968](lon=27.381758, lat=36.366009, depth=0.000000, plastic_amount=0.309853, time=not_yet_set)
# P[969](lon=27.385979, lat=36.482912, depth=0.000000, plastic_amount=0.308333, time=not_yet_set)
# P[970](lon=27.394705, lat=36.715519, depth=0.000000, plastic_amount=0.782105, time=not_yet_set)
# P[971](lon=27.401499, lat=36.888931, depth=0.000000, plastic_amount=5.563289, time=not_yet_set)
# P[972](lon=27.403812, lat=36.946538, depth=0.000000, plastic_amount=5.549572, time=not_yet_set)
# P[973](lon=27.410897, lat=37.118760, depth=0.000000, plastic_amount=4.199387, time=not_yet_set)
# P[974](lon=27.418205, lat=37.290095, depth=0.000000, plastic_amount=4.171127, time=not_yet_set)
# P[975](lon=27.467125, lat=36.422563, depth=0.000000, plastic_amount=0.309002, time=not_yet_set)
# P[976](lon=27.475752, lat=36.655483, depth=0.000000, plastic_amount=0.783801, time=not_yet_set)
# P[977](lon=27.480206, lat=36.771344, depth=0.000000, plastic_amount=0.779943, time=not_yet_set)
# P[978](lon=27.487069, lat=36.944391, depth=0.000000, plastic_amount=4.229310, time=not_yet_set)
# P[979](lon=27.494150, lat=37.116543, depth=0.000000, plastic_amount=4.198055, time=not_yet_set)
# P[980](lon=27.501453, lat=37.287808, depth=0.000000, plastic_amount=1.177903, time=not_yet_set)
# P[981](lon=27.559015, lat=36.653449, depth=0.000000, plastic_amount=0.783453, time=not_yet_set)
# P[982](lon=27.563466, lat=36.769266, depth=0.000000, plastic_amount=0.779591, time=not_yet_set)
# P[983](lon=27.572659, lat=36.999703, depth=0.000000, plastic_amount=4.216910, time=not_yet_set)
# P[984](lon=27.579810, lat=37.171490, depth=0.000000, plastic_amount=4.185694, time=not_yet_set)
# P[985](lon=27.582243, lat=37.228555, depth=0.000000, plastic_amount=2.744001, time=not_yet_set)
# P[986](lon=27.642276, lat=36.651415, depth=0.000000, plastic_amount=0.783167, time=not_yet_set)
# P[987](lon=27.648985, lat=36.824921, depth=0.000000, plastic_amount=0.777377, time=not_yet_set)
# P[988](lon=27.655913, lat=36.997533, depth=0.000000, plastic_amount=4.215304, time=not_yet_set)
# P[989](lon=27.698889, lat=35.887358, depth=0.000000, plastic_amount=0.062383, time=not_yet_set)
# P[990](lon=27.700804, lat=35.946580, depth=0.000000, plastic_amount=0.133784, time=not_yet_set)
# P[991](lon=27.702741, lat=36.005701, depth=0.000000, plastic_amount=0.327399, time=not_yet_set)
# P[992](lon=27.704700, lat=36.064722, depth=0.000000, plastic_amount=0.326552, time=not_yet_set)
# P[993](lon=27.706681, lat=36.123642, depth=0.000000, plastic_amount=0.325749, time=not_yet_set)
# P[994](lon=27.708684, lat=36.182461, depth=0.000000, plastic_amount=0.325377, time=not_yet_set)
# P[995](lon=27.727748, lat=36.707293, depth=0.000000, plastic_amount=0.781109, time=not_yet_set)
# P[996](lon=27.732242, lat=36.822820, depth=0.000000, plastic_amount=0.777139, time=not_yet_set)
# P[997](lon=27.739164, lat=36.995362, depth=0.000000, plastic_amount=4.213990, time=not_yet_set)
# P[998](lon=27.780273, lat=35.826300, depth=0.000000, plastic_amount=0.062512, time=not_yet_set)
# P[999](lon=27.793979, lat=36.239297, depth=0.000000, plastic_amount=0.364035, time=not_yet_set)
# P[1000](lon=27.796027, lat=36.297893, depth=0.000000, plastic_amount=0.363137, time=not_yet_set)
# P[1001](lon=27.811006, lat=36.705237, depth=0.000000, plastic_amount=0.780651, time=not_yet_set)
# P[1002](lon=27.815497, lat=36.820719, depth=0.000000, plastic_amount=0.776785, time=not_yet_set)
# P[1003](lon=27.824769, lat=37.050486, depth=0.000000, plastic_amount=1.269018, time=not_yet_set)
# P[1004](lon=27.865441, lat=35.883849, depth=0.000000, plastic_amount=0.118332, time=not_yet_set)
# P[1005](lon=27.881363, lat=36.354462, depth=0.000000, plastic_amount=0.629511, time=not_yet_set)
# P[1006](lon=27.894264, lat=36.703182, depth=0.000000, plastic_amount=0.780361, time=not_yet_set)
# P[1007](lon=27.898752, lat=36.818620, depth=0.000000, plastic_amount=0.776496, time=not_yet_set)
# P[1008](lon=27.908018, lat=37.048294, depth=0.000000, plastic_amount=1.187220, time=not_yet_set)
# P[1009](lon=27.950626, lat=35.941255, depth=0.000000, plastic_amount=0.393839, time=not_yet_set)
# P[1010](lon=27.952559, lat=36.000314, depth=0.000000, plastic_amount=0.656082, time=not_yet_set)
# P[1011](lon=27.966719, lat=36.410889, depth=0.000000, plastic_amount=1.420881, time=not_yet_set)
# P[1012](lon=27.977520, lat=36.701127, depth=0.000000, plastic_amount=1.741591, time=not_yet_set)
# P[1013](lon=27.982005, lat=36.816519, depth=0.000000, plastic_amount=1.732711, time=not_yet_set)
# P[1014](lon=27.984284, lat=36.874065, depth=0.000000, plastic_amount=1.728659, time=not_yet_set)
# P[1015](lon=27.991265, lat=37.046102, depth=0.000000, plastic_amount=1.187023, time=not_yet_set)
# P[1016](lon=28.037784, lat=36.057456, depth=0.000000, plastic_amount=1.219663, time=not_yet_set)
# P[1017](lon=28.049981, lat=36.408945, depth=0.000000, plastic_amount=8.802123, time=not_yet_set)
# P[1018](lon=28.058569, lat=36.641248, depth=0.000000, plastic_amount=1.744894, time=not_yet_set)
# P[1019](lon=28.060775, lat=36.699072, depth=0.000000, plastic_amount=1.740569, time=not_yet_set)
# P[1020](lon=28.069836, lat=36.929366, depth=0.000000, plastic_amount=1.723315, time=not_yet_set)
# P[1021](lon=28.074512, lat=37.043911, depth=0.000000, plastic_amount=1.172973, time=not_yet_set)
# P[1022](lon=28.123029, lat=36.114454, depth=0.000000, plastic_amount=2.187276, time=not_yet_set)
# P[1023](lon=28.125027, lat=36.173164, depth=0.000000, plastic_amount=4.445632, time=not_yet_set)
# P[1024](lon=28.133242, lat=36.407000, depth=0.000000, plastic_amount=28.882973, time=not_yet_set)
# P[1025](lon=28.139645, lat=36.581315, depth=0.000000, plastic_amount=1.748601, time=not_yet_set)
# P[1026](lon=28.155409, lat=36.984521, depth=0.000000, plastic_amount=1.718371, time=not_yet_set)
# P[1027](lon=28.210310, lat=36.229897, depth=0.000000, plastic_amount=4.433363, time=not_yet_set)
# P[1028](lon=28.212352, lat=36.288386, depth=0.000000, plastic_amount=4.422378, time=not_yet_set)
# P[1029](lon=28.214415, lat=36.346774, depth=0.000000, plastic_amount=21.039104, time=not_yet_set)
# P[1030](lon=28.218612, lat=36.463242, depth=0.000000, plastic_amount=49.559151, time=not_yet_set)
# P[1031](lon=28.225079, lat=36.637187, depth=0.000000, plastic_amount=1.743735, time=not_yet_set)
# P[1032](lon=28.227283, lat=36.694965, depth=0.000000, plastic_amount=1.739644, time=not_yet_set)
# P[1033](lon=28.299761, lat=36.403116, depth=0.000000, plastic_amount=49.661011, time=not_yet_set)
# P[1034](lon=28.312760, lat=36.750569, depth=0.000000, plastic_amount=1.734279, time=not_yet_set)
# P[1035](lon=28.315009, lat=36.808124, depth=0.000000, plastic_amount=1.729954, time=not_yet_set)
# P[1036](lon=28.398256, lat=36.806025, depth=0.000000, plastic_amount=1.729308, time=not_yet_set)
# P[1037](lon=28.481504, lat=36.803928, depth=0.000000, plastic_amount=1.728779, time=not_yet_set)
# P[1038](lon=28.562506, lat=36.744344, depth=0.000000, plastic_amount=3.415866, time=not_yet_set)
# P[1039](lon=28.643534, lat=36.684704, depth=0.000000, plastic_amount=3.423169, time=not_yet_set)

# %%
fig = plt.figure()
ax = plt.axes(projection=ccrs.PlateCarree())
ax.scatter(pset.lon, pset.lat, c=np.log(pset.plastic_amount), s=5, transform=ccrs.PlateCarree())
ax.coastlines()
ax.gridlines(draw_labels=True)
plt.title("Initial particle positions")
plt.show()

fig = plt.figure()
ax = plt.axes(projection=ccrs.PlateCarree())
ax.scatter(pset.lon, pset.lat, c=np.log(pset.plastic_amount), s=2, transform=ccrs.PlateCarree())
ax.coastlines()
ax.gridlines(draw_labels=True)
ax.set_xlim([np.min(pset.lon)-25, np.max(pset.lon)+25])
ax.set_ylim([np.min(pset.lat)-25, np.max(pset.lat)+25])
plt.title("Initial particle positions")
plt.show()
# Out:
# /Users/denes001/anaconda3/envs/py3_parcels/lib/python3.11/site-packages/shapely/predicates.py:798: RuntimeWarning: invalid value encountered in intersects
#   return lib.intersects(a, b, **kwargs)

# %%
kernels = PP.constructors.create_kernel(fieldset, pset)

# %%
#kernels = kernels[1:]

# %%
kernels = [kernels[1], kernels[3], kernels[4], kernels[5], kernels[6]]
kernels
# Out:
# [<function parcels.application_kernels.advection.AdvectionRK4_3D(particle, fieldset, time)>,
#  <function PlasticParcels.kernels.checkThroughBathymetry(particle, fieldset, time)>,
#  <function PlasticParcels.kernels.checkErrorThroughSurface(particle, fieldset, time)>,
#  <function PlasticParcels.kernels.periodicBC(particle, fieldset, time)>,
#  <function PlasticParcels.kernels.deleteParticle(particle, fieldset, time)>]

# %%
## Define the runtime, the timestepping, and the output frequency of the simulation
runtime = settings['simulation']['runtime']
dt_timestep = settings['simulation']['dt_timestep']
dt_write = settings['simulation']['dt_write']

# %%
## Create the particle file where output will be stored
pfile = ParticleFile('tes2.zarr', pset, outputdt=dt_write)
pfile.add_metadata('PlasticParcels_settings', str(settings))

## Execute the simulation
pset.execute(kernels, runtime=runtime, dt=dt_timestep, output_file=pfile)
# Out:
# INFO: Output files are stored in tes2.zarr.
#   0%|          | 1200.0/259200.0 [01:10<3:35:02, 20.00it/s]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
fig = plt.figure()
ax = plt.axes(projection=ccrs.PlateCarree())
ax.scatter(pset.lon, pset.lat, c=np.log(pset.plastic_amount), s=5, transform=ccrs.PlateCarree())
ax.coastlines()
ax.gridlines(draw_labels=True)
plt.title("Final particle positions")
plt.show()

fig = plt.figure()
ax = plt.axes(projection=ccrs.PlateCarree())
ax.scatter(pset.lon, pset.lat, c=np.log(pset.plastic_amount), s=5, transform=ccrs.PlateCarree())
ax.coastlines()
ax.gridlines(draw_labels=True)
ax.set_xlim([np.min(pset.lon)-25, np.max(pset.lon)+25])
ax.set_ylim([np.min(pset.lat)-25, np.max(pset.lat)+25])
plt.title("Final particle positions")
plt.show()

# %%
particle_locations = pd.read_csv(settings['release_maps']['coastal'])

# %%
particle_locations['MPW_Cell']

# %%
import xarray as xr
ds = xr.open_zarr('tes2.zarr')

# %%
test = ds.attrs['Settings']

# %%
len(pset.lon)

# %%
import xarray as xr
mask = xr.open_dataset('/Users/denes001/Research/Projects/PlasticParcels/PlasticParcels/data/input_data/MOi/domain_ORCA0083-N006/PSY4V3R1_mask.nc')
mask

# %%
ax = plt.subplot(111, projection=ccrs.PlateCarree())
ax.pcolormesh(mask['nav_lon'], mask['nav_lat'], mask['umask'][0,25], transform=ccrs.PlateCarree())
plt.show()

# %%
coordinates = xr.open_dataset('/Users/denes001/Research/Projects/PlasticParcels/PlasticParcels/data/input_data/MOi/domain_ORCA0083-N006/coordinates.nc', decode_cf=False)

# %%
coordinates

# %% [markdown]
# # Create a Parcels fieldset
# We now create the fieldset that contains all the required fields (ocean velocities, temperature and salinity, ocean biology, winds and waves, etc.).
#
# We loaded the default settings above, which we will pass into the `create_fieldset` PlasticParcels function. This removes a lot of the complexity when creating fieldsets with a large number of underlying fields. What is produced is a Parcels fieldset object.

# %%
fieldset = create_fieldset(model_settings, particle_settings)

print("Time origin of data: ", fieldset.time_origin)

# %% [markdown]
# To list all the fields that are present we use `.get_fields()` method to return a list of the fields, which we can then utilise and analyse.

# %%
for parcels_field in fieldset.get_fields():
    print(parcels_field.name)

# %% [markdown]
# ## Plotting Parcels `fields`
# Parcels fields are not loaded into memory immediately, rather the fields are only loaded when they are required (deferred load). Often the hydrodynamic data alone can be hundreds of GBs. To visualise these fields we can load in the first timestep of data.
#
# We do this using the `.computeTimeChunk(time, dt)` method, which takes as input a model time to load, and a number of timesteps to load. Once loaded, we plot the resulting fields using the `pcolormesh` matplotlib function. Below is a small snippet of code used to plot these fields.
#
# **A key highlight here is that Parcels handles different spatial grids and temporal resolutions automatically, and can even use different interpolation methods on each.**

# %% [markdown]
# <div class="alert alert-info">
# Note - The plots below are indicative only. Since the data is on a C-grid, and the plotting assumes we are passing T-points, there is a slight spatial shift to the data. This is only an issue with our basic plotting below, Parcels correctly interprets the grids.
# </div>

# %%
## Load data into memory
fieldset.computeTimeChunk(0,1)

# %%
## Plotting function
def plot_field(lons, lats, data, title):
    fig = plt.figure()
    ax = plt.axes(projection=ccrs.PlateCarree())
    colors = ax.pcolormesh(lons, lats, data, transform=ccrs.PlateCarree())
    ax.coastlines()
    ax.gridlines(draw_labels=True)
    plt.title(title)
    plt.colorbar(colors)
    plt.show()

# %% [markdown]
# Note that some fields have no depth component (e.g. bathymetry, wind, waves), and so the shape of their data is different, and should be indexed differently.

# %%
print("The usual shape order is (time, depth, latitude, longitude)")
print("Ocean U velocity data shape:", fieldset.U.data.shape)
print("Ocean V velocity data shape:", fieldset.V.data.shape)
print("Wind U velocity data shape:", fieldset.Wind_U.data.shape)
print("Wind V velocity data shape:", fieldset.Wind_U.data.shape)
print("Bathymetry shape:", fieldset.bathymetry.data.shape)

# %% [markdown]
# Plot the ocean surface velocity fields

# %%
## Plot velocity fields
plot_field(fieldset.U.grid.lon, fieldset.U.grid.lat, fieldset.U.data[0,0], "Surface velocity in i-direction (m/s)")
plot_field(fieldset.V.grid.lon, fieldset.V.grid.lat, fieldset.V.data[0,0], "Surface velocity in j-direction (m/s)")

# %% [markdown]
# <div class="alert alert-info">
# Note: The U,V fields are on a curvilinear grid, and the velocities are in the i- and j-directions. Parcels automatically rotates these vectors into the zonal- and meridional-directions when performing interpolation.
# </div>

# %% [markdown]
# Plot the model bathymetry field

# %%
## Plot bathymetry
plot_field(fieldset.bathymetry.grid.lon, fieldset.bathymetry.grid.lat, fieldset.bathymetry.data[0], "Depth (m)")

# %% [markdown]
# Plot the 10m-wind velocity fields

# %%
## Plot Wind velocity fields
plot_field(fieldset.Wind_U.grid.lon, fieldset.Wind_U.grid.lat, fieldset.Wind_U.data[0], "Zonal wind velocity (m/s)")
plot_field(fieldset.Wind_V.grid.lon, fieldset.Wind_V.grid.lat, fieldset.Wind_V.data[0], "Meridional wind velocity (m/s)")

# %% [markdown]
# Plot vertical eddy diffusivity

# %%
## Plot Vertical Diffusivity field
plot_field(fieldset.mixing_kz.grid.lon, fieldset.mixing_kz.grid.lat, fieldset.mixing_kz.data[0,0], "Vertical eddy diffusivity at surface (m$^2$/s)")

# %% [markdown]
# Plot biology related fields

# %%
## Plot pp_phyto
plot_field(fieldset.pp_phyto.grid.lon, fieldset.pp_phyto.grid.lat, fieldset.pp_phyto.data[0,0], "Total Primary Production of Phyto (mg m$^{-3}$/d)")
plot_field(fieldset.bio_diatom.grid.lon, fieldset.bio_diatom.grid.lat, fieldset.bio_diatom.data[0,0], "Mole concentration of Diatoms\n expressed as carbon in sea water")
plot_field(fieldset.pp_phyto.grid.lon, fieldset.pp_phyto.grid.lat, fieldset.pp_phyto.data[0,0], "Mole concentration of nanophytoplankton\n expressed as carbon in sea water")

# %% [markdown]
# # Parcels can also be used as a standalone field interpolator
# There are two ways to access the data in each Parcels field object. Firstly, as above, accessing the data directly and using the grid indices directly.
#
# Another way to access the field data is to pass the field a (time, depth, latitude, longitude) tuple, from which Parcels will interpolate the data for you.
#
# <div class="alert alert-info">
# Note: The U,V fields are on a curvilinear grid, and the velocities are in the i- and j-directions. The UV field is a Parcels VectorField which references the U and V fields, appropriately rotating and scaling the i/j-vectors into zonal- and meridional-directions. Other velocity fields (e.g. wind) need their units to be converted when loaded as a field.
# </div>

# %%
# Sample the U,V ocean velocities at the ocean surface somewhere in the Mediterranean
poi = [35.25, 20.11] # Point of Interest: 35.25deg North, 20.11deg East

U_value = fieldset.U[0,0,poi[0],poi[1]]
V_value = fieldset.V[0,0,poi[0],poi[1]]
print("Surface velocities in the i-, j-directions:", U_value, V_value, " (degrees/s).")

U_value, V_value = fieldset.UV[0,0,poi[0],poi[1]]
print("Surface velocities in the zonal-, meridional-directions:", U_value, V_value, " (degrees/s)")

# %% [markdown]
# We can also convert the values back into units of m/s by using the applyConversion parameter

# %%
U_value, V_value = fieldset.UV.eval(0, 0, poi[0],poi[1], applyConversion=False)
print("Surface velocities in the zonal-, meridional-directions:", U_value, V_value, " (m/s)")

# %%
## Determine the ocean depth at the point of interest
print(fieldset.bathymetry[0,0,poi[0], poi[1]])

# %%
## Determine the wind velocity at the point of interest
Wind_U_value = fieldset.Wind_U[0,0,poi[0],poi[1]]
Wind_V_value = fieldset.Wind_V[0,0,poi[0],poi[1]]
print("Surface wind velocities: ", Wind_U_value, Wind_V_value, " (degrees/s).")

Wind_U_value = fieldset.Wind_U.eval(0, 0, poi[0],poi[1], applyConversion=False)
Wind_V_value = fieldset.Wind_V.eval(0, 0, poi[0],poi[1], applyConversion=False)
print("Surface wind velocities: ", Wind_U_value, Wind_V_value, " (m/s).")

# %% [markdown]
# # Particle Sets
# We will now create some particle sets which represent release locations for microplastic particles.
#
# In the first instance, we will create a basic particle set using Parcels. Since our microplastic particles require additional variables (e.g. windage coefficients and settling velocities), we will still use the PlasticParcels helper functions.
#
# In the second instance, we will use PlasticParcels to create more complicated particle sets that replicate likely microplastic release locations. These release locations are determined using a range of datasets.

# %% [markdown]
# ## Creating a simple particle set
# Parcels includes a number of methods to create particle sets.
#
# The most commonly used is `ParticleSet.from_list()`, which allows you to pass through a list of longitudes, latitudes, depths, and times.
#
# Below, we randomly place particles in a box at different depths, and given these particles a wind coefficient, density, and diameter.

# %%
## Number of particles to release
n_particles = 100

## Randomly place particle release locations on a grid
lons = np.random.uniform(2,7,n_particles)
lats = np.random.uniform(37,42,n_particles)

## Randomly place the particles between the ocean surface and 50m depth
depths = np.random.uniform(0,50, n_particles)

## Create a dictionary of lists containing release location information 
release_locations = {'lons': lons,
                     'lats': lats,
                     'depths': depths
}

## Define particle properties
wind_coefficient = 0.01 # Percent of wind speed to apply
plastic_density = 1020. # Particle density (kg/m^3)
plastic_diameter = 0.001 # Partice diameter (m)
## Particleset settings
particle_settings.update({'release_locations': release_locations, # A dictionary of lons, lats, depths (optional), and times (optional)
                          'windage_coefficient': wind_coefficient, # A float or Nx1 array of windage coefficients, values in [0,1] [percent of wind speed]
                          'particle_density': plastic_density, # A float or Nx1 array of particle densities [kg m-3]
                          'particle_diameter': plastic_diameter, # A float or Nx1 array of particle lengths [m]
                          'write_output_option': 'none' # Option to write variables. Options: 'none' (default), 'tracer' (saves tracer fields), 'dynamic' (saves all variables that change spatiotemporally), 'all' (saves all variables)
                           })

# %%
## Create the particle set, and kernels required for the simulation
pset = create_particleset(fieldset, particle_settings)
kernels = create_kernel(fieldset, pset)

# %% [markdown]
# Let's take a look at the particle set

# %%
print(pset)

# %% [markdown]
# These particle sets can be indexed by particle id

# %%
print("Information saved for particle_id = 4:", pset[4])

# %% [markdown]
# Plot the particles, and list the kernels that will be used

# %%
fig = plt.figure()
ax = plt.axes(projection=ccrs.PlateCarree())
ax.scatter(pset.lon, pset.lat, s=2, transform=ccrs.PlateCarree())
ax.coastlines()
ax.gridlines(draw_labels=True)
plt.title("Initial particle positions")
plt.show()

fig = plt.figure()
ax = plt.axes(projection=ccrs.PlateCarree())
ax.scatter(pset.lon, pset.lat, s=2, transform=ccrs.PlateCarree())
ax.coastlines()
ax.gridlines(draw_labels=True)
ax.set_xlim([np.min(pset.lon)-25, np.max(pset.lon)+25])
ax.set_ylim([np.min(pset.lat)-25, np.max(pset.lat)+25])
plt.title("Initial particle positions")
plt.show()

# %% [markdown]
# List the kernels that will be used in the particle advection.
# For documentation on the kernels, see `PlasticParcels/kernels.py`

# %%
kernels

# %% [markdown]
# We will now advect these particles. We first need to create a Parcels `ParticleFile` where we will store our output. To advect the particles, we simply use the `execute` method.

# %%
## Define the runtime, the timestepping, and the output frequency of the simulation
runtime = particle_settings['runtime']
dt_timestep = particle_settings['dt_timestep']
dt_write = particle_settings['dt_write']

## Create the particle file where output will be stored
pfile = ParticleFile('simple_release.zarr', pset, outputdt=dt_write)

## Execute the simulation
pset.execute(kernels, runtime=runtime, dt=dt_timestep, output_file=pfile)

# %% [markdown]
# Plot the final locations of the particles

# %%
fig = plt.figure()
ax = plt.axes(projection=ccrs.PlateCarree())
ax.scatter(pset.lon, pset.lat, s=2, transform=ccrs.PlateCarree())
ax.coastlines()
ax.gridlines(draw_labels=True)
plt.title("Final particle positions")
plt.show()

fig = plt.figure()
ax = plt.axes(projection=ccrs.PlateCarree())
ax.scatter(pset.lon, pset.lat, s=2, transform=ccrs.PlateCarree())
ax.coastlines()
ax.gridlines(draw_labels=True)
ax.set_xlim([np.min(pset.lon)-25, np.max(pset.lon)+25])
ax.set_ylim([np.min(pset.lat)-25, np.max(pset.lat)+25])
plt.title("Final particle positions")
plt.show()

# %% [markdown]
# <div class="alert alert-info">
# To analyse the output, you can follow the Parcels tutorial here: https://docs.oceanparcels.org/en/latest/examples/tutorial_output.html
# </div>

# %% [markdown]
# ## Creating a more likely plastic particle release map
#
# ### Plastics emitted on the coast
# We use the mismanaged plastic waste estimates by country from Jambeck et. al "Plastic waste inputs from land into the ocean", Science (2015) (DOI: 10.1126/science.1260352) combined with the NASA GPW v4.11 global population dataset (see https://sedac.ciesin.columbia.edu/data/set/gpw-v4-population-density-rev11/) and the Natural Earth coastline vector dataset (see https://www.naturalearthdata.com/) in order to create a likely 'coastal' particle release map.

# %%
# File locations
coastal = './../../data/release/generated_files/coastal_population_MPW_NEMO0083.csv'
rivers = './../../data/release/generated_files/river_emissions_NEMO0083.csv'
fisheries = './../../data/release/generated_files/agg_data_fisheries_info.csv'

# Read and print coastal dataset
plastic_release = pd.read_csv(coastal)
plastic_release

# %% [markdown]
# ### Particles emitted at river outlets
# We use the  from Meijer et. al "More than 1000 rivers account for 80% of global riverine plastic emissions into the ocean" Science Advances (2021) (DOI: 10.1126/sciadv.aaz5803) combined with the Natural Earth coastline vector dataset to create a likely 'river' particle release map.

# %%
# Read and print coastal dataset
plastic_release = pd.read_csv(rivers)
plastic_release

# %% [markdown]
# ### Particles emitted from fishing-related activity
# Lastly, we use the Global Fishing Watch public fishing effort dataset (see https://globalfishingwatch.org/data-download/datasets/public-fishing-effort) combined with the Natural Earth coastline vector dataset to create a likely 'fisheries' particle release map.

# %%
# Read and print coastal dataset
plastic_release = pd.read_csv(fisheries)
plastic_release

# %%
del(plastic_release)

# %% [markdown]
# ### Create a particle set with these release settings

# %%
## First we need to remove the release locations we used in the basic example above
del(particle_settings['release_locations'])

# %%
## Remove any settings previously applied
settings_to_remove = ['release_type', 'particle_density', 'particle_diameter', 'windage_coefficient',
                      'continent', 'subregion', 'region', 'subregion', 'country']

for setting in settings_to_remove:
    if setting in particle_settings.keys():
        del(particle_settings[setting])


## Update your new settings here
new_settings = {'release_type': 'coastal',
                #'continent': '',
                #'region': '',
                #'subregion': 'Southern Europe',
                'country': 'Greece',
                'windage_coefficient' : 0.01, # Percentage of wind to apply to particles
                'particle_diameter' : 0.001, # Plastic particle diameter (m)
                'particle_density' : 1020. # Plastic particle density (kg/m^3)
}
particle_settings.update(new_settings)

## Create the particleset
pset = create_particleset_from_file(fieldset, particle_settings)

# %%
## Plot the particles initial positions
fig = plt.figure()
ax = plt.axes(projection=ccrs.PlateCarree())
ax.scatter(pset.lon, pset.lat, s=2, transform=ccrs.PlateCarree())
ax.coastlines()
ax.gridlines(draw_labels=True)
plt.title("Initial particle positions")
plt.show()

# %%
## Define the runtime, the timestepping, and the output frequency of the simulation
runtime = particle_settings['runtime']
dt_timestep = particle_settings['dt_timestep']
dt_write = particle_settings['dt_write']

## Create the particle file where output will be stored
pfile = ParticleFile('advanced_release.zarr', pset, outputdt=dt_write)

## Execute the simulation
pset.execute(kernels, runtime=runtime, dt=dt_timestep, output_file=pfile)

# %%
## Plot the particles final positions
fig = plt.figure()
ax = plt.axes(projection=ccrs.PlateCarree())
ax.scatter(pset.lon, pset.lat, s=2, transform=ccrs.PlateCarree())
ax.coastlines()
ax.gridlines(draw_labels=True)
plt.title("Final particle positions")
plt.show()

# %% [markdown]
# # Particle Trajectory Analysis
# You can now analyse your particle sets. Rather than re-invent the wheel, we point you to the Parcels tutorial https://docs.oceanparcels.org/en/latest/examples/tutorial_output.html which explains how to read and analyse Parcels particle trajectory datasets.
